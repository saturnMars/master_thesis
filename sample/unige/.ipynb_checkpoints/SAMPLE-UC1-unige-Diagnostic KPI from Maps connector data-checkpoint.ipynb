# %%
from sys import path
if '..' not in path:
    path.insert(0, '..')

# %%
from _library.utils import SYSTEM_NAMES_UNIGE,SYSTEM_NAMES_FULL, load_datasets
from os import path, makedirs
from scipy.stats import stats

# %%
import _library.diagnostic_utils as diagnostic_utils
import _library.fault_utils as fault_utils
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from datetime import datetime, timedelta, timezone

# %%
# %cd /mnt/data/vieri/projects/SAMPLE/
# Out:
# /mnt/data/vieri/projects/SAMPLE

# %% [markdown]
# # A) The PV system

# %% [markdown]
# ## A.1) Selecting the PV System

# %%
print(SYSTEM_NAMES_UNIGE)
# --- 0 ---------- 1 ---------- 2 ----- 3 ------ 4 --------- 5 -------- 6 --------- 7 ----
# Out:
# ['FV', 'Q05_FV']

# %%
# N.B. we have data only for FV system
system_name = SYSTEM_NAMES_UNIGE[0]
print("PV SYSTEM -->", system_name)
# Out:
# PV SYSTEM --> FV

# %% [markdown]
# ## A.2) Retrieve the Nominal Power of the PV system

# %%
inv_names = [system_name]
nominal_power = diagnostic_utils.load_PV_nominal_power(system_name)
inverter_nominal_power = nominal_power / len(inv_names)
beta = diagnostic_utils.load_PV_params(system_name)
print(f"[{system_name}] PV Nominal Power:   {nominal_power} kWp")
print(f"[{system_name}] It has {len(inv_names)} inverters: {inverter_nominal_power} kWp/inverter")
# Out:
# [FV] PV Nominal Power:   80 kWp
# [FV] It has 1 inverters: 80.0 kWp/inverter

# %%
beta = diagnostic_utils.load_PV_params(system_name)

# %% [markdown]
# ## A.3) Data wrangling

# %%
def maps_connector_data_wrangler():
    df = pd.DataFrame(columns = ["Irradiance (W/mq)", "Panel Temp 1", "Panel Temp 2"])

    data_type = "RADIATION"
    print("Reading " + data_type + " data of masp connector" + " ...")
    radiation = pd.read_csv("data/unige/pv1_maps_connector_data/pv1_panel_solar_rad.csv")
    radiation.columns = ['timestamp', 'Irradiance (W/mq)']
    radiation['timestamp'] = pd.to_datetime(radiation.timestamp)

    time_grouper = pd.Grouper(freq="1h")

    radiation = radiation.set_index('timestamp')
    data = radiation.groupby(time_grouper)['Irradiance (W/mq)'].mean()
    radiation = pd.DataFrame(data)
    radiation.index = radiation.index + timedelta(hours=1)

    data_type = "Temperature 1"
    print("Reading " + data_type +  " data of maps connector" + " ...")
    temperature1 = pd.read_csv("data/unige/pv1_maps_connector_data/pv1_panel_temp1.csv")
    temperature1.columns = ['timestamp', 'Panel Temp 1']
    temperature1['timestamp'] = pd.to_datetime(temperature1.timestamp)

    temperature1 = temperature1.set_index('timestamp')
    data = temperature1.groupby(time_grouper)['Panel Temp 1'].mean()
    temperature1 = pd.DataFrame(data)
    temperature1.index = temperature1.index + timedelta(hours=1)

    data_type = "Temperature 2"
    print("Reading " + data_type +  " data of maps connector" + " ...")
    temperature2 = pd.read_csv("data/unige/pv1_maps_connector_data/pv1_panel_temp2.csv")
    temperature2.columns = ['timestamp', 'Panel Temp 2']
    temperature2['timestamp'] = pd.to_datetime(temperature2.timestamp)

    temperature2 = temperature2.set_index('timestamp')
    data = temperature2.groupby(time_grouper)['Panel Temp 2'].mean()
    temperature2 = pd.DataFrame(data)
    temperature2.index = temperature2.index + timedelta(hours=1)

    data_type = "active_power"
    print("Reading " + data_type + " data of maps connector" + " ...")
    active_power = pd.read_csv("data/unige/pv1_maps_connector_data/pv1_active_power.csv")
    active_power.columns = ['timestamp', 'active_power']
    active_power['timestamp'] = pd.to_datetime(active_power.timestamp)

    active_power = active_power.set_index('timestamp')
    data = active_power['active_power'].groupby([pd.Grouper(freq='h')]).sum()
    ap = pd.DataFrame(data)

    ap['active_power_count'] = active_power['active_power'].groupby([pd.Grouper(freq='h')]).count().values
    ap["Generated Energy (kWh)"] = ap['active_power'] / ap['active_power_count']
    ap.loc[ap[ap["Generated Energy (kWh)"] < 0].index, "Generated Energy (kWh)"] = 0
        
    gen_energy = pd.DataFrame(ap.iloc[:,-1])
    df = df.append(radiation.join(temperature1).join(temperature2).join(gen_energy))
    
    return df, radiation, temperature1, temperature2, gen_energy

# %%
df, maps_radiation, maps_temperature1, maps_temperature2, maps_gen_energy = maps_connector_data_wrangler()
# Out:
# Reading RADIATION data of masp connector ...
# Reading Temperature 1 data of maps connector ...
# Reading Temperature 2 data of maps connector ...
# Reading active_power data of maps connector ...
# /tmp/ipykernel_25823/4181230160.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(radiation.join(temperature1).join(temperature2).join(gen_energy))

# %% [markdown]
# ## A.3 bis) Visualize data

# %%
plt.plot(maps_gen_energy)

# %%
plt.plot(maps_temperature1)

# %%
plt.plot(maps_temperature2)

# %%
plt.plot(maps_radiation)

# %% [markdown]
# ## A.4) Carry out some transformation to the dataset
# 1. Setting the **datetime column as index**.
# 2. **Computing the Generated Energy (kWh)** for each observation using the active power.
# 3. **Discarding problematic periods** (i.e., corrupted data)
# 4. fitting missing values

# %%
pd.set_option('display.float_format', lambda value: '%.3f' % value)
dt_col_name = "Date/Time"

# a) Set the datatime as index 
#    df.set_index(keys = df[dt_col_name], inplace = True)
#    df.drop(columns = dt_col_name, inplace = True)
#    print("a) Setting the datetime column as index.\n")

# b) Compute the E. totale (kWh) for the observations
df["E. totale (kWh)"] = df['Generated Energy (kWh)'].cumsum()
print("b) Compute the E. totale (kWh) for each observation .\n")

duplicated_ts = df[df.index.duplicated()].index
df.drop(index = duplicated_ts, inplace= True)
if len(duplicated_ts) > 0:
    print(f"d) Dropped some artefacts (i.e., {len(duplicated_ts)} duplicated obs.)\n")
# Out:
# b) Compute the E. totale (kWh) for each observation .

# %%
column_names = ['Irradiance (W/mq)', 'Panel Temp 1', 'Panel Temp 2','Generated Energy (kWh)']

# %%
def fit_missing_values(df,column_names, yearly_window = 7, local_window=7):
    
    for column_name in column_names:
        nan_indexes = df[df[column_name].isna()].index
#        if column_name == 'Irradiance (W/mq)':
#            for idx in nan_indexes:
#                df.at[idx,column_name] = df[idx-timedelta(days=local_window)::24].head(local_window).rolling(window = str(local_window)+'d').mean()[column_name][-1]
        
#        else:
        for idx in nan_indexes:
            if idx-timedelta(days=yearly_window+365-1) in df.index and not np.isnan(df.loc[idx-timedelta(days=yearly_window+365-1),column_name]):
                df.at[idx,column_name] = df[idx-timedelta(days=yearly_window+365-1)::24].head(yearly_window).rolling(window = str(yearly_window)+'d').mean()[column_name][-1]
            else:
                df.at[idx,column_name] = df[idx-timedelta(days=local_window)::24].head(local_window).rolling(window = str(local_window)+'d').mean()[column_name][-1]
    return df

# %%
df = fit_missing_values(df,column_names)

# %% [markdown]
# ### quality check

# %%
plt.plot(df['Panel Temp 1'])

# %%
plt.plot(df['Panel Temp 2'])

# %%
plt.plot(df['Irradiance (W/mq)'])

# %% [markdown]
# ### A.5) choose which KPI to use

# %%
##### choose which temp to use
possible_temp = ['Panel Temp 1', 'Panel Temp 2']
temp = possible_temp[0]

df = df.rename(columns={temp: "Panel Temp (°C)"})
columns = ['Irradiance (W/mq)', 'Panel Temp (°C)', 'Generated Energy (kWh)',"E. totale (kWh)"]
df = df[columns]

# %%
KPI_to_compute_options = ['PR', 'PR_with_temp_correction']

print('-'*30, 'set the type of KPI to compute', '-'*30)
#### choose the KPI to compute

KPI_to_compute = KPI_to_compute_options[1]
print(KPI_to_compute)

inv_data = {}

if KPI_to_compute == 'PR':
    df = df[['Irradiance (W/mq)','Generated Energy (kWh)', "E. totale (kWh)"]].dropna()
if KPI_to_compute == 'PR_with_temp_correction':
    df = df.dropna()
# Out:
# ------------------------------ set the type of KPI to compute ------------------------------
# PR_with_temp_correction

# %% [markdown]
# # B) Outlier correction

# %% [markdown]
# ## *Find and Fix the outliers*: Negative values for the variable 'Generated Energy'

# %%
# 0) Load the dataset
simplifed_df = df[["E. totale (kWh)", "Generated Energy (kWh)"]]

# 1) Find the outliers (TYPE A: Negative Generated Energy)
neg_cond = simplifed_df["Generated Energy (kWh)"] < - 0.00001 #? --> SINCE: -0.0
negative_generated_energy = simplifed_df[neg_cond]

if len(negative_generated_energy) != 0:
    print(f"OUTLIER (Type A): There are {len(negative_generated_energy)} observations "\
          f"({round((len(negative_generated_energy)/len(simplifed_df))*100, 2)} %) with a NEGATIVE VALUE for "\
          f"the generated energy (kWh)")

    # Perform the outlier corrrection 
    diagnostic_utils.neg_outlier_correction(df, negative_generated_energy.index)

else:
    print("OUTLIER (Type A): That's good. No negative values have been found!")
# Out:
# OUTLIER (Type A): That's good. No negative values have been found!

# %% [markdown]
# # C) Dealing with missing houlry observations
# ## STATEGY: Subtract the increment detected during the missing observations

# %%
timestamps = df.index.tolist()

# Detect gaps
time_deltas = np.diff(timestamps)
idk_problematic_obs = [(idk_obs, delta.components[1]) for idk_obs, delta in enumerate(time_deltas) if delta.components[1] > 1]

if len(idk_problematic_obs) == 0:
    print("OUTLIER (Type B): That's good. No problematic gaps have been found!")

for counter, (idk_obs, delta) in enumerate(idk_problematic_obs): 

    # Retrieve the previous and next value
    window_df = df.loc[df.index[idk_obs]:df.index[idk_obs + 1], "E. totale (kWh)"]
    obs_value = window_df.iloc[0]
    next_value = window_df.iloc[1]
    ts_next_obs = window_df.index[1]

    # Detect whethere there has been an increase in the cumulative variable 
    increase = round(np.abs(next_value - obs_value), 0)
    if increase > 0:
        print(f"\nPROBLEMATIC OBSERVATION: {counter + 1}/{len(idk_problematic_obs)}: "\
              f"{df.index[idk_obs].strftime('%Y-%m-%d (%H:%M)')}\n" + 60 * "-")
        print(f"[OBSERVATION]   {window_df.index[0].strftime('%H:%M')}: {round(obs_value, 2)} kWh")
        print(f"[NEXT OBS.]     {window_df.index[1].strftime('%H:%M')}: {round(next_value, 2)} kWh ")
        print(f"\n--> DELTA:  {delta} hours \n--> INCREASE: {increase} kWh\n")

        print('STAT 1: Subtract the "extra" generated energy from all the counters of the upcoming observations\n' 
              + "-" * 95)
        print(f"[BEFORE] Last obs. {df.index[-1]} --> {df['E. totale (kWh)'].iloc[-1]} kWh")

#            df.loc[ts_next_obs: , "E. totale (kWh)"] -= increase

        print(f"[AFTER]  Last obs. {df.index[-1]} --> {df['E. totale (kWh)'].iloc[-1]} kWh (-{increase} kWh)")
# Out:
# PROBLEMATIC OBSERVATION: 1/19: 2020-01-27 (21:00)
# ------------------------------------------------------------
# [OBSERVATION]   21:00: 8958.11 kWh
# [NEXT OBS.]     14:00: 8971.68 kWh
#
# --> DELTA:  17 hours
# --> INCREASE: 14.0 kWh
#
# STAT 1: Subtract the "extra" generated energy from all the counters of the upcoming observations
# -----------------------------------------------------------------------------------------------
# [BEFORE] Last obs. 2022-02-17 12:00:00+00:00 --> 181814.12404853394 kWh
# [AFTER]  Last obs. 2022-02-17 12:00:00+00:00 --> 181814.12404853394 kWh (-14.0 kWh)
#
# PROBLEMATIC OBSERVATION: 2/19: 2020-05-09 (05:00)
# ------------------------------------------------------------
# [OBSERVATION]   05:00: 33673.08 kWh
# [NEXT OBS.]     07:00: 33675.68 kWh
#
# --> DELTA:  2 hours
# --> INCREASE: 3.0 kWh
#
# STAT 1: Subtract the "extra" generated energy from all the counters of the upcoming observations
# -----------------------------------------------------------------------------------------------
# [BEFORE] Last obs. 2022-02-17 12:00:00+00:00 --> 181814.12404853394 kWh
# [AFTER]  Last obs. 2022-02-17 12:00:00+00:00 --> 181814.12404853394 kWh (-3.0 kWh)
#
# PROBLEMATIC OBSERVATION: 3/19: 2020-05-11 (13:00)
# ------------------------------------------------------------
# [OBSERVATION]   13:00: 33778.69 kWh
# [NEXT OBS.]     08:00: 33822.71 kWh
#
# --> DELTA:  19 hours
# --> INCREASE: 44.0 kWh
#
# STAT 1: Subtract the "extra" generated energy from all the counters of the upcoming observations
# -----------------------------------------------------------------------------------------------
# [BEFORE] Last obs. 2022-02-17 12:00:00+00:00 --> 181814.12404853394 kWh
# [AFTER]  Last obs. 2022-02-17 12:00:00+00:00 --> 181814.12404853394 kWh (-44.0 kWh)
#
# PROBLEMATIC OBSERVATION: 4/19: 2020-05-25 (19:00)
# ------------------------------------------------------------
# [OBSERVATION]   19:00: 38183.65 kWh
# [NEXT OBS.]     07:00: 38224.39 kWh
#
# --> DELTA:  12 hours
# --> INCREASE: 41.0 kWh
#
# STAT 1: Subtract the "extra" generated energy from all the counters of the upcoming observations
# -----------------------------------------------------------------------------------------------
# [BEFORE] Last obs. 2022-02-17 12:00:00+00:00 --> 181814.12404853394 kWh
# [AFTER]  Last obs. 2022-02-17 12:00:00+00:00 --> 181814.12404853394 kWh (-41.0 kWh)
#
# PROBLEMATIC OBSERVATION: 5/19: 2020-06-24 (22:00)
# ------------------------------------------------------------
# [OBSERVATION]   22:00: 47921.46 kWh
# [NEXT OBS.]     06:00: 47939.22 kWh
#
# --> DELTA:  8 hours
# --> INCREASE: 18.0 kWh
#
# STAT 1: Subtract the "extra" generated energy from all the counters of the upcoming observations
# -----------------------------------------------------------------------------------------------
# [BEFORE] Last obs. 2022-02-17 12:00:00+00:00 --> 181814.12404853394 kWh
# [AFTER]  Last obs. 2022-02-17 12:00:00+00:00 --> 181814.12404853394 kWh (-18.0 kWh)
#
# PROBLEMATIC OBSERVATION: 6/19: 2020-07-02 (15:00)
# ------------------------------------------------------------
# [OBSERVATION]   15:00: 50696.85 kWh
# [NEXT OBS.]     17:00: 50697.59 kWh
#
# --> DELTA:  2 hours
# --> INCREASE: 1.0 kWh
#
# STAT 1: Subtract the "extra" generated energy from all the counters of the upcoming observations
# -----------------------------------------------------------------------------------------------
# [BEFORE] Last obs. 2022-02-17 12:00:00+00:00 --> 181814.12404853394 kWh
# [AFTER]  Last obs. 2022-02-17 12:00:00+00:00 --> 181814.12404853394 kWh (-1.0 kWh)
#
# PROBLEMATIC OBSERVATION: 8/19: 2020-08-03 (12:00)
# ------------------------------------------------------------
# [OBSERVATION]   12:00: 62537.48 kWh
# [NEXT OBS.]     08:00: 62570.05 kWh
#
# --> DELTA:  20 hours
# --> INCREASE: 33.0 kWh
#
# STAT 1: Subtract the "extra" generated energy from all the counters of the upcoming observations
# -----------------------------------------------------------------------------------------------
# [BEFORE] Last obs. 2022-02-17 12:00:00+00:00 --> 181814.12404853394 kWh
# [AFTER]  Last obs. 2022-02-17 12:00:00+00:00 --> 181814.12404853394 kWh (-33.0 kWh)
#
# PROBLEMATIC OBSERVATION: 9/19: 2020-08-18 (09:00)
# ------------------------------------------------------------
# [OBSERVATION]   09:00: 67619.79 kWh
# [NEXT OBS.]     07:00: 67656.55 kWh
#
# --> DELTA:  22 hours
# --> INCREASE: 37.0 kWh
#
# STAT 1: Subtract the "extra" generated energy from all the counters of the upcoming observations
# -----------------------------------------------------------------------------------------------
# [BEFORE] Last obs. 2022-02-17 12:00:00+00:00 --> 181814.12404853394 kWh
# [AFTER]  Last obs. 2022-02-17 12:00:00+00:00 --> 181814.12404853394 kWh (-37.0 kWh)
#
# PROBLEMATIC OBSERVATION: 10/19: 2020-10-02 (19:00)
# ------------------------------------------------------------
# [OBSERVATION]   19:00: 80559.71 kWh
# [NEXT OBS.]     09:00: 80608.64 kWh
#
# --> DELTA:  14 hours
# --> INCREASE: 49.0 kWh
#
# STAT 1: Subtract the "extra" generated energy from all the counters of the upcoming observations
# -----------------------------------------------------------------------------------------------
# [BEFORE] Last obs. 2022-02-17 12:00:00+00:00 --> 181814.12404853394 kWh
# [AFTER]  Last obs. 2022-02-17 12:00:00+00:00 --> 181814.12404853394 kWh (-49.0 kWh)
#
# PROBLEMATIC OBSERVATION: 11/19: 2020-10-16 (23:00)
# ------------------------------------------------------------
# [OBSERVATION]   23:00: 83300.32 kWh
# [NEXT OBS.]     08:00: 83337.02 kWh
#
# --> DELTA:  9 hours
# --> INCREASE: 37.0 kWh
#
# STAT 1: Subtract the "extra" generated energy from all the counters of the upcoming observations
# -----------------------------------------------------------------------------------------------
# [BEFORE] Last obs. 2022-02-17 12:00:00+00:00 --> 181814.12404853394 kWh
# [AFTER]  Last obs. 2022-02-17 12:00:00+00:00 --> 181814.12404853394 kWh (-37.0 kWh)
#
# PROBLEMATIC OBSERVATION: 15/19: 2021-01-11 (09:00)
# ------------------------------------------------------------
# [OBSERVATION]   09:00: 91648.47 kWh
# [NEXT OBS.]     11:00: 91685.2 kWh
#
# --> DELTA:  2 hours
# --> INCREASE: 37.0 kWh
#
# STAT 1: Subtract the "extra" generated energy from all the counters of the upcoming observations
# -----------------------------------------------------------------------------------------------
# [BEFORE] Last obs. 2022-02-17 12:00:00+00:00 --> 181814.12404853394 kWh
# [AFTER]  Last obs. 2022-02-17 12:00:00+00:00 --> 181814.12404853394 kWh (-37.0 kWh)
#
# PROBLEMATIC OBSERVATION: 16/19: 2021-05-14 (21:00)
# ------------------------------------------------------------
# [OBSERVATION]   21:00: 120043.06 kWh
# [NEXT OBS.]     07:00: 120063.88 kWh
#
# --> DELTA:  10 hours
# --> INCREASE: 21.0 kWh
#
# STAT 1: Subtract the "extra" generated energy from all the counters of the upcoming observations
# -----------------------------------------------------------------------------------------------
# [BEFORE] Last obs. 2022-02-17 12:00:00+00:00 --> 181814.12404853394 kWh
# [AFTER]  Last obs. 2022-02-17 12:00:00+00:00 --> 181814.12404853394 kWh (-21.0 kWh)
#
# PROBLEMATIC OBSERVATION: 17/19: 2021-05-27 (13:00)
# ------------------------------------------------------------
# [OBSERVATION]   13:00: 123176.15 kWh
# [NEXT OBS.]     15:00: 123196.37 kWh
#
# --> DELTA:  2 hours
# --> INCREASE: 20.0 kWh
#
# STAT 1: Subtract the "extra" generated energy from all the counters of the upcoming observations
# -----------------------------------------------------------------------------------------------
# [BEFORE] Last obs. 2022-02-17 12:00:00+00:00 --> 181814.12404853394 kWh
# [AFTER]  Last obs. 2022-02-17 12:00:00+00:00 --> 181814.12404853394 kWh (-20.0 kWh)

# %% [markdown]
# # D) Perfomance Ratio (PR)

# %% [markdown]
# ## D.1) Set Sliding window [months]
# 1. Number of months
# 2. Cumulative [-1]

# %%
sliding_window = 1

# %% [markdown]
# ## D.2) Compute the *daily* Perfomance Ratio using a sliding window

# %%
verbose = False

# %%
inv_perfomance_ratio = dict()

# Isolate the dates
all_df_dates = sorted(set(df.index.date))
print(f"DATE AVAIABLE: {len(all_df_dates)}")
print(f"SELECTED PERIOD: {sliding_window} month(s)\n" +"-" * 40)

#display(df['2019-09-29':].head(50))

daily_perfomance_ratio = dict()
for idk, day in enumerate(all_df_dates):
    daily_ratio = diagnostic_utils.compute_perfomance_ratios(df, all_df_dates, day, sliding_window, 
                                                             inverter_nominal_power, verbose)

    # Try to use the previous KPI value (if available) in case of None value
    if daily_ratio == None:
        prev_day = all_df_dates[idk - 1]

        if str(prev_day) in daily_perfomance_ratio.keys():
            prev_kpi = daily_perfomance_ratio[str(prev_day)]
            daily_ratio = prev_kpi

            #print(f"[FIXED] Replaced the missing value with: {prev_day} "\
                  #f"--> KPI: {round(prev_kpi['Perfomance Ratio (%)'], 2)} %")

    # Save the value only if it's available
    if daily_ratio:
        daily_perfomance_ratio[str(day)] = daily_ratio

# Create and save a dataframe for each inverter
perfomance_ratio_df = pd.DataFrame.from_dict(daily_perfomance_ratio, orient = "index")

# Carry out some transformation
perfomance_ratio_df["Generated energy (kWh)"] = perfomance_ratio_df["Generated energy (kWh)"] / 10 ** 3
perfomance_ratio_df["Summed Solar Irradiance (Wh/mq)"] = perfomance_ratio_df["Summed Solar Irradiance (Wh/mq)"] / 10 ** 3
perfomance_ratio_df.rename(columns = {"Generated energy (kWh)": "Generated energy (MWh)",
                                      "Summed Solar Irradiance (Wh/mq)" : "Summed Solar Irradiance (kWh/mq)"}, 
                           inplace = True)
#display(perfomance_ratio_df)

#x = inv_perfomance_ratio[inv_names[0]].head(50)
#display(x)
# Out:
# DATE AVAIABLE: 835
# SELECTED PERIOD: 1 month(s)
# ----------------------------------------
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour

# %% [markdown]
# ## D.3) Visualize potential problematic ratios

# %%
pr_col_name = "Perfomance Ratio (%)"

# ISSUE: Perfomance Ratio values excedding 100%
cond = perfomance_ratio_df[pr_col_name] > 100
invalid_scores = perfomance_ratio_df.loc[cond, :]
if len(invalid_scores) > 0:
    print(f"ISSUE: There are {len(invalid_scores)} observations ({round((len(invalid_scores)/len(perfomance_ratio_df))*100, 2)} %) "\
          "which have their PERFOMANCE RATIO EXCEEDING 100%\n" + "-" * 96)

    verbose = True
    for idk, outlier_ts in enumerate(invalid_scores.index): #[:50]
        print(f"\n\tOBSERVATION ({idk + 1}/{len(invalid_scores)}): {outlier_ts}\n\t" + "-" * 41)

        observation = invalid_scores.loc[outlier_ts, :]

        if verbose:
            for col_name, value in observation.to_dict().items():
                name_parts = col_name.split("(")
                if len(name_parts) == 2:
                    print(f"\t{name_parts[0].strip()}: {round(value, 2)} {name_parts[1][:-1]}")
                else:
                    print(f"\t{col_name}: {value}")

        # Stat: set it to the maxium value (100%)
        perfomance_ratio_df.loc[outlier_ts, pr_col_name] = 100
        print("\n\t" + "-" * 50 + "\n\tSTRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).\n" 
              + "-" * 50 + "\n")
else:
    print("There aren't observations with thier perfomance ratio exceeding 100%. That's fantastic!\n"\
          f"\nDaily perfomance ratio available: {len(perfomance_ratio_df)} days")
# Out:
# ISSUE: There are 391 observations (48.57 %) which have their PERFOMANCE RATIO EXCEEDING 100%
# ------------------------------------------------------------------------------------------------
#
# 	OBSERVATION (1/391): 2019-12-09
# 	-----------------------------------------
# 	Starting Date: 2019-11-09
# 	Generated energy: 2.67 MWh
# 	Summed Solar Irradiance: 32.18 kWh/mq
# 	Perfomance Ratio: 103.89 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (2/391): 2019-12-10
# 	-----------------------------------------
# 	Starting Date: 2019-11-10
# 	Generated energy: 2.76 MWh
# 	Summed Solar Irradiance: 31.46 kWh/mq
# 	Perfomance Ratio: 109.51 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (3/391): 2019-12-11
# 	-----------------------------------------
# 	Starting Date: 2019-11-11
# 	Generated energy: 2.78 MWh
# 	Summed Solar Irradiance: 30.97 kWh/mq
# 	Perfomance Ratio: 112.36 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (4/391): 2019-12-12
# 	-----------------------------------------
# 	Starting Date: 2019-11-12
# 	Generated energy: 2.91 MWh
# 	Summed Solar Irradiance: 31.14 kWh/mq
# 	Perfomance Ratio: 116.93 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (5/391): 2019-12-13
# 	-----------------------------------------
# 	Starting Date: 2019-11-13
# 	Generated energy: 2.8 MWh
# 	Summed Solar Irradiance: 28.38 kWh/mq
# 	Perfomance Ratio: 123.12 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (6/391): 2019-12-14
# 	-----------------------------------------
# 	Starting Date: 2019-11-14
# 	Generated energy: 2.73 MWh
# 	Summed Solar Irradiance: 27.65 kWh/mq
# 	Perfomance Ratio: 123.37 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (7/391): 2019-12-15
# 	-----------------------------------------
# 	Starting Date: 2019-11-15
# 	Generated energy: 2.7 MWh
# 	Summed Solar Irradiance: 27.3 kWh/mq
# 	Perfomance Ratio: 123.78 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (8/391): 2019-12-16
# 	-----------------------------------------
# 	Starting Date: 2019-11-16
# 	Generated energy: 2.72 MWh
# 	Summed Solar Irradiance: 27.68 kWh/mq
# 	Perfomance Ratio: 122.76 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (9/391): 2019-12-17
# 	-----------------------------------------
# 	Starting Date: 2019-11-17
# 	Generated energy: 2.56 MWh
# 	Summed Solar Irradiance: 25.74 kWh/mq
# 	Perfomance Ratio: 124.55 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (10/391): 2019-12-18
# 	-----------------------------------------
# 	Starting Date: 2019-11-18
# 	Generated energy: 2.52 MWh
# 	Summed Solar Irradiance: 25.96 kWh/mq
# 	Perfomance Ratio: 121.55 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (11/391): 2019-12-19
# 	-----------------------------------------
# 	Starting Date: 2019-11-19
# 	Generated energy: 2.51 MWh
# 	Summed Solar Irradiance: 26.53 kWh/mq
# 	Perfomance Ratio: 118.45 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (12/391): 2019-12-20
# 	-----------------------------------------
# 	Starting Date: 2019-11-20
# 	Generated energy: 2.5 MWh
# 	Summed Solar Irradiance: 27.32 kWh/mq
# 	Perfomance Ratio: 114.16 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (13/391): 2019-12-21
# 	-----------------------------------------
# 	Starting Date: 2019-11-21
# 	Generated energy: 2.55 MWh
# 	Summed Solar Irradiance: 27.34 kWh/mq
# 	Perfomance Ratio: 116.77 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (14/391): 2019-12-22
# 	-----------------------------------------
# 	Starting Date: 2019-11-22
# 	Generated energy: 2.63 MWh
# 	Summed Solar Irradiance: 27.15 kWh/mq
# 	Perfomance Ratio: 120.98 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (15/391): 2019-12-23
# 	-----------------------------------------
# 	Starting Date: 2019-11-23
# 	Generated energy: 2.72 MWh
# 	Summed Solar Irradiance: 27.37 kWh/mq
# 	Perfomance Ratio: 124.29 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (16/391): 2019-12-24
# 	-----------------------------------------
# 	Starting Date: 2019-11-24
# 	Generated energy: 2.86 MWh
# 	Summed Solar Irradiance: 28.4 kWh/mq
# 	Perfomance Ratio: 125.71 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (17/391): 2019-12-25
# 	-----------------------------------------
# 	Starting Date: 2019-11-25
# 	Generated energy: 2.97 MWh
# 	Summed Solar Irradiance: 29.09 kWh/mq
# 	Perfomance Ratio: 127.72 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (18/391): 2019-12-26
# 	-----------------------------------------
# 	Starting Date: 2019-11-26
# 	Generated energy: 2.91 MWh
# 	Summed Solar Irradiance: 27.42 kWh/mq
# 	Perfomance Ratio: 132.65 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (19/391): 2019-12-27
# 	-----------------------------------------
# 	Starting Date: 2019-11-27
# 	Generated energy: 2.94 MWh
# 	Summed Solar Irradiance: 28.11 kWh/mq
# 	Perfomance Ratio: 130.93 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (20/391): 2019-12-28
# 	-----------------------------------------
# 	Starting Date: 2019-11-28
# 	Generated energy: 3.04 MWh
# 	Summed Solar Irradiance: 28.76 kWh/mq
# 	Perfomance Ratio: 131.97 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (21/391): 2019-12-29
# 	-----------------------------------------
# 	Starting Date: 2019-11-29
# 	Generated energy: 3.07 MWh
# 	Summed Solar Irradiance: 29.35 kWh/mq
# 	Perfomance Ratio: 130.71 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (22/391): 2019-12-30
# 	-----------------------------------------
# 	Starting Date: 2019-11-30
# 	Generated energy: 3.06 MWh
# 	Summed Solar Irradiance: 29.69 kWh/mq
# 	Perfomance Ratio: 128.74 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (23/391): 2019-12-31
# 	-----------------------------------------
# 	Starting Date: 2019-12-01
# 	Generated energy: 3.0 MWh
# 	Summed Solar Irradiance: 30.28 kWh/mq
# 	Perfomance Ratio: 123.72 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (24/391): 2020-01-01
# 	-----------------------------------------
# 	Starting Date: 2019-12-02
# 	Generated energy: 3.13 MWh
# 	Summed Solar Irradiance: 30.97 kWh/mq
# 	Perfomance Ratio: 126.27 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (25/391): 2020-01-02
# 	-----------------------------------------
# 	Starting Date: 2019-12-03
# 	Generated energy: 3.13 MWh
# 	Summed Solar Irradiance: 31.45 kWh/mq
# 	Perfomance Ratio: 124.36 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (26/391): 2020-01-03
# 	-----------------------------------------
# 	Starting Date: 2019-12-04
# 	Generated energy: 3.06 MWh
# 	Summed Solar Irradiance: 31.82 kWh/mq
# 	Perfomance Ratio: 120.12 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (27/391): 2020-01-04
# 	-----------------------------------------
# 	Starting Date: 2019-12-05
# 	Generated energy: 3.07 MWh
# 	Summed Solar Irradiance: 32.26 kWh/mq
# 	Perfomance Ratio: 119.1 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (28/391): 2020-01-05
# 	-----------------------------------------
# 	Starting Date: 2019-12-06
# 	Generated energy: 3.14 MWh
# 	Summed Solar Irradiance: 32.73 kWh/mq
# 	Perfomance Ratio: 120.08 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (29/391): 2020-01-06
# 	-----------------------------------------
# 	Starting Date: 2019-12-07
# 	Generated energy: 3.23 MWh
# 	Summed Solar Irradiance: 33.36 kWh/mq
# 	Perfomance Ratio: 121.18 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (30/391): 2020-01-07
# 	-----------------------------------------
# 	Starting Date: 2019-12-08
# 	Generated energy: 3.24 MWh
# 	Summed Solar Irradiance: 34.05 kWh/mq
# 	Perfomance Ratio: 118.78 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (31/391): 2020-01-08
# 	-----------------------------------------
# 	Starting Date: 2019-12-09
# 	Generated energy: 3.28 MWh
# 	Summed Solar Irradiance: 34.5 kWh/mq
# 	Perfomance Ratio: 118.91 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (32/391): 2020-01-09
# 	-----------------------------------------
# 	Starting Date: 2019-12-10
# 	Generated energy: 3.26 MWh
# 	Summed Solar Irradiance: 35.17 kWh/mq
# 	Perfomance Ratio: 115.96 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (33/391): 2020-01-10
# 	-----------------------------------------
# 	Starting Date: 2019-12-11
# 	Generated energy: 3.21 MWh
# 	Summed Solar Irradiance: 35.73 kWh/mq
# 	Perfomance Ratio: 112.18 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (34/391): 2020-01-11
# 	-----------------------------------------
# 	Starting Date: 2019-12-12
# 	Generated energy: 3.27 MWh
# 	Summed Solar Irradiance: 36.08 kWh/mq
# 	Perfomance Ratio: 113.13 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (35/391): 2020-01-12
# 	-----------------------------------------
# 	Starting Date: 2019-12-13
# 	Generated energy: 3.29 MWh
# 	Summed Solar Irradiance: 36.66 kWh/mq
# 	Perfomance Ratio: 112.02 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (36/391): 2020-01-13
# 	-----------------------------------------
# 	Starting Date: 2019-12-14
# 	Generated energy: 3.34 MWh
# 	Summed Solar Irradiance: 37.32 kWh/mq
# 	Perfomance Ratio: 111.91 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (37/391): 2020-01-14
# 	-----------------------------------------
# 	Starting Date: 2019-12-15
# 	Generated energy: 3.23 MWh
# 	Summed Solar Irradiance: 35.18 kWh/mq
# 	Perfomance Ratio: 114.88 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (38/391): 2020-01-15
# 	-----------------------------------------
# 	Starting Date: 2019-12-16
# 	Generated energy: 3.23 MWh
# 	Summed Solar Irradiance: 35.95 kWh/mq
# 	Perfomance Ratio: 112.25 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (39/391): 2020-01-16
# 	-----------------------------------------
# 	Starting Date: 2019-12-17
# 	Generated energy: 3.31 MWh
# 	Summed Solar Irradiance: 36.01 kWh/mq
# 	Perfomance Ratio: 114.97 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (40/391): 2020-01-17
# 	-----------------------------------------
# 	Starting Date: 2019-12-18
# 	Generated energy: 3.33 MWh
# 	Summed Solar Irradiance: 36.13 kWh/mq
# 	Perfomance Ratio: 115.38 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (41/391): 2020-01-18
# 	-----------------------------------------
# 	Starting Date: 2019-12-19
# 	Generated energy: 3.49 MWh
# 	Summed Solar Irradiance: 36.19 kWh/mq
# 	Perfomance Ratio: 120.54 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (42/391): 2020-01-19
# 	-----------------------------------------
# 	Starting Date: 2019-12-20
# 	Generated energy: 3.63 MWh
# 	Summed Solar Irradiance: 36.2 kWh/mq
# 	Perfomance Ratio: 125.48 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (43/391): 2020-01-20
# 	-----------------------------------------
# 	Starting Date: 2019-12-21
# 	Generated energy: 3.78 MWh
# 	Summed Solar Irradiance: 36.09 kWh/mq
# 	Perfomance Ratio: 130.98 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (44/391): 2020-01-21
# 	-----------------------------------------
# 	Starting Date: 2019-12-22
# 	Generated energy: 3.74 MWh
# 	Summed Solar Irradiance: 36.46 kWh/mq
# 	Perfomance Ratio: 128.36 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (45/391): 2020-01-22
# 	-----------------------------------------
# 	Starting Date: 2019-12-23
# 	Generated energy: 3.74 MWh
# 	Summed Solar Irradiance: 37.9 kWh/mq
# 	Perfomance Ratio: 123.36 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (46/391): 2020-01-23
# 	-----------------------------------------
# 	Starting Date: 2019-12-24
# 	Generated energy: 3.76 MWh
# 	Summed Solar Irradiance: 41.27 kWh/mq
# 	Perfomance Ratio: 113.97 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (47/391): 2020-01-24
# 	-----------------------------------------
# 	Starting Date: 2019-12-25
# 	Generated energy: 3.67 MWh
# 	Summed Solar Irradiance: 44.69 kWh/mq
# 	Perfomance Ratio: 102.65 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (48/391): 2020-06-22
# 	-----------------------------------------
# 	Starting Date: 2020-05-23
# 	Generated energy: 9.83 MWh
# 	Summed Solar Irradiance: 118.87 kWh/mq
# 	Perfomance Ratio: 103.42 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (49/391): 2020-06-23
# 	-----------------------------------------
# 	Starting Date: 2020-05-24
# 	Generated energy: 10.21 MWh
# 	Summed Solar Irradiance: 118.89 kWh/mq
# 	Perfomance Ratio: 107.36 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (50/391): 2020-06-24
# 	-----------------------------------------
# 	Starting Date: 2020-05-25
# 	Generated energy: 10.21 MWh
# 	Summed Solar Irradiance: 111.48 kWh/mq
# 	Perfomance Ratio: 114.45 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (51/391): 2020-06-25
# 	-----------------------------------------
# 	Starting Date: 2020-05-25
# 	Generated energy: 10.21 MWh
# 	Summed Solar Irradiance: 111.48 kWh/mq
# 	Perfomance Ratio: 114.45 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (52/391): 2020-06-26
# 	-----------------------------------------
# 	Starting Date: 2020-05-27
# 	Generated energy: 10.49 MWh
# 	Summed Solar Irradiance: 104.88 kWh/mq
# 	Perfomance Ratio: 124.99 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (53/391): 2020-06-27
# 	-----------------------------------------
# 	Starting Date: 2020-05-28
# 	Generated energy: 10.52 MWh
# 	Summed Solar Irradiance: 98.34 kWh/mq
# 	Perfomance Ratio: 133.79 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (54/391): 2020-06-28
# 	-----------------------------------------
# 	Starting Date: 2020-05-29
# 	Generated energy: 10.59 MWh
# 	Summed Solar Irradiance: 92.44 kWh/mq
# 	Perfomance Ratio: 143.16 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (55/391): 2020-06-29
# 	-----------------------------------------
# 	Starting Date: 2020-05-30
# 	Generated energy: 10.66 MWh
# 	Summed Solar Irradiance: 88.75 kWh/mq
# 	Perfomance Ratio: 150.16 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (56/391): 2020-06-30
# 	-----------------------------------------
# 	Starting Date: 2020-05-31
# 	Generated energy: 10.49 MWh
# 	Summed Solar Irradiance: 82.02 kWh/mq
# 	Perfomance Ratio: 159.89 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (57/391): 2020-07-01
# 	-----------------------------------------
# 	Starting Date: 2020-06-01
# 	Generated energy: 10.29 MWh
# 	Summed Solar Irradiance: 76.67 kWh/mq
# 	Perfomance Ratio: 167.75 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (58/391): 2020-07-02
# 	-----------------------------------------
# 	Starting Date: 2020-06-02
# 	Generated energy: 10.21 MWh
# 	Summed Solar Irradiance: 69.48 kWh/mq
# 	Perfomance Ratio: 183.62 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (59/391): 2020-07-03
# 	-----------------------------------------
# 	Starting Date: 2020-06-03
# 	Generated energy: 10.15 MWh
# 	Summed Solar Irradiance: 62.29 kWh/mq
# 	Perfomance Ratio: 203.78 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (60/391): 2020-07-04
# 	-----------------------------------------
# 	Starting Date: 2020-06-04
# 	Generated energy: 10.45 MWh
# 	Summed Solar Irradiance: 59.77 kWh/mq
# 	Perfomance Ratio: 218.51 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (61/391): 2020-07-05
# 	-----------------------------------------
# 	Starting Date: 2020-06-05
# 	Generated energy: 10.88 MWh
# 	Summed Solar Irradiance: 59.74 kWh/mq
# 	Perfomance Ratio: 227.71 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (62/391): 2020-07-06
# 	-----------------------------------------
# 	Starting Date: 2020-06-06
# 	Generated energy: 10.83 MWh
# 	Summed Solar Irradiance: 52.84 kWh/mq
# 	Perfomance Ratio: 256.1 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (63/391): 2020-07-07
# 	-----------------------------------------
# 	Starting Date: 2020-06-07
# 	Generated energy: 10.98 MWh
# 	Summed Solar Irradiance: 48.09 kWh/mq
# 	Perfomance Ratio: 285.38 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (64/391): 2020-07-08
# 	-----------------------------------------
# 	Starting Date: 2020-06-08
# 	Generated energy: 11.43 MWh
# 	Summed Solar Irradiance: 47.61 kWh/mq
# 	Perfomance Ratio: 299.95 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (65/391): 2020-07-09
# 	-----------------------------------------
# 	Starting Date: 2020-06-09
# 	Generated energy: 11.51 MWh
# 	Summed Solar Irradiance: 42.33 kWh/mq
# 	Perfomance Ratio: 339.89 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (66/391): 2020-07-10
# 	-----------------------------------------
# 	Starting Date: 2020-06-10
# 	Generated energy: 11.51 MWh
# 	Summed Solar Irradiance: 36.7 kWh/mq
# 	Perfomance Ratio: 392.2 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (67/391): 2020-07-11
# 	-----------------------------------------
# 	Starting Date: 2020-06-11
# 	Generated energy: 11.45 MWh
# 	Summed Solar Irradiance: 33.84 kWh/mq
# 	Perfomance Ratio: 423.05 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (68/391): 2020-07-12
# 	-----------------------------------------
# 	Starting Date: 2020-06-12
# 	Generated energy: 11.77 MWh
# 	Summed Solar Irradiance: 32.28 kWh/mq
# 	Perfomance Ratio: 455.82 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (69/391): 2020-07-13
# 	-----------------------------------------
# 	Starting Date: 2020-06-13
# 	Generated energy: 11.97 MWh
# 	Summed Solar Irradiance: 30.96 kWh/mq
# 	Perfomance Ratio: 483.18 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (70/391): 2020-07-14
# 	-----------------------------------------
# 	Starting Date: 2020-06-14
# 	Generated energy: 12.26 MWh
# 	Summed Solar Irradiance: 31.67 kWh/mq
# 	Perfomance Ratio: 483.71 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (71/391): 2020-07-15
# 	-----------------------------------------
# 	Starting Date: 2020-06-15
# 	Generated energy: 12.15 MWh
# 	Summed Solar Irradiance: 31.16 kWh/mq
# 	Perfomance Ratio: 487.37 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (72/391): 2020-07-16
# 	-----------------------------------------
# 	Starting Date: 2020-06-16
# 	Generated energy: 12.13 MWh
# 	Summed Solar Irradiance: 30.39 kWh/mq
# 	Perfomance Ratio: 498.91 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (73/391): 2020-07-17
# 	-----------------------------------------
# 	Starting Date: 2020-06-17
# 	Generated energy: 12.13 MWh
# 	Summed Solar Irradiance: 30.35 kWh/mq
# 	Perfomance Ratio: 499.75 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (74/391): 2020-07-18
# 	-----------------------------------------
# 	Starting Date: 2020-06-18
# 	Generated energy: 12.12 MWh
# 	Summed Solar Irradiance: 30.98 kWh/mq
# 	Perfomance Ratio: 488.95 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (75/391): 2020-07-19
# 	-----------------------------------------
# 	Starting Date: 2020-06-19
# 	Generated energy: 12.28 MWh
# 	Summed Solar Irradiance: 30.93 kWh/mq
# 	Perfomance Ratio: 496.49 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (76/391): 2020-07-20
# 	-----------------------------------------
# 	Starting Date: 2020-06-20
# 	Generated energy: 12.39 MWh
# 	Summed Solar Irradiance: 30.93 kWh/mq
# 	Perfomance Ratio: 500.82 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (77/391): 2020-07-21
# 	-----------------------------------------
# 	Starting Date: 2020-06-21
# 	Generated energy: 12.14 MWh
# 	Summed Solar Irradiance: 30.91 kWh/mq
# 	Perfomance Ratio: 490.94 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (78/391): 2020-07-22
# 	-----------------------------------------
# 	Starting Date: 2020-06-22
# 	Generated energy: 11.92 MWh
# 	Summed Solar Irradiance: 30.92 kWh/mq
# 	Perfomance Ratio: 481.84 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (79/391): 2020-07-23
# 	-----------------------------------------
# 	Starting Date: 2020-06-23
# 	Generated energy: 11.82 MWh
# 	Summed Solar Irradiance: 28.62 kWh/mq
# 	Perfomance Ratio: 516.28 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (80/391): 2020-07-24
# 	-----------------------------------------
# 	Starting Date: 2020-06-24
# 	Generated energy: 11.53 MWh
# 	Summed Solar Irradiance: 27.95 kWh/mq
# 	Perfomance Ratio: 515.62 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (81/391): 2020-07-25
# 	-----------------------------------------
# 	Starting Date: 2020-06-25
# 	Generated energy: 11.5 MWh
# 	Summed Solar Irradiance: 27.93 kWh/mq
# 	Perfomance Ratio: 514.68 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (82/391): 2020-07-26
# 	-----------------------------------------
# 	Starting Date: 2020-06-26
# 	Generated energy: 11.41 MWh
# 	Summed Solar Irradiance: 27.92 kWh/mq
# 	Perfomance Ratio: 510.69 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (83/391): 2020-07-27
# 	-----------------------------------------
# 	Starting Date: 2020-06-27
# 	Generated energy: 11.45 MWh
# 	Summed Solar Irradiance: 27.81 kWh/mq
# 	Perfomance Ratio: 514.6 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (84/391): 2020-07-28
# 	-----------------------------------------
# 	Starting Date: 2020-06-28
# 	Generated energy: 11.33 MWh
# 	Summed Solar Irradiance: 27.82 kWh/mq
# 	Perfomance Ratio: 508.97 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (85/391): 2020-07-29
# 	-----------------------------------------
# 	Starting Date: 2020-06-29
# 	Generated energy: 11.23 MWh
# 	Summed Solar Irradiance: 27.82 kWh/mq
# 	Perfomance Ratio: 504.35 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (86/391): 2020-07-30
# 	-----------------------------------------
# 	Starting Date: 2020-06-30
# 	Generated energy: 11.34 MWh
# 	Summed Solar Irradiance: 33.54 kWh/mq
# 	Perfomance Ratio: 422.53 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (87/391): 2020-07-31
# 	-----------------------------------------
# 	Starting Date: 2020-07-01
# 	Generated energy: 11.44 MWh
# 	Summed Solar Irradiance: 33.5 kWh/mq
# 	Perfomance Ratio: 426.88 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (88/391): 2020-08-01
# 	-----------------------------------------
# 	Starting Date: 2020-07-02
# 	Generated energy: 11.69 MWh
# 	Summed Solar Irradiance: 33.55 kWh/mq
# 	Perfomance Ratio: 435.41 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (89/391): 2020-08-02
# 	-----------------------------------------
# 	Starting Date: 2020-07-03
# 	Generated energy: 11.72 MWh
# 	Summed Solar Irradiance: 33.83 kWh/mq
# 	Perfomance Ratio: 432.89 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (90/391): 2020-08-03
# 	-----------------------------------------
# 	Starting Date: 2020-07-04
# 	Generated energy: 11.42 MWh
# 	Summed Solar Irradiance: 33.81 kWh/mq
# 	Perfomance Ratio: 422.09 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (91/391): 2020-08-04
# 	-----------------------------------------
# 	Starting Date: 2020-07-05
# 	Generated energy: 11.3 MWh
# 	Summed Solar Irradiance: 33.41 kWh/mq
# 	Perfomance Ratio: 422.86 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (92/391): 2020-08-05
# 	-----------------------------------------
# 	Starting Date: 2020-07-06
# 	Generated energy: 11.29 MWh
# 	Summed Solar Irradiance: 33.55 kWh/mq
# 	Perfomance Ratio: 420.61 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (93/391): 2020-08-06
# 	-----------------------------------------
# 	Starting Date: 2020-07-07
# 	Generated energy: 11.33 MWh
# 	Summed Solar Irradiance: 33.7 kWh/mq
# 	Perfomance Ratio: 420.23 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (94/391): 2020-08-07
# 	-----------------------------------------
# 	Starting Date: 2020-07-08
# 	Generated energy: 11.26 MWh
# 	Summed Solar Irradiance: 35.01 kWh/mq
# 	Perfomance Ratio: 402.06 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (95/391): 2020-08-08
# 	-----------------------------------------
# 	Starting Date: 2020-07-09
# 	Generated energy: 11.23 MWh
# 	Summed Solar Irradiance: 34.92 kWh/mq
# 	Perfomance Ratio: 401.9 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (96/391): 2020-08-09
# 	-----------------------------------------
# 	Starting Date: 2020-07-10
# 	Generated energy: 11.19 MWh
# 	Summed Solar Irradiance: 36.83 kWh/mq
# 	Perfomance Ratio: 379.6 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (97/391): 2020-08-10
# 	-----------------------------------------
# 	Starting Date: 2020-07-11
# 	Generated energy: 11.11 MWh
# 	Summed Solar Irradiance: 36.85 kWh/mq
# 	Perfomance Ratio: 377.05 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (98/391): 2020-08-11
# 	-----------------------------------------
# 	Starting Date: 2020-07-12
# 	Generated energy: 11.31 MWh
# 	Summed Solar Irradiance: 36.84 kWh/mq
# 	Perfomance Ratio: 383.69 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (99/391): 2020-08-12
# 	-----------------------------------------
# 	Starting Date: 2020-07-13
# 	Generated energy: 11.14 MWh
# 	Summed Solar Irradiance: 36.85 kWh/mq
# 	Perfomance Ratio: 377.89 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (100/391): 2020-08-13
# 	-----------------------------------------
# 	Starting Date: 2020-07-14
# 	Generated energy: 11.01 MWh
# 	Summed Solar Irradiance: 36.39 kWh/mq
# 	Perfomance Ratio: 378.12 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (101/391): 2020-08-14
# 	-----------------------------------------
# 	Starting Date: 2020-07-15
# 	Generated energy: 10.98 MWh
# 	Summed Solar Irradiance: 35.25 kWh/mq
# 	Perfomance Ratio: 389.22 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (102/391): 2020-08-15
# 	-----------------------------------------
# 	Starting Date: 2020-07-16
# 	Generated energy: 11.03 MWh
# 	Summed Solar Irradiance: 40.57 kWh/mq
# 	Perfomance Ratio: 339.98 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (103/391): 2020-08-16
# 	-----------------------------------------
# 	Starting Date: 2020-07-17
# 	Generated energy: 10.91 MWh
# 	Summed Solar Irradiance: 44.54 kWh/mq
# 	Perfomance Ratio: 306.26 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (104/391): 2020-08-17
# 	-----------------------------------------
# 	Starting Date: 2020-07-18
# 	Generated energy: 10.71 MWh
# 	Summed Solar Irradiance: 43.48 kWh/mq
# 	Perfomance Ratio: 307.91 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (105/391): 2020-08-18
# 	-----------------------------------------
# 	Starting Date: 2020-07-19
# 	Generated energy: 10.52 MWh
# 	Summed Solar Irradiance: 41.88 kWh/mq
# 	Perfomance Ratio: 313.92 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (106/391): 2020-08-19
# 	-----------------------------------------
# 	Starting Date: 2020-07-20
# 	Generated energy: 10.46 MWh
# 	Summed Solar Irradiance: 48.44 kWh/mq
# 	Perfomance Ratio: 269.78 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (107/391): 2020-08-20
# 	-----------------------------------------
# 	Starting Date: 2020-07-21
# 	Generated energy: 10.41 MWh
# 	Summed Solar Irradiance: 55.11 kWh/mq
# 	Perfomance Ratio: 236.11 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (108/391): 2020-08-21
# 	-----------------------------------------
# 	Starting Date: 2020-07-22
# 	Generated energy: 10.58 MWh
# 	Summed Solar Irradiance: 61.95 kWh/mq
# 	Perfomance Ratio: 213.51 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (109/391): 2020-08-22
# 	-----------------------------------------
# 	Starting Date: 2020-07-23
# 	Generated energy: 10.7 MWh
# 	Summed Solar Irradiance: 67.99 kWh/mq
# 	Perfomance Ratio: 196.71 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (110/391): 2020-08-23
# 	-----------------------------------------
# 	Starting Date: 2020-07-24
# 	Generated energy: 10.7 MWh
# 	Summed Solar Irradiance: 74.38 kWh/mq
# 	Perfomance Ratio: 179.75 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (111/391): 2020-08-24
# 	-----------------------------------------
# 	Starting Date: 2020-07-25
# 	Generated energy: 10.82 MWh
# 	Summed Solar Irradiance: 78.85 kWh/mq
# 	Perfomance Ratio: 171.52 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (112/391): 2020-08-25
# 	-----------------------------------------
# 	Starting Date: 2020-07-26
# 	Generated energy: 10.76 MWh
# 	Summed Solar Irradiance: 85.45 kWh/mq
# 	Perfomance Ratio: 157.39 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (113/391): 2020-08-26
# 	-----------------------------------------
# 	Starting Date: 2020-07-27
# 	Generated energy: 10.82 MWh
# 	Summed Solar Irradiance: 91.38 kWh/mq
# 	Perfomance Ratio: 148.04 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (114/391): 2020-08-27
# 	-----------------------------------------
# 	Starting Date: 2020-07-28
# 	Generated energy: 10.76 MWh
# 	Summed Solar Irradiance: 97.63 kWh/mq
# 	Perfomance Ratio: 137.79 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (115/391): 2020-08-28
# 	-----------------------------------------
# 	Starting Date: 2020-07-29
# 	Generated energy: 10.61 MWh
# 	Summed Solar Irradiance: 99.41 kWh/mq
# 	Perfomance Ratio: 133.47 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (116/391): 2020-08-29
# 	-----------------------------------------
# 	Starting Date: 2020-07-30
# 	Generated energy: 10.48 MWh
# 	Summed Solar Irradiance: 102.94 kWh/mq
# 	Perfomance Ratio: 127.31 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (117/391): 2020-08-30
# 	-----------------------------------------
# 	Starting Date: 2020-07-31
# 	Generated energy: 10.46 MWh
# 	Summed Solar Irradiance: 103.46 kWh/mq
# 	Perfomance Ratio: 126.34 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (118/391): 2020-08-31
# 	-----------------------------------------
# 	Starting Date: 2020-08-01
# 	Generated energy: 10.28 MWh
# 	Summed Solar Irradiance: 107.0 kWh/mq
# 	Perfomance Ratio: 120.12 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (119/391): 2020-09-01
# 	-----------------------------------------
# 	Starting Date: 2020-08-02
# 	Generated energy: 10.21 MWh
# 	Summed Solar Irradiance: 112.45 kWh/mq
# 	Perfomance Ratio: 113.48 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (120/391): 2020-09-02
# 	-----------------------------------------
# 	Starting Date: 2020-08-03
# 	Generated energy: 10.1 MWh
# ...
# 	-----------------------------------------
# 	Starting Date: 2021-11-14
# 	Generated energy: 3.38 MWh
# 	Summed Solar Irradiance: 19.88 kWh/mq
# 	Perfomance Ratio: 212.41 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (353/391): 2021-12-15
# 	-----------------------------------------
# 	Starting Date: 2021-11-15
# 	Generated energy: 3.45 MWh
# 	Summed Solar Irradiance: 19.91 kWh/mq
# 	Perfomance Ratio: 216.88 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (354/391): 2021-12-16
# 	-----------------------------------------
# 	Starting Date: 2021-11-16
# 	Generated energy: 3.58 MWh
# 	Summed Solar Irradiance: 19.95 kWh/mq
# 	Perfomance Ratio: 224.5 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (355/391): 2021-12-17
# 	-----------------------------------------
# 	Starting Date: 2021-11-17
# 	Generated energy: 3.61 MWh
# 	Summed Solar Irradiance: 19.95 kWh/mq
# 	Perfomance Ratio: 226.28 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (356/391): 2021-12-18
# 	-----------------------------------------
# 	Starting Date: 2021-11-18
# 	Generated energy: 3.67 MWh
# 	Summed Solar Irradiance: 19.96 kWh/mq
# 	Perfomance Ratio: 229.71 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (357/391): 2021-12-19
# 	-----------------------------------------
# 	Starting Date: 2021-11-19
# 	Generated energy: 3.56 MWh
# 	Summed Solar Irradiance: 19.9 kWh/mq
# 	Perfomance Ratio: 223.69 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (358/391): 2021-12-20
# 	-----------------------------------------
# 	Starting Date: 2021-11-20
# 	Generated energy: 3.48 MWh
# 	Summed Solar Irradiance: 19.85 kWh/mq
# 	Perfomance Ratio: 218.87 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (359/391): 2021-12-21
# 	-----------------------------------------
# 	Starting Date: 2021-11-21
# 	Generated energy: 3.41 MWh
# 	Summed Solar Irradiance: 19.79 kWh/mq
# 	Perfomance Ratio: 215.25 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (360/391): 2021-12-22
# 	-----------------------------------------
# 	Starting Date: 2021-11-22
# 	Generated energy: 3.46 MWh
# 	Summed Solar Irradiance: 19.78 kWh/mq
# 	Perfomance Ratio: 218.38 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (361/391): 2021-12-23
# 	-----------------------------------------
# 	Starting Date: 2021-11-23
# 	Generated energy: 3.43 MWh
# 	Summed Solar Irradiance: 19.76 kWh/mq
# 	Perfomance Ratio: 217.16 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (362/391): 2021-12-24
# 	-----------------------------------------
# 	Starting Date: 2021-11-24
# 	Generated energy: 3.29 MWh
# 	Summed Solar Irradiance: 19.7 kWh/mq
# 	Perfomance Ratio: 208.78 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (363/391): 2021-12-25
# 	-----------------------------------------
# 	Starting Date: 2021-11-25
# 	Generated energy: 3.15 MWh
# 	Summed Solar Irradiance: 19.63 kWh/mq
# 	Perfomance Ratio: 200.5 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (364/391): 2021-12-26
# 	-----------------------------------------
# 	Starting Date: 2021-11-26
# 	Generated energy: 3.22 MWh
# 	Summed Solar Irradiance: 19.66 kWh/mq
# 	Perfomance Ratio: 204.64 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (365/391): 2021-12-27
# 	-----------------------------------------
# 	Starting Date: 2021-11-27
# 	Generated energy: 3.07 MWh
# 	Summed Solar Irradiance: 19.49 kWh/mq
# 	Perfomance Ratio: 196.73 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (366/391): 2021-12-28
# 	-----------------------------------------
# 	Starting Date: 2021-11-28
# 	Generated energy: 3.01 MWh
# 	Summed Solar Irradiance: 19.46 kWh/mq
# 	Perfomance Ratio: 193.49 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (367/391): 2021-12-29
# 	-----------------------------------------
# 	Starting Date: 2021-11-29
# 	Generated energy: 2.94 MWh
# 	Summed Solar Irradiance: 19.42 kWh/mq
# 	Perfomance Ratio: 189.32 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (368/391): 2021-12-30
# 	-----------------------------------------
# 	Starting Date: 2021-11-30
# 	Generated energy: 2.88 MWh
# 	Summed Solar Irradiance: 19.3 kWh/mq
# 	Perfomance Ratio: 186.55 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (369/391): 2021-12-31
# 	-----------------------------------------
# 	Starting Date: 2021-12-01
# 	Generated energy: 2.74 MWh
# 	Summed Solar Irradiance: 19.23 kWh/mq
# 	Perfomance Ratio: 178.1 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (370/391): 2022-01-01
# 	-----------------------------------------
# 	Starting Date: 2021-12-02
# 	Generated energy: 2.64 MWh
# 	Summed Solar Irradiance: 19.18 kWh/mq
# 	Perfomance Ratio: 171.75 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (371/391): 2022-01-02
# 	-----------------------------------------
# 	Starting Date: 2021-12-03
# 	Generated energy: 2.54 MWh
# 	Summed Solar Irradiance: 19.15 kWh/mq
# 	Perfomance Ratio: 166.1 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (372/391): 2022-01-03
# 	-----------------------------------------
# 	Starting Date: 2021-12-04
# 	Generated energy: 2.41 MWh
# 	Summed Solar Irradiance: 19.09 kWh/mq
# 	Perfomance Ratio: 157.72 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (373/391): 2022-01-04
# 	-----------------------------------------
# 	Starting Date: 2021-12-05
# 	Generated energy: 2.37 MWh
# 	Summed Solar Irradiance: 19.09 kWh/mq
# 	Perfomance Ratio: 154.91 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (374/391): 2022-01-05
# 	-----------------------------------------
# 	Starting Date: 2021-12-06
# 	Generated energy: 2.24 MWh
# 	Summed Solar Irradiance: 19.05 kWh/mq
# 	Perfomance Ratio: 147.24 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (375/391): 2022-01-06
# 	-----------------------------------------
# 	Starting Date: 2021-12-07
# 	Generated energy: 2.19 MWh
# 	Summed Solar Irradiance: 19.04 kWh/mq
# 	Perfomance Ratio: 143.53 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (376/391): 2022-01-07
# 	-----------------------------------------
# 	Starting Date: 2021-12-08
# 	Generated energy: 2.19 MWh
# 	Summed Solar Irradiance: 19.02 kWh/mq
# 	Perfomance Ratio: 143.93 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (377/391): 2022-01-08
# 	-----------------------------------------
# 	Starting Date: 2021-12-09
# 	Generated energy: 2.33 MWh
# 	Summed Solar Irradiance: 19.1 kWh/mq
# 	Perfomance Ratio: 152.69 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (378/391): 2022-01-09
# 	-----------------------------------------
# 	Starting Date: 2021-12-10
# 	Generated energy: 2.42 MWh
# 	Summed Solar Irradiance: 19.15 kWh/mq
# 	Perfomance Ratio: 157.68 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (379/391): 2022-01-10
# 	-----------------------------------------
# 	Starting Date: 2021-12-11
# 	Generated energy: 2.56 MWh
# 	Summed Solar Irradiance: 19.21 kWh/mq
# 	Perfomance Ratio: 166.52 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (380/391): 2022-01-11
# 	-----------------------------------------
# 	Starting Date: 2021-12-12
# 	Generated energy: 2.58 MWh
# 	Summed Solar Irradiance: 19.2 kWh/mq
# 	Perfomance Ratio: 167.68 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (381/391): 2022-01-12
# 	-----------------------------------------
# 	Starting Date: 2021-12-13
# 	Generated energy: 2.6 MWh
# 	Summed Solar Irradiance: 19.19 kWh/mq
# 	Perfomance Ratio: 169.45 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (382/391): 2022-01-13
# 	-----------------------------------------
# 	Starting Date: 2021-12-14
# 	Generated energy: 2.65 MWh
# 	Summed Solar Irradiance: 19.2 kWh/mq
# 	Perfomance Ratio: 172.27 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (383/391): 2022-01-14
# 	-----------------------------------------
# 	Starting Date: 2021-12-15
# 	Generated energy: 2.67 MWh
# 	Summed Solar Irradiance: 19.2 kWh/mq
# 	Perfomance Ratio: 173.79 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (384/391): 2022-01-15
# 	-----------------------------------------
# 	Starting Date: 2021-12-16
# 	Generated energy: 2.67 MWh
# 	Summed Solar Irradiance: 19.18 kWh/mq
# 	Perfomance Ratio: 174.34 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (385/391): 2022-01-16
# 	-----------------------------------------
# 	Starting Date: 2021-12-17
# 	Generated energy: 2.59 MWh
# 	Summed Solar Irradiance: 19.59 kWh/mq
# 	Perfomance Ratio: 165.08 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (386/391): 2022-01-17
# 	-----------------------------------------
# 	Starting Date: 2021-12-18
# 	Generated energy: 2.62 MWh
# 	Summed Solar Irradiance: 22.57 kWh/mq
# 	Perfomance Ratio: 145.0 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (387/391): 2022-01-18
# 	-----------------------------------------
# 	Starting Date: 2021-12-19
# 	Generated energy: 2.65 MWh
# 	Summed Solar Irradiance: 25.42 kWh/mq
# 	Perfomance Ratio: 130.14 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (388/391): 2022-01-19
# 	-----------------------------------------
# 	Starting Date: 2021-12-20
# 	Generated energy: 2.74 MWh
# 	Summed Solar Irradiance: 27.98 kWh/mq
# 	Perfomance Ratio: 122.19 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (389/391): 2022-01-20
# 	-----------------------------------------
# 	Starting Date: 2021-12-21
# 	Generated energy: 2.82 MWh
# 	Summed Solar Irradiance: 30.88 kWh/mq
# 	Perfomance Ratio: 113.95 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (390/391): 2022-01-21
# 	-----------------------------------------
# 	Starting Date: 2021-12-22
# 	Generated energy: 2.94 MWh
# 	Summed Solar Irradiance: 34.09 kWh/mq
# 	Perfomance Ratio: 107.64 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (391/391): 2022-01-22
# 	-----------------------------------------
# 	Starting Date: 2021-12-23
# 	Generated energy: 2.98 MWh
# 	Summed Solar Irradiance: 37.15 kWh/mq
# 	Perfomance Ratio: 100.2 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------

# %% [markdown]
# # E) GRAPH: Performance Ratio (temporal trend)

# %% [markdown]
# ## E.0) Create the saving folder

# %%
system_path = 'data/unige/'
folder_name = "Diagnostic"
saving_path = path.join(system_path, folder_name)

if not path.exists(saving_path):
    makedirs(saving_path)
    print(f"The folder: {'folder_name'} has been created.")
else:
    print(f"The folder '{folder_name}' already exists. That's nice.")
    
subfolders = ["Perfomance Ratio", "Correlation"]
for subfolder in subfolders:
    if not path.exists(path.join(saving_path, subfolder)):
        makedirs(path.join(saving_path, subfolder))
        print(f"The folder: {'subfolder'} has been created.")
    else:
        print(f"The folder '{subfolder}' already exists. That's nice.")
# Out:
# The folder 'Diagnostic' already exists. That's nice.
# The folder 'Perfomance Ratio' already exists. That's nice.
# The folder 'Correlation' already exists. That's nice.

# %% [markdown]
# ## E.1) Save the perfomance ratio

# %%
sub_folder = "Raw scores"
score_folder_path = path.join(saving_path, subfolders[0], sub_folder)

if not path.exists(score_folder_path):
    makedirs(score_folder_path)
    print(f"The folder: '{sub_folder}' has been created.")
else:
    print(f"The folder '{sub_folder}' already exists. That's nice.")
# Out:
# The folder 'Raw scores' already exists. That's nice.

# %%
for inv_name in inv_perfomance_ratio.keys():
    df = inv_perfomance_ratio[inv_name]

    file_name = f"{system_name.replace(' ', '')}_{inv_name.upper()}_perfomanceScores_"\
                f"{str(sliding_window) + 'month' if sliding_window != -1 else 'cumulative'}.csv"
    path_file = path.join(score_folder_path, file_name)
    
    df.to_csv(path_file, index = False)
    print(f"Perfomance ratio scores have been saved as '{file_name}'")

# %% [markdown]
# ## E.2) Plot the historical trend of the 'Perfomance ratio'

# %%
normality_threshold = 70

# %%
n_col = 1
n_row = len(inv_names) // n_col

# Retrieve the sliding window type to create the subtitle of the graphical pane
if sliding_window > 0:
    sub_title = r"$\it{SLIDING WINDOW: " + str(sliding_window) + " month" + ('s' if sliding_window > 1 else '') + r"}$"
    sub_title = sub_title.replace(' ', '\\ ')
else:
    sub_title = 'Cumulative'

# Create the Graphical panel 
fig, axes = plt.subplots(n_row, n_col, figsize= (20 * n_col, 10 * n_row), facecolor = "white")

axes = np.array([axes])

# Figure title
fig.suptitle(f"[{system_name.upper()}] " + r"$\bf{" + "Perfomance Ratio".replace(" ", "\\ ") + "}$", 
             fontsize = 40, color = "dimgray", y = 1.20)
fig.supxlabel(sub_title,  fontsize = 30, color = "dimgray", y = 0.9 if n_row == 2 else 0.952) #y = 

# Generate an historical graph for each inverter
idk_column = 0
idk_row = 0
inv_periods_below_thresholds = dict()

    
# Selecting the sub-graph 
graph = axes[0]

# Generate the graph
period_below_thresholds = diagnostic_utils.generate_historicalGraphs(perfomance_ratio_df, graph, system_name[0], normality_threshold, 
                                                                     plot_moving_average_lines = True, 
                                                                     visualize_under_threshold_period = True)
#inv_periods_below_thresholds[inv_name] = period_below_thresholds
    
    # Increment the row/column counters
#    if idk_column + 1 < axes.shape[1]:
#        idk_column += 1
#    else:
#        idk_column = 0
#        idk_row += 1
        
# Save the graphical panel  (as a png image) 
if sliding_window == -1:
    file_name = f"{system_name.replace(' ', '')}_perfomance_ratio_cumulative.png"
else:
    file_name = f"{system_name.replace(' ', '')}_perfomance_ratio_{sliding_window}month.png"
fig.tight_layout(pad = 4)
fig.savefig(path.join(saving_path, subfolders[0], file_name), bbox_inches='tight', pad_inches = 1)

# Visualize the graphical panel
fig.show()
# Out:
# ------------------------- F -------------------------
# PERIOD 1: FROM '2020-01-31' TO '2020-03-21' (51 days)
# PERIOD 2: FROM '2020-09-14' TO '2020-09-25' (12 days)
# PERIOD 3: FROM '2020-11-03' TO '2020-11-21' (19 days)
# PERIOD 4: FROM '2021-01-13' TO '2021-01-22' (10 days)
# PERIOD 5: FROM '2021-01-25' TO '2021-02-28' (35 days)
# PERIOD 6: FROM '2022-02-11' TO '2022-02-17' (7 days)
# ../_library/diagnostic_utils.py:349: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   perfomance_ratio_values = perfomance_ratio_values.append(new_artificial_data)
# ../_library/diagnostic_utils.py:349: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   perfomance_ratio_values = perfomance_ratio_values.append(new_artificial_data)
# ../_library/diagnostic_utils.py:349: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   perfomance_ratio_values = perfomance_ratio_values.append(new_artificial_data)
# ../_library/diagnostic_utils.py:349: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   perfomance_ratio_values = perfomance_ratio_values.append(new_artificial_data)

# %% [markdown]
# # F) Performance Ratio with temperature correction

# %% [markdown]
# ## F.1) Set Sliding window [months]
# 1. Number of months
# 2. Cumulative [-1]

# %%
sliding_window = 1

# %% [markdown]
# ## F.2) Compute the *daily* Perfomance Ratio with temperature correction using a sliding window

# %%
verbose = False

# %%
inv_perfomance_ratio = dict()

# Isolate the dates
all_df_dates = sorted(set(df.index.date))
print(f"DATE AVAIABLE: {len(all_df_dates)}")
print(f"SELECTED PERIOD: {sliding_window} month(s)\n" +"-" * 40)

#display(df['2019-09-29':].head(50))

daily_perfomance_ratio = dict()
for idk, day in enumerate(all_df_dates):
    module_temp = diagnostic_utils.compute_module_temp(df, all_df_dates, day, sliding_window, verbose = False)
    daily_ratio = diagnostic_utils.compute_perfomance_ratios_temp_correction(df, all_df_dates, day, sliding_window, inverter_nominal_power, beta, module_temp, verbose = False)

    # Try to use the previous KPI value (if available) in case of None value
    if daily_ratio == None:
        prev_day = all_df_dates[idk - 1]

        if str(prev_day) in daily_perfomance_ratio.keys():
            prev_kpi = daily_perfomance_ratio[str(prev_day)]
            daily_ratio = prev_kpi

            #print(f"[FIXED] Replaced the missing value with: {prev_day} "\
                  #f"--> KPI: {round(prev_kpi['Perfomance Ratio (%)'], 2)} %")

    # Save the value only if it's available
    if daily_ratio:
        daily_perfomance_ratio[str(day)] = daily_ratio

# Create and save a dataframe for each inverter
perfomance_ratio_df = pd.DataFrame.from_dict(daily_perfomance_ratio, orient = "index")

# Carry out some transformation
perfomance_ratio_df["Generated energy (kWh)"] = perfomance_ratio_df["Generated energy (kWh)"] / 10 ** 3
perfomance_ratio_df["Summed Solar Irradiance (Wh/mq)"] = perfomance_ratio_df["Summed Solar Irradiance (Wh/mq)"] / 10 ** 3
perfomance_ratio_df.rename(columns = {"Generated energy (kWh)": "Generated energy (MWh)",
                                      "Summed Solar Irradiance (Wh/mq)" : "Summed Solar Irradiance (kWh/mq)"}, 
                           inplace = True)
#display(perfomance_ratio_df)

#x = inv_perfomance_ratio[inv_names[0]].head(50)
#display(x)
# Out:
# DATE AVAIABLE: 835
# SELECTED PERIOD: 1 month(s)
# ----------------------------------------
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour
# ../_library/diagnostic_utils.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_sliding_window["Irradiance (Wh/mq)"] = obs_sliding_window["Irradiance (W/mq)"] * 1 # hour

# %% [markdown]
# ## F.3) Visualize potential problematic ratios

# %%
pr_col_name = "Perfomance Ratio (%)"

# ISSUE: Perfomance Ratio values excedding 100%
cond = perfomance_ratio_df[pr_col_name] > 100
invalid_scores = perfomance_ratio_df.loc[cond, :]
if len(invalid_scores) > 0:
    print(f"ISSUE: There are {len(invalid_scores)} observations ({round((len(invalid_scores)/len(perfomance_ratio_df))*100, 2)} %) "\
          "which have their PERFOMANCE RATIO EXCEEDING 100%\n" + "-" * 96)

    verbose = True
    for idk, outlier_ts in enumerate(invalid_scores.index): #[:50]
        print(f"\n\tOBSERVATION ({idk + 1}/{len(invalid_scores)}): {outlier_ts}\n\t" + "-" * 41)

        observation = invalid_scores.loc[outlier_ts, :]

        if verbose:
            for col_name, value in observation.to_dict().items():
                name_parts = col_name.split("(")
                if len(name_parts) == 2:
                    print(f"\t{name_parts[0].strip()}: {round(value, 2)} {name_parts[1][:-1]}")
                else:
                    print(f"\t{col_name}: {value}")

        # Stat: set it to the maxium value (100%)
        perfomance_ratio_df.loc[outlier_ts, pr_col_name] = 100
        print("\n\t" + "-" * 50 + "\n\tSTRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).\n" 
              + "-" * 50 + "\n")
else:
    print("There aren't observations with thier perfomance ratio exceeding 100%. That's fantastic!\n"\
          f"\nDaily perfomance ratio available: {len(perfomance_ratio_df)} days")
# Out:
# ISSUE: There are 391 observations (48.57 %) which have their PERFOMANCE RATIO EXCEEDING 100%
# ------------------------------------------------------------------------------------------------
#
# 	OBSERVATION (1/391): 2019-12-09
# 	-----------------------------------------
# 	Starting Date: 2019-11-09
# 	Generated energy: 2.67 MWh
# 	Summed Solar Irradiance: 32.18 kWh/mq
# 	Perfomance Ratio: 105.34 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (2/391): 2019-12-10
# 	-----------------------------------------
# 	Starting Date: 2019-11-10
# 	Generated energy: 2.76 MWh
# 	Summed Solar Irradiance: 31.46 kWh/mq
# 	Perfomance Ratio: 110.94 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (3/391): 2019-12-11
# 	-----------------------------------------
# 	Starting Date: 2019-11-11
# 	Generated energy: 2.78 MWh
# 	Summed Solar Irradiance: 30.97 kWh/mq
# 	Perfomance Ratio: 113.83 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (4/391): 2019-12-12
# 	-----------------------------------------
# 	Starting Date: 2019-11-12
# 	Generated energy: 2.91 MWh
# 	Summed Solar Irradiance: 31.14 kWh/mq
# 	Perfomance Ratio: 118.54 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (5/391): 2019-12-13
# 	-----------------------------------------
# 	Starting Date: 2019-11-13
# 	Generated energy: 2.8 MWh
# 	Summed Solar Irradiance: 28.38 kWh/mq
# 	Perfomance Ratio: 124.86 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (6/391): 2019-12-14
# 	-----------------------------------------
# 	Starting Date: 2019-11-14
# 	Generated energy: 2.73 MWh
# 	Summed Solar Irradiance: 27.65 kWh/mq
# 	Perfomance Ratio: 125.14 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (7/391): 2019-12-15
# 	-----------------------------------------
# 	Starting Date: 2019-11-15
# 	Generated energy: 2.7 MWh
# 	Summed Solar Irradiance: 27.3 kWh/mq
# 	Perfomance Ratio: 125.52 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (8/391): 2019-12-16
# 	-----------------------------------------
# 	Starting Date: 2019-11-16
# 	Generated energy: 2.72 MWh
# 	Summed Solar Irradiance: 27.68 kWh/mq
# 	Perfomance Ratio: 124.47 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (9/391): 2019-12-17
# 	-----------------------------------------
# 	Starting Date: 2019-11-17
# 	Generated energy: 2.56 MWh
# 	Summed Solar Irradiance: 25.74 kWh/mq
# 	Perfomance Ratio: 126.27 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (10/391): 2019-12-18
# 	-----------------------------------------
# 	Starting Date: 2019-11-18
# 	Generated energy: 2.52 MWh
# 	Summed Solar Irradiance: 25.96 kWh/mq
# 	Perfomance Ratio: 123.19 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (11/391): 2019-12-19
# 	-----------------------------------------
# 	Starting Date: 2019-11-19
# 	Generated energy: 2.51 MWh
# 	Summed Solar Irradiance: 26.53 kWh/mq
# 	Perfomance Ratio: 120.03 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (12/391): 2019-12-20
# 	-----------------------------------------
# 	Starting Date: 2019-11-20
# 	Generated energy: 2.5 MWh
# 	Summed Solar Irradiance: 27.32 kWh/mq
# 	Perfomance Ratio: 115.65 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (13/391): 2019-12-21
# 	-----------------------------------------
# 	Starting Date: 2019-11-21
# 	Generated energy: 2.55 MWh
# 	Summed Solar Irradiance: 27.34 kWh/mq
# 	Perfomance Ratio: 118.29 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (14/391): 2019-12-22
# 	-----------------------------------------
# 	Starting Date: 2019-11-22
# 	Generated energy: 2.63 MWh
# 	Summed Solar Irradiance: 27.15 kWh/mq
# 	Perfomance Ratio: 122.62 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (15/391): 2019-12-23
# 	-----------------------------------------
# 	Starting Date: 2019-11-23
# 	Generated energy: 2.72 MWh
# 	Summed Solar Irradiance: 27.37 kWh/mq
# 	Perfomance Ratio: 126.0 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (16/391): 2019-12-24
# 	-----------------------------------------
# 	Starting Date: 2019-11-24
# 	Generated energy: 2.86 MWh
# 	Summed Solar Irradiance: 28.4 kWh/mq
# 	Perfomance Ratio: 127.5 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (17/391): 2019-12-25
# 	-----------------------------------------
# 	Starting Date: 2019-11-25
# 	Generated energy: 2.97 MWh
# 	Summed Solar Irradiance: 29.09 kWh/mq
# 	Perfomance Ratio: 129.57 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (18/391): 2019-12-26
# 	-----------------------------------------
# 	Starting Date: 2019-11-26
# 	Generated energy: 2.91 MWh
# 	Summed Solar Irradiance: 27.42 kWh/mq
# 	Perfomance Ratio: 134.64 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (19/391): 2019-12-27
# 	-----------------------------------------
# 	Starting Date: 2019-11-27
# 	Generated energy: 2.94 MWh
# 	Summed Solar Irradiance: 28.11 kWh/mq
# 	Perfomance Ratio: 132.97 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (20/391): 2019-12-28
# 	-----------------------------------------
# 	Starting Date: 2019-11-28
# 	Generated energy: 3.04 MWh
# 	Summed Solar Irradiance: 28.76 kWh/mq
# 	Perfomance Ratio: 134.05 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (21/391): 2019-12-29
# 	-----------------------------------------
# 	Starting Date: 2019-11-29
# 	Generated energy: 3.07 MWh
# 	Summed Solar Irradiance: 29.35 kWh/mq
# 	Perfomance Ratio: 132.84 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (22/391): 2019-12-30
# 	-----------------------------------------
# 	Starting Date: 2019-11-30
# 	Generated energy: 3.06 MWh
# 	Summed Solar Irradiance: 29.69 kWh/mq
# 	Perfomance Ratio: 131.08 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (23/391): 2019-12-31
# 	-----------------------------------------
# 	Starting Date: 2019-12-01
# 	Generated energy: 3.0 MWh
# 	Summed Solar Irradiance: 30.28 kWh/mq
# 	Perfomance Ratio: 126.18 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (24/391): 2020-01-01
# 	-----------------------------------------
# 	Starting Date: 2019-12-02
# 	Generated energy: 3.13 MWh
# 	Summed Solar Irradiance: 30.97 kWh/mq
# 	Perfomance Ratio: 128.79 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (25/391): 2020-01-02
# 	-----------------------------------------
# 	Starting Date: 2019-12-03
# 	Generated energy: 3.13 MWh
# 	Summed Solar Irradiance: 31.45 kWh/mq
# 	Perfomance Ratio: 126.86 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (26/391): 2020-01-03
# 	-----------------------------------------
# 	Starting Date: 2019-12-04
# 	Generated energy: 3.06 MWh
# 	Summed Solar Irradiance: 31.82 kWh/mq
# 	Perfomance Ratio: 122.56 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (27/391): 2020-01-04
# 	-----------------------------------------
# 	Starting Date: 2019-12-05
# 	Generated energy: 3.07 MWh
# 	Summed Solar Irradiance: 32.26 kWh/mq
# 	Perfomance Ratio: 121.5 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (28/391): 2020-01-05
# 	-----------------------------------------
# 	Starting Date: 2019-12-06
# 	Generated energy: 3.14 MWh
# 	Summed Solar Irradiance: 32.73 kWh/mq
# 	Perfomance Ratio: 122.48 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (29/391): 2020-01-06
# 	-----------------------------------------
# 	Starting Date: 2019-12-07
# 	Generated energy: 3.23 MWh
# 	Summed Solar Irradiance: 33.36 kWh/mq
# 	Perfomance Ratio: 123.59 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (30/391): 2020-01-07
# 	-----------------------------------------
# 	Starting Date: 2019-12-08
# 	Generated energy: 3.24 MWh
# 	Summed Solar Irradiance: 34.05 kWh/mq
# 	Perfomance Ratio: 121.19 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (31/391): 2020-01-08
# 	-----------------------------------------
# 	Starting Date: 2019-12-09
# 	Generated energy: 3.28 MWh
# 	Summed Solar Irradiance: 34.5 kWh/mq
# 	Perfomance Ratio: 121.37 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (32/391): 2020-01-09
# 	-----------------------------------------
# 	Starting Date: 2019-12-10
# 	Generated energy: 3.26 MWh
# 	Summed Solar Irradiance: 35.17 kWh/mq
# 	Perfomance Ratio: 118.43 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (33/391): 2020-01-10
# 	-----------------------------------------
# 	Starting Date: 2019-12-11
# 	Generated energy: 3.21 MWh
# 	Summed Solar Irradiance: 35.73 kWh/mq
# 	Perfomance Ratio: 114.67 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (34/391): 2020-01-11
# 	-----------------------------------------
# 	Starting Date: 2019-12-12
# 	Generated energy: 3.27 MWh
# 	Summed Solar Irradiance: 36.08 kWh/mq
# 	Perfomance Ratio: 115.64 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (35/391): 2020-01-12
# 	-----------------------------------------
# 	Starting Date: 2019-12-13
# 	Generated energy: 3.29 MWh
# 	Summed Solar Irradiance: 36.66 kWh/mq
# 	Perfomance Ratio: 114.46 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (36/391): 2020-01-13
# 	-----------------------------------------
# 	Starting Date: 2019-12-14
# 	Generated energy: 3.34 MWh
# 	Summed Solar Irradiance: 37.32 kWh/mq
# 	Perfomance Ratio: 114.31 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (37/391): 2020-01-14
# 	-----------------------------------------
# 	Starting Date: 2019-12-15
# 	Generated energy: 3.23 MWh
# 	Summed Solar Irradiance: 35.18 kWh/mq
# 	Perfomance Ratio: 117.51 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (38/391): 2020-01-15
# 	-----------------------------------------
# 	Starting Date: 2019-12-16
# 	Generated energy: 3.23 MWh
# 	Summed Solar Irradiance: 35.95 kWh/mq
# 	Perfomance Ratio: 114.81 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (39/391): 2020-01-16
# 	-----------------------------------------
# 	Starting Date: 2019-12-17
# 	Generated energy: 3.31 MWh
# 	Summed Solar Irradiance: 36.01 kWh/mq
# 	Perfomance Ratio: 117.58 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (40/391): 2020-01-17
# 	-----------------------------------------
# 	Starting Date: 2019-12-18
# 	Generated energy: 3.33 MWh
# 	Summed Solar Irradiance: 36.13 kWh/mq
# 	Perfomance Ratio: 118.0 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (41/391): 2020-01-18
# 	-----------------------------------------
# 	Starting Date: 2019-12-19
# 	Generated energy: 3.49 MWh
# 	Summed Solar Irradiance: 36.19 kWh/mq
# 	Perfomance Ratio: 123.28 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (42/391): 2020-01-19
# 	-----------------------------------------
# 	Starting Date: 2019-12-20
# 	Generated energy: 3.63 MWh
# 	Summed Solar Irradiance: 36.2 kWh/mq
# 	Perfomance Ratio: 128.33 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (43/391): 2020-01-20
# 	-----------------------------------------
# 	Starting Date: 2019-12-21
# 	Generated energy: 3.78 MWh
# 	Summed Solar Irradiance: 36.09 kWh/mq
# 	Perfomance Ratio: 133.94 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (44/391): 2020-01-21
# 	-----------------------------------------
# 	Starting Date: 2019-12-22
# 	Generated energy: 3.74 MWh
# 	Summed Solar Irradiance: 36.46 kWh/mq
# 	Perfomance Ratio: 131.32 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (45/391): 2020-01-22
# 	-----------------------------------------
# 	Starting Date: 2019-12-23
# 	Generated energy: 3.74 MWh
# 	Summed Solar Irradiance: 37.9 kWh/mq
# 	Perfomance Ratio: 126.12 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (46/391): 2020-01-23
# 	-----------------------------------------
# 	Starting Date: 2019-12-24
# 	Generated energy: 3.76 MWh
# 	Summed Solar Irradiance: 41.27 kWh/mq
# 	Perfomance Ratio: 116.45 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (47/391): 2020-01-24
# 	-----------------------------------------
# 	Starting Date: 2019-12-25
# 	Generated energy: 3.67 MWh
# 	Summed Solar Irradiance: 44.69 kWh/mq
# 	Perfomance Ratio: 104.87 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (48/391): 2020-06-23
# 	-----------------------------------------
# 	Starting Date: 2020-05-24
# 	Generated energy: 10.21 MWh
# 	Summed Solar Irradiance: 118.89 kWh/mq
# 	Perfomance Ratio: 103.44 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (49/391): 2020-06-24
# 	-----------------------------------------
# 	Starting Date: 2020-05-25
# 	Generated energy: 10.21 MWh
# 	Summed Solar Irradiance: 111.48 kWh/mq
# 	Perfomance Ratio: 110.26 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (50/391): 2020-06-25
# 	-----------------------------------------
# 	Starting Date: 2020-05-25
# 	Generated energy: 10.21 MWh
# 	Summed Solar Irradiance: 111.48 kWh/mq
# 	Perfomance Ratio: 110.26 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (51/391): 2020-06-26
# 	-----------------------------------------
# 	Starting Date: 2020-05-27
# 	Generated energy: 10.49 MWh
# 	Summed Solar Irradiance: 104.88 kWh/mq
# 	Perfomance Ratio: 120.35 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (52/391): 2020-06-27
# 	-----------------------------------------
# 	Starting Date: 2020-05-28
# 	Generated energy: 10.52 MWh
# 	Summed Solar Irradiance: 98.34 kWh/mq
# 	Perfomance Ratio: 128.78 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (53/391): 2020-06-28
# 	-----------------------------------------
# 	Starting Date: 2020-05-29
# 	Generated energy: 10.59 MWh
# 	Summed Solar Irradiance: 92.44 kWh/mq
# 	Perfomance Ratio: 137.67 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (54/391): 2020-06-29
# 	-----------------------------------------
# 	Starting Date: 2020-05-30
# 	Generated energy: 10.66 MWh
# 	Summed Solar Irradiance: 88.75 kWh/mq
# 	Perfomance Ratio: 144.25 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (55/391): 2020-06-30
# 	-----------------------------------------
# 	Starting Date: 2020-05-31
# 	Generated energy: 10.49 MWh
# 	Summed Solar Irradiance: 82.02 kWh/mq
# 	Perfomance Ratio: 153.27 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (56/391): 2020-07-01
# 	-----------------------------------------
# 	Starting Date: 2020-06-01
# 	Generated energy: 10.29 MWh
# 	Summed Solar Irradiance: 76.67 kWh/mq
# 	Perfomance Ratio: 160.79 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (57/391): 2020-07-02
# 	-----------------------------------------
# 	Starting Date: 2020-06-02
# 	Generated energy: 10.21 MWh
# 	Summed Solar Irradiance: 69.48 kWh/mq
# 	Perfomance Ratio: 175.98 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (58/391): 2020-07-03
# 	-----------------------------------------
# 	Starting Date: 2020-06-03
# 	Generated energy: 10.15 MWh
# 	Summed Solar Irradiance: 62.29 kWh/mq
# 	Perfomance Ratio: 195.17 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (59/391): 2020-07-04
# 	-----------------------------------------
# 	Starting Date: 2020-06-04
# 	Generated energy: 10.45 MWh
# 	Summed Solar Irradiance: 59.77 kWh/mq
# 	Perfomance Ratio: 209.12 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (60/391): 2020-07-05
# 	-----------------------------------------
# 	Starting Date: 2020-06-05
# 	Generated energy: 10.88 MWh
# 	Summed Solar Irradiance: 59.74 kWh/mq
# 	Perfomance Ratio: 217.78 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (61/391): 2020-07-06
# 	-----------------------------------------
# 	Starting Date: 2020-06-06
# 	Generated energy: 10.83 MWh
# 	Summed Solar Irradiance: 52.84 kWh/mq
# 	Perfomance Ratio: 244.84 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (62/391): 2020-07-07
# 	-----------------------------------------
# 	Starting Date: 2020-06-07
# 	Generated energy: 10.98 MWh
# 	Summed Solar Irradiance: 48.09 kWh/mq
# 	Perfomance Ratio: 272.76 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (63/391): 2020-07-08
# 	-----------------------------------------
# 	Starting Date: 2020-06-08
# 	Generated energy: 11.43 MWh
# 	Summed Solar Irradiance: 47.61 kWh/mq
# 	Perfomance Ratio: 286.64 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (64/391): 2020-07-09
# 	-----------------------------------------
# 	Starting Date: 2020-06-09
# 	Generated energy: 11.51 MWh
# 	Summed Solar Irradiance: 42.33 kWh/mq
# 	Perfomance Ratio: 324.67 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (65/391): 2020-07-10
# 	-----------------------------------------
# 	Starting Date: 2020-06-10
# 	Generated energy: 11.51 MWh
# 	Summed Solar Irradiance: 36.7 kWh/mq
# 	Perfomance Ratio: 374.49 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (66/391): 2020-07-11
# 	-----------------------------------------
# 	Starting Date: 2020-06-11
# 	Generated energy: 11.45 MWh
# 	Summed Solar Irradiance: 33.84 kWh/mq
# 	Perfomance Ratio: 403.83 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (67/391): 2020-07-12
# 	-----------------------------------------
# 	Starting Date: 2020-06-12
# 	Generated energy: 11.77 MWh
# 	Summed Solar Irradiance: 32.28 kWh/mq
# 	Perfomance Ratio: 434.91 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (68/391): 2020-07-13
# 	-----------------------------------------
# 	Starting Date: 2020-06-13
# 	Generated energy: 11.97 MWh
# 	Summed Solar Irradiance: 30.96 kWh/mq
# 	Perfomance Ratio: 460.86 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (69/391): 2020-07-14
# 	-----------------------------------------
# 	Starting Date: 2020-06-14
# 	Generated energy: 12.26 MWh
# 	Summed Solar Irradiance: 31.67 kWh/mq
# 	Perfomance Ratio: 461.05 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (70/391): 2020-07-15
# 	-----------------------------------------
# 	Starting Date: 2020-06-15
# 	Generated energy: 12.15 MWh
# 	Summed Solar Irradiance: 31.16 kWh/mq
# 	Perfomance Ratio: 464.5 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (71/391): 2020-07-16
# 	-----------------------------------------
# 	Starting Date: 2020-06-16
# 	Generated energy: 12.13 MWh
# 	Summed Solar Irradiance: 30.39 kWh/mq
# 	Perfomance Ratio: 475.57 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (72/391): 2020-07-17
# 	-----------------------------------------
# 	Starting Date: 2020-06-17
# 	Generated energy: 12.13 MWh
# 	Summed Solar Irradiance: 30.35 kWh/mq
# 	Perfomance Ratio: 476.23 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (73/391): 2020-07-18
# 	-----------------------------------------
# 	Starting Date: 2020-06-18
# 	Generated energy: 12.12 MWh
# 	Summed Solar Irradiance: 30.98 kWh/mq
# 	Perfomance Ratio: 465.96 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (74/391): 2020-07-19
# 	-----------------------------------------
# 	Starting Date: 2020-06-19
# 	Generated energy: 12.28 MWh
# 	Summed Solar Irradiance: 30.93 kWh/mq
# 	Perfomance Ratio: 472.86 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (75/391): 2020-07-20
# 	-----------------------------------------
# 	Starting Date: 2020-06-20
# 	Generated energy: 12.39 MWh
# 	Summed Solar Irradiance: 30.93 kWh/mq
# 	Perfomance Ratio: 476.66 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (76/391): 2020-07-21
# 	-----------------------------------------
# 	Starting Date: 2020-06-21
# 	Generated energy: 12.14 MWh
# 	Summed Solar Irradiance: 30.91 kWh/mq
# 	Perfomance Ratio: 467.22 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (77/391): 2020-07-22
# 	-----------------------------------------
# 	Starting Date: 2020-06-22
# 	Generated energy: 11.92 MWh
# 	Summed Solar Irradiance: 30.92 kWh/mq
# 	Perfomance Ratio: 458.62 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (78/391): 2020-07-23
# 	-----------------------------------------
# 	Starting Date: 2020-06-23
# 	Generated energy: 11.82 MWh
# 	Summed Solar Irradiance: 28.62 kWh/mq
# 	Perfomance Ratio: 491.69 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (79/391): 2020-07-24
# 	-----------------------------------------
# 	Starting Date: 2020-06-24
# 	Generated energy: 11.53 MWh
# 	Summed Solar Irradiance: 27.95 kWh/mq
# 	Perfomance Ratio: 491.37 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (80/391): 2020-07-25
# 	-----------------------------------------
# 	Starting Date: 2020-06-25
# 	Generated energy: 11.5 MWh
# 	Summed Solar Irradiance: 27.93 kWh/mq
# 	Perfomance Ratio: 490.45 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (81/391): 2020-07-26
# 	-----------------------------------------
# 	Starting Date: 2020-06-26
# 	Generated energy: 11.41 MWh
# 	Summed Solar Irradiance: 27.92 kWh/mq
# 	Perfomance Ratio: 486.8 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (82/391): 2020-07-27
# 	-----------------------------------------
# 	Starting Date: 2020-06-27
# 	Generated energy: 11.45 MWh
# 	Summed Solar Irradiance: 27.81 kWh/mq
# 	Perfomance Ratio: 490.47 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (83/391): 2020-07-28
# 	-----------------------------------------
# 	Starting Date: 2020-06-28
# 	Generated energy: 11.33 MWh
# 	Summed Solar Irradiance: 27.82 kWh/mq
# 	Perfomance Ratio: 485.15 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (84/391): 2020-07-29
# 	-----------------------------------------
# 	Starting Date: 2020-06-29
# 	Generated energy: 11.23 MWh
# 	Summed Solar Irradiance: 27.82 kWh/mq
# 	Perfomance Ratio: 480.71 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (85/391): 2020-07-30
# 	-----------------------------------------
# 	Starting Date: 2020-06-30
# 	Generated energy: 11.34 MWh
# 	Summed Solar Irradiance: 33.54 kWh/mq
# 	Perfomance Ratio: 402.56 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (86/391): 2020-07-31
# 	-----------------------------------------
# 	Starting Date: 2020-07-01
# 	Generated energy: 11.44 MWh
# 	Summed Solar Irradiance: 33.5 kWh/mq
# 	Perfomance Ratio: 406.61 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (87/391): 2020-08-01
# 	-----------------------------------------
# 	Starting Date: 2020-07-02
# 	Generated energy: 11.69 MWh
# 	Summed Solar Irradiance: 33.55 kWh/mq
# 	Perfomance Ratio: 414.44 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (88/391): 2020-08-02
# 	-----------------------------------------
# 	Starting Date: 2020-07-03
# 	Generated energy: 11.72 MWh
# 	Summed Solar Irradiance: 33.83 kWh/mq
# 	Perfomance Ratio: 411.91 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (89/391): 2020-08-03
# 	-----------------------------------------
# 	Starting Date: 2020-07-04
# 	Generated energy: 11.42 MWh
# 	Summed Solar Irradiance: 33.81 kWh/mq
# 	Perfomance Ratio: 401.87 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (90/391): 2020-08-04
# 	-----------------------------------------
# 	Starting Date: 2020-07-05
# 	Generated energy: 11.3 MWh
# 	Summed Solar Irradiance: 33.41 kWh/mq
# 	Perfomance Ratio: 402.43 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (91/391): 2020-08-05
# 	-----------------------------------------
# 	Starting Date: 2020-07-06
# 	Generated energy: 11.29 MWh
# 	Summed Solar Irradiance: 33.55 kWh/mq
# 	Perfomance Ratio: 400.29 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (92/391): 2020-08-06
# 	-----------------------------------------
# 	Starting Date: 2020-07-07
# 	Generated energy: 11.33 MWh
# 	Summed Solar Irradiance: 33.7 kWh/mq
# 	Perfomance Ratio: 399.85 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (93/391): 2020-08-07
# 	-----------------------------------------
# 	Starting Date: 2020-07-08
# 	Generated energy: 11.26 MWh
# 	Summed Solar Irradiance: 35.01 kWh/mq
# 	Perfomance Ratio: 382.38 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (94/391): 2020-08-08
# 	-----------------------------------------
# 	Starting Date: 2020-07-09
# 	Generated energy: 11.23 MWh
# 	Summed Solar Irradiance: 34.92 kWh/mq
# 	Perfomance Ratio: 381.98 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (95/391): 2020-08-09
# 	-----------------------------------------
# 	Starting Date: 2020-07-10
# 	Generated energy: 11.19 MWh
# 	Summed Solar Irradiance: 36.83 kWh/mq
# 	Perfomance Ratio: 360.64 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (96/391): 2020-08-10
# 	-----------------------------------------
# 	Starting Date: 2020-07-11
# 	Generated energy: 11.11 MWh
# 	Summed Solar Irradiance: 36.85 kWh/mq
# 	Perfomance Ratio: 358.06 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (97/391): 2020-08-11
# 	-----------------------------------------
# 	Starting Date: 2020-07-12
# 	Generated energy: 11.31 MWh
# 	Summed Solar Irradiance: 36.84 kWh/mq
# 	Perfomance Ratio: 364.12 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (98/391): 2020-08-12
# 	-----------------------------------------
# 	Starting Date: 2020-07-13
# 	Generated energy: 11.14 MWh
# 	Summed Solar Irradiance: 36.85 kWh/mq
# 	Perfomance Ratio: 358.37 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (99/391): 2020-08-13
# 	-----------------------------------------
# 	Starting Date: 2020-07-14
# 	Generated energy: 11.01 MWh
# 	Summed Solar Irradiance: 36.39 kWh/mq
# 	Perfomance Ratio: 358.58 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (100/391): 2020-08-14
# 	-----------------------------------------
# 	Starting Date: 2020-07-15
# 	Generated energy: 10.98 MWh
# 	Summed Solar Irradiance: 35.25 kWh/mq
# 	Perfomance Ratio: 369.18 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (101/391): 2020-08-15
# 	-----------------------------------------
# 	Starting Date: 2020-07-16
# 	Generated energy: 11.03 MWh
# 	Summed Solar Irradiance: 40.57 kWh/mq
# 	Perfomance Ratio: 322.29 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (102/391): 2020-08-16
# 	-----------------------------------------
# 	Starting Date: 2020-07-17
# 	Generated energy: 10.91 MWh
# 	Summed Solar Irradiance: 44.54 kWh/mq
# 	Perfomance Ratio: 290.18 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (103/391): 2020-08-17
# 	-----------------------------------------
# 	Starting Date: 2020-07-18
# 	Generated energy: 10.71 MWh
# 	Summed Solar Irradiance: 43.48 kWh/mq
# 	Perfomance Ratio: 291.74 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (104/391): 2020-08-18
# 	-----------------------------------------
# 	Starting Date: 2020-07-19
# 	Generated energy: 10.52 MWh
# 	Summed Solar Irradiance: 41.88 kWh/mq
# 	Perfomance Ratio: 297.38 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (105/391): 2020-08-19
# 	-----------------------------------------
# 	Starting Date: 2020-07-20
# 	Generated energy: 10.46 MWh
# 	Summed Solar Irradiance: 48.44 kWh/mq
# 	Perfomance Ratio: 255.49 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (106/391): 2020-08-20
# 	-----------------------------------------
# 	Starting Date: 2020-07-21
# 	Generated energy: 10.41 MWh
# 	Summed Solar Irradiance: 55.11 kWh/mq
# 	Perfomance Ratio: 223.58 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (107/391): 2020-08-21
# 	-----------------------------------------
# 	Starting Date: 2020-07-22
# 	Generated energy: 10.58 MWh
# 	Summed Solar Irradiance: 61.95 kWh/mq
# 	Perfomance Ratio: 202.11 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (108/391): 2020-08-22
# 	-----------------------------------------
# 	Starting Date: 2020-07-23
# 	Generated energy: 10.7 MWh
# 	Summed Solar Irradiance: 67.99 kWh/mq
# 	Perfomance Ratio: 186.12 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (109/391): 2020-08-23
# 	-----------------------------------------
# 	Starting Date: 2020-07-24
# 	Generated energy: 10.7 MWh
# 	Summed Solar Irradiance: 74.38 kWh/mq
# 	Perfomance Ratio: 170.06 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (110/391): 2020-08-24
# 	-----------------------------------------
# 	Starting Date: 2020-07-25
# 	Generated energy: 10.82 MWh
# 	Summed Solar Irradiance: 78.85 kWh/mq
# 	Perfomance Ratio: 162.24 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (111/391): 2020-08-25
# 	-----------------------------------------
# 	Starting Date: 2020-07-26
# 	Generated energy: 10.76 MWh
# 	Summed Solar Irradiance: 85.45 kWh/mq
# 	Perfomance Ratio: 148.88 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (112/391): 2020-08-26
# 	-----------------------------------------
# 	Starting Date: 2020-07-27
# 	Generated energy: 10.82 MWh
# 	Summed Solar Irradiance: 91.38 kWh/mq
# 	Perfomance Ratio: 139.98 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (113/391): 2020-08-27
# 	-----------------------------------------
# 	Starting Date: 2020-07-28
# 	Generated energy: 10.76 MWh
# 	Summed Solar Irradiance: 97.63 kWh/mq
# 	Perfomance Ratio: 130.28 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (114/391): 2020-08-28
# 	-----------------------------------------
# 	Starting Date: 2020-07-29
# 	Generated energy: 10.61 MWh
# 	Summed Solar Irradiance: 99.41 kWh/mq
# 	Perfomance Ratio: 126.21 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (115/391): 2020-08-29
# 	-----------------------------------------
# 	Starting Date: 2020-07-30
# 	Generated energy: 10.48 MWh
# 	Summed Solar Irradiance: 102.94 kWh/mq
# 	Perfomance Ratio: 120.42 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (116/391): 2020-08-30
# 	-----------------------------------------
# 	Starting Date: 2020-07-31
# 	Generated energy: 10.46 MWh
# 	Summed Solar Irradiance: 103.46 kWh/mq
# 	Perfomance Ratio: 119.58 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (117/391): 2020-08-31
# 	-----------------------------------------
# 	Starting Date: 2020-08-01
# 	Generated energy: 10.28 MWh
# 	Summed Solar Irradiance: 107.0 kWh/mq
# 	Perfomance Ratio: 113.76 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (118/391): 2020-09-01
# 	-----------------------------------------
# 	Starting Date: 2020-08-02
# 	Generated energy: 10.21 MWh
# 	Summed Solar Irradiance: 112.45 kWh/mq
# 	Perfomance Ratio: 107.54 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (119/391): 2020-09-02
# 	-----------------------------------------
# 	Starting Date: 2020-08-03
# 	Generated energy: 10.1 MWh
# 	Summed Solar Irradiance: 116.88 kWh/mq
# 	Perfomance Ratio: 102.43 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (120/391): 2020-12-04
# 	-----------------------------------------
# 	Starting Date: 2020-11-04
# 	Generated energy: 3.6 MWh
# ...
# 	-----------------------------------------
# 	Starting Date: 2021-11-15
# 	Generated energy: 3.45 MWh
# 	Summed Solar Irradiance: 19.91 kWh/mq
# 	Perfomance Ratio: 218.79 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (353/391): 2021-12-16
# 	-----------------------------------------
# 	Starting Date: 2021-11-16
# 	Generated energy: 3.58 MWh
# 	Summed Solar Irradiance: 19.95 kWh/mq
# 	Perfomance Ratio: 226.5 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (354/391): 2021-12-17
# 	-----------------------------------------
# 	Starting Date: 2021-11-17
# 	Generated energy: 3.61 MWh
# 	Summed Solar Irradiance: 19.95 kWh/mq
# 	Perfomance Ratio: 228.18 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (355/391): 2021-12-18
# 	-----------------------------------------
# 	Starting Date: 2021-11-18
# 	Generated energy: 3.67 MWh
# 	Summed Solar Irradiance: 19.96 kWh/mq
# 	Perfomance Ratio: 231.62 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (356/391): 2021-12-19
# 	-----------------------------------------
# 	Starting Date: 2021-11-19
# 	Generated energy: 3.56 MWh
# 	Summed Solar Irradiance: 19.9 kWh/mq
# 	Perfomance Ratio: 225.73 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (357/391): 2021-12-20
# 	-----------------------------------------
# 	Starting Date: 2021-11-20
# 	Generated energy: 3.48 MWh
# 	Summed Solar Irradiance: 19.85 kWh/mq
# 	Perfomance Ratio: 221.02 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (358/391): 2021-12-21
# 	-----------------------------------------
# 	Starting Date: 2021-11-21
# 	Generated energy: 3.41 MWh
# 	Summed Solar Irradiance: 19.79 kWh/mq
# 	Perfomance Ratio: 217.64 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (359/391): 2021-12-22
# 	-----------------------------------------
# 	Starting Date: 2021-11-22
# 	Generated energy: 3.46 MWh
# 	Summed Solar Irradiance: 19.78 kWh/mq
# 	Perfomance Ratio: 220.91 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (360/391): 2021-12-23
# 	-----------------------------------------
# 	Starting Date: 2021-11-23
# 	Generated energy: 3.43 MWh
# 	Summed Solar Irradiance: 19.76 kWh/mq
# 	Perfomance Ratio: 219.68 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (361/391): 2021-12-24
# 	-----------------------------------------
# 	Starting Date: 2021-11-24
# 	Generated energy: 3.29 MWh
# 	Summed Solar Irradiance: 19.7 kWh/mq
# 	Perfomance Ratio: 211.19 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (362/391): 2021-12-25
# 	-----------------------------------------
# 	Starting Date: 2021-11-25
# 	Generated energy: 3.15 MWh
# 	Summed Solar Irradiance: 19.63 kWh/mq
# 	Perfomance Ratio: 202.82 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (363/391): 2021-12-26
# 	-----------------------------------------
# 	Starting Date: 2021-11-26
# 	Generated energy: 3.22 MWh
# 	Summed Solar Irradiance: 19.66 kWh/mq
# 	Perfomance Ratio: 207.03 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (364/391): 2021-12-27
# 	-----------------------------------------
# 	Starting Date: 2021-11-27
# 	Generated energy: 3.07 MWh
# 	Summed Solar Irradiance: 19.49 kWh/mq
# 	Perfomance Ratio: 199.19 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (365/391): 2021-12-28
# 	-----------------------------------------
# 	Starting Date: 2021-11-28
# 	Generated energy: 3.01 MWh
# 	Summed Solar Irradiance: 19.46 kWh/mq
# 	Perfomance Ratio: 196.0 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (366/391): 2021-12-29
# 	-----------------------------------------
# 	Starting Date: 2021-11-29
# 	Generated energy: 2.94 MWh
# 	Summed Solar Irradiance: 19.42 kWh/mq
# 	Perfomance Ratio: 191.72 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (367/391): 2021-12-30
# 	-----------------------------------------
# 	Starting Date: 2021-11-30
# 	Generated energy: 2.88 MWh
# 	Summed Solar Irradiance: 19.3 kWh/mq
# 	Perfomance Ratio: 188.87 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (368/391): 2021-12-31
# 	-----------------------------------------
# 	Starting Date: 2021-12-01
# 	Generated energy: 2.74 MWh
# 	Summed Solar Irradiance: 19.23 kWh/mq
# 	Perfomance Ratio: 180.42 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (369/391): 2022-01-01
# 	-----------------------------------------
# 	Starting Date: 2021-12-02
# 	Generated energy: 2.64 MWh
# 	Summed Solar Irradiance: 19.18 kWh/mq
# 	Perfomance Ratio: 174.04 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (370/391): 2022-01-02
# 	-----------------------------------------
# 	Starting Date: 2021-12-03
# 	Generated energy: 2.54 MWh
# 	Summed Solar Irradiance: 19.15 kWh/mq
# 	Perfomance Ratio: 168.25 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (371/391): 2022-01-03
# 	-----------------------------------------
# 	Starting Date: 2021-12-04
# 	Generated energy: 2.41 MWh
# 	Summed Solar Irradiance: 19.09 kWh/mq
# 	Perfomance Ratio: 159.78 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (372/391): 2022-01-04
# 	-----------------------------------------
# 	Starting Date: 2021-12-05
# 	Generated energy: 2.37 MWh
# 	Summed Solar Irradiance: 19.09 kWh/mq
# 	Perfomance Ratio: 156.86 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (373/391): 2022-01-05
# 	-----------------------------------------
# 	Starting Date: 2021-12-06
# 	Generated energy: 2.24 MWh
# 	Summed Solar Irradiance: 19.05 kWh/mq
# 	Perfomance Ratio: 149.1 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (374/391): 2022-01-06
# 	-----------------------------------------
# 	Starting Date: 2021-12-07
# 	Generated energy: 2.19 MWh
# 	Summed Solar Irradiance: 19.04 kWh/mq
# 	Perfomance Ratio: 145.36 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (375/391): 2022-01-07
# 	-----------------------------------------
# 	Starting Date: 2021-12-08
# 	Generated energy: 2.19 MWh
# 	Summed Solar Irradiance: 19.02 kWh/mq
# 	Perfomance Ratio: 145.93 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (376/391): 2022-01-08
# 	-----------------------------------------
# 	Starting Date: 2021-12-09
# 	Generated energy: 2.33 MWh
# 	Summed Solar Irradiance: 19.1 kWh/mq
# 	Perfomance Ratio: 154.78 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (377/391): 2022-01-09
# 	-----------------------------------------
# 	Starting Date: 2021-12-10
# 	Generated energy: 2.42 MWh
# 	Summed Solar Irradiance: 19.15 kWh/mq
# 	Perfomance Ratio: 159.8 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (378/391): 2022-01-10
# 	-----------------------------------------
# 	Starting Date: 2021-12-11
# 	Generated energy: 2.56 MWh
# 	Summed Solar Irradiance: 19.21 kWh/mq
# 	Perfomance Ratio: 168.82 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (379/391): 2022-01-11
# 	-----------------------------------------
# 	Starting Date: 2021-12-12
# 	Generated energy: 2.58 MWh
# 	Summed Solar Irradiance: 19.2 kWh/mq
# 	Perfomance Ratio: 170.07 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (380/391): 2022-01-12
# 	-----------------------------------------
# 	Starting Date: 2021-12-13
# 	Generated energy: 2.6 MWh
# 	Summed Solar Irradiance: 19.19 kWh/mq
# 	Perfomance Ratio: 172.08 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (381/391): 2022-01-13
# 	-----------------------------------------
# 	Starting Date: 2021-12-14
# 	Generated energy: 2.65 MWh
# 	Summed Solar Irradiance: 19.2 kWh/mq
# 	Perfomance Ratio: 175.12 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (382/391): 2022-01-14
# 	-----------------------------------------
# 	Starting Date: 2021-12-15
# 	Generated energy: 2.67 MWh
# 	Summed Solar Irradiance: 19.2 kWh/mq
# 	Perfomance Ratio: 176.59 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (383/391): 2022-01-15
# 	-----------------------------------------
# 	Starting Date: 2021-12-16
# 	Generated energy: 2.67 MWh
# 	Summed Solar Irradiance: 19.18 kWh/mq
# 	Perfomance Ratio: 177.08 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (384/391): 2022-01-16
# 	-----------------------------------------
# 	Starting Date: 2021-12-17
# 	Generated energy: 2.59 MWh
# 	Summed Solar Irradiance: 19.59 kWh/mq
# 	Perfomance Ratio: 167.75 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (385/391): 2022-01-17
# 	-----------------------------------------
# 	Starting Date: 2021-12-18
# 	Generated energy: 2.62 MWh
# 	Summed Solar Irradiance: 22.57 kWh/mq
# 	Perfomance Ratio: 147.26 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (386/391): 2022-01-18
# 	-----------------------------------------
# 	Starting Date: 2021-12-19
# 	Generated energy: 2.65 MWh
# 	Summed Solar Irradiance: 25.42 kWh/mq
# 	Perfomance Ratio: 132.05 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (387/391): 2022-01-19
# 	-----------------------------------------
# 	Starting Date: 2021-12-20
# 	Generated energy: 2.74 MWh
# 	Summed Solar Irradiance: 27.98 kWh/mq
# 	Perfomance Ratio: 123.95 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (388/391): 2022-01-20
# 	-----------------------------------------
# 	Starting Date: 2021-12-21
# 	Generated energy: 2.82 MWh
# 	Summed Solar Irradiance: 30.88 kWh/mq
# 	Perfomance Ratio: 115.53 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (389/391): 2022-01-21
# 	-----------------------------------------
# 	Starting Date: 2021-12-22
# 	Generated energy: 2.94 MWh
# 	Summed Solar Irradiance: 34.09 kWh/mq
# 	Perfomance Ratio: 109.08 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (390/391): 2022-01-22
# 	-----------------------------------------
# 	Starting Date: 2021-12-23
# 	Generated energy: 2.98 MWh
# 	Summed Solar Irradiance: 37.15 kWh/mq
# 	Perfomance Ratio: 101.43 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------
#
#
# 	OBSERVATION (391/391): 2022-01-23
# 	-----------------------------------------
# 	Starting Date: 2021-12-24
# 	Generated energy: 3.04 MWh
# 	Summed Solar Irradiance: 38.42 kWh/mq
# 	Perfomance Ratio: 100.19 %
# 	Sliding window: 1 months
#
# 	--------------------------------------------------
# 	STRAT: Setting this outliert to theorethical maxiumum (i.e., 100%).
# --------------------------------------------------

# %% [markdown]
# # G) GRAPH: Performance Ratio with temperature correction (temporal trend)

# %% [markdown]
# ## G.0) Create the saving folder

# %%
system_path = 'data/unige/'
folder_name = "Diagnostic"
saving_path = path.join(system_path, folder_name)

if not path.exists(saving_path):
    makedirs(saving_path)
    print(f"The folder: {'folder_name'} has been created.")
else:
    print(f"The folder '{folder_name}' already exists. That's nice.")
    
subfolders = ["Perfomance Ratio with temperature correction", "Correlation"]
for subfolder in subfolders:
    if not path.exists(path.join(saving_path, subfolder)):
        makedirs(path.join(saving_path, subfolder))
        print(f"The folder: {'subfolder'} has been created.")
    else:
        print(f"The folder '{subfolder}' already exists. That's nice.")
# Out:
# The folder 'Diagnostic' already exists. That's nice.
# The folder 'Perfomance Ratio with temperature correction' already exists. That's nice.
# The folder 'Correlation' already exists. That's nice.

# %% [markdown]
# ## G.1) Save the performance ratio with temperature correction

# %%
sub_folder = "Raw scores"
score_folder_path = path.join(saving_path, subfolders[0], sub_folder)
    
if not path.exists(score_folder_path):
    makedirs(score_folder_path)
    print(f"The folder: '{sub_folder}' has been created.")
else:
    print(f"The folder '{sub_folder}' already exists. That's nice.")
# Out:
# The folder 'Raw scores' already exists. That's nice.

# %%
for inv_name in inv_perfomance_ratio.keys():
    df = inv_perfomance_ratio[inv_name]

    file_name = f"{system_name.replace(' ', '')}_{inv_name.upper()}_perfomanceScores_"\
                f"{str(sliding_window) + 'month' if sliding_window != -1 else 'cumulative'}.csv"
    path_file = path.join(score_folder_path, file_name)
    
    df.to_csv(path_file, index = False)
    print(f"Perfomance ratio scores have been saved as '{file_name}'")

# %% [markdown]
# ## G.2) Plot the historical trend of the 'Perfomance ratio with temperature correction'

# %%
normality_threshold = 70

# %%
n_col = 1
n_row = len(inv_names) // n_col

# Retrieve the sliding window type to create the subtitle of the graphical pane
if sliding_window > 0:
    sub_title = r"$\it{SLIDING WINDOW: " + str(sliding_window) + " month" + ('s' if sliding_window > 1 else '') + r"}$"
    sub_title = sub_title.replace(' ', '\\ ')
else:
    sub_title = 'Cumulative'

# Create the Graphical panel 
fig, axes = plt.subplots(n_row, n_col, figsize= (20 * n_col, 5 * n_row), facecolor = "white")

axes = np.array([axes])

# Figure title
fig.suptitle(f"[{system_name.upper()}] " + r"$\bf{" + "Perfomance Ratio with temperature correction".replace(" ", "\\ ") + "}$", 
             fontsize = 40, color = "dimgray", y = 1.20)
fig.supxlabel(sub_title,  fontsize = 30, color = "dimgray", y = 0.9 if n_row == 2 else 0.952) #y = 

# Generate an historical graph for each inverter
idk_column = 0
idk_row = 0
inv_periods_below_thresholds = dict()

    
# Selecting the sub-graph 
graph = axes[0]

# Generate the graph
period_below_thresholds = diagnostic_utils.generate_historicalGraphs(perfomance_ratio_df, graph, 'FV', normality_threshold, 
                                                                     plot_moving_average_lines = True, 
                                                                     visualize_under_threshold_period = True)
#inv_periods_below_thresholds[inv_name] = period_below_thresholds
    
    # Increment the row/column counters
#    if idk_column + 1 < axes.shape[1]:
#        idk_column += 1
#    else:
#        idk_column = 0
#        idk_row += 1
        
# Save the graphical panel  (as a png image) 
if sliding_window == -1:
    file_name = f"{system_name.replace(' ', '')}_perfomance_ratio_with_temperature_correction_cumulative.png"
else:
    file_name = f"{system_name.replace(' ', '')}_perfomance_ratio_with_temperature_correction_{sliding_window}month.png"
fig.tight_layout(pad = 0.5)
fig.savefig(path.join(saving_path, subfolders[0], file_name), bbox_inches='tight', pad_inches = 1)

# Visualize the graphical panel
fig.show()
# Out:
# ../_library/diagnostic_utils.py:349: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   perfomance_ratio_values = perfomance_ratio_values.append(new_artificial_data)
# ../_library/diagnostic_utils.py:349: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   perfomance_ratio_values = perfomance_ratio_values.append(new_artificial_data)
# ../_library/diagnostic_utils.py:349: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   perfomance_ratio_values = perfomance_ratio_values.append(new_artificial_data)
# ../_library/diagnostic_utils.py:349: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   perfomance_ratio_values = perfomance_ratio_values.append(new_artificial_data)
# ------------------------- FV -------------------------
# PERIOD 1: FROM '2020-01-31' TO '2020-03-22' (52 days)
# PERIOD 2: FROM '2020-05-24' TO '2020-06-04' (12 days)
# PERIOD 3: FROM '2020-06-07' TO '2020-06-09' (3 days)
# PERIOD 4: FROM '2020-09-13' TO '2020-09-26' (14 days)
# PERIOD 5: FROM '2020-11-01' TO '2020-11-21' (21 days)
# PERIOD 6: FROM '2021-01-13' TO '2021-01-19' (7 days)
# PERIOD 7: FROM '2021-01-26' TO '2021-02-26' (32 days)
# PERIOD 8: FROM '2022-02-11' TO '2022-02-17' (7 days)
