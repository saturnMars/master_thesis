# %%
from sys import path
if '../..' not in path:
    path.insert(0, '../..')

# %%
from os import path, makedirs
from _library.utils import SYSTEM_NAMES_FULL, load_datasets
from scipy.stats import zscore
from IPython.display import clear_output
import numpy as np
import pandas as pd

# %%
# Select the main folder 
# %cd /mnt/data/vieri/projects/SAMPLE/

# Visualize names of PV systems
print(SYSTEM_NAMES_FULL)
# --- 0 ---------- 1 --------- 2 ------ 3 ------ 4 --------- 5 --------- 6 -------- 7 ---
# Out:
# /mnt/data/vieri/projects/SAMPLE
# ['Binetto 1', 'Binetto 2', 'Cantore', 'Emi', 'Soleto 1', 'Soleto 2', 'Galatina', 'Verone']

# %% [markdown]
# # Selecting the PV system

# %%
system_name = SYSTEM_NAMES_FULL[4]
print("PV SYSTEM --> ", system_name)
# Out:
# PV SYSTEM -->  Soleto 1

# %% [markdown]
# # Loading dataset

# %%
# Loading the datasets
path_file, inv_data, inv_names, raw_irr_data, string_inv_data, string_inv_names = load_datasets(system_name, verbose=True)
# Out:
# --------------------------------------------------------------------------------
# 				PV SYSTEM --> SOLETO 1
# --------------------------------------------------------------------------------
#
# Loading inverter data...
# SOLETO 1: OK, component data loaded (4) --> INV1, INV2, INV3, INV4
#
# Loading irradiance values...
# SOLETO 1: OK, raw irradiance data (234304 observations) have been loaded
#
# --------------------------------------------------------------------------------
# FINISHED!: All datasets have been loaded. (SYS: 4 - IRR FILE: 1)
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# EXAMPLE --> Soleto 1: INV1 (FROM '2018-08-08' TO '2021-06-30': 1057 days).
# --------------------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146605 entries, 0 to 146604
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Date/Time            146605 non-null  datetime64[ns]
#  1   Iac R (A)            146605 non-null  int64
#  2   Iac S (A)            146605 non-null  int64
#  3   Iac T (A)            146605 non-null  int64
#  4   Vac R (V)            146605 non-null  int64
#  5   Vac S (V)            146605 non-null  int64
#  6   Vac T (V)            146605 non-null  int64
#  7   Pac R (kW)           146605 non-null  int64
#  8   Pac S (kW)           0 non-null       float64
#  9   Pac T (kW)           0 non-null       float64
#  10  E. totale (kWh)      146605 non-null  float64
#  11  Cc 1 (A)             146605 non-null  int64
#  12  Vcc 1 (V)            146605 non-null  int64
#  13  Allarme              146605 non-null  string
#  14  Stato                0 non-null       float64
#  15  Inverter temp. (°C)  146605 non-null  int64
#  16  Fac (Hz)             0 non-null       float64
#  17  Irr. medio (W/mq)    125184 non-null  float64
# dtypes: datetime64[ns](1), float64(6), int64(10), string(1)
# memory usage: 20.1 MB

# %% [markdown]
# # Exploration

# %%
# TASK (EXPLORE): Carry out some descriptive statistics on problematic columns (i.e., those identified through numerical and temporal distribution graphs)
to_load = inv_names[0]

# Check numerical distribution via some descriptive statistics (mean, IQR, etc)
check_emptiness = ["Pac S (kW)", "Pac T (kW)", "Stato", "Fac (Hz)"] 
varibles_to_analyse = ["Irr. medio (W/mq)", "Inverter temp. (°C)"]
for var in [check_emptiness + varibles_to_analyse]:
    print(inv_data[to_load][var].describe(), "\n")

# Quick check at the invalid temperature values (above the likely physical limit)
valid_temperature = 200 # °C
valid_tempValue = inv_data[to_load].loc[inv_data[to_load]["Inverter temp. (°C)"] <= valid_temperature, :]
print(f"VALID TEMP. VALUE: {len(valid_tempValue)} ({round((len(valid_tempValue)/len(inv_data[to_load]['Inverter temp. (°C)']))*100, 2)}%)")

# FINDINGS: 
# 1) "Pac S (kW)", "Pac T (kW)", "Stato", "Fac (Hz)" --> OK: 0 valid values --> They can be discarded
# 2) Irr. medio --> it seems okay (mean, std, IQR, min, max)
# 3) Inverter temp [°C] --> Strange 
#   --->  mean: 1064, std: 8223, IQR: 11-21, max = 65535
#   ---> value above 1000 should be analyse
# Out:
#        Pac S (kW)  Pac T (kW)  Stato  Fac (Hz)  Irr. medio (W/mq)  \
# count         0.0         0.0    0.0       0.0      125184.000000
# mean          NaN         NaN    NaN       NaN         306.464061
# std           NaN         NaN    NaN       NaN         371.583198
# min           NaN         NaN    NaN       NaN           4.000000
# 25%           NaN         NaN    NaN       NaN          33.000000
# 50%           NaN         NaN    NaN       NaN         121.000000
# 75%           NaN         NaN    NaN       NaN         578.000000
# max           NaN         NaN    NaN       NaN        5040.000000
#
#        Inverter temp. (°C)
# count        146605.000000
# mean             41.598738
# std            1121.816403
# min               1.000000
# 25%              17.000000
# 50%              21.000000
# 75%              29.000000
# max           65535.000000
#
# VALID TEMP. VALUE: 146562 (99.97%)

# %%
# TASK (EXPLORE): Check whather a type converstion is necessary?
# VARIABLE: Irr. medio (W/mq) --> From 'float64' to int64
irr_values = inv_data[to_load]["Irr. medio (W/mq)"]
non_integer = [value for value in irr_values if not value.is_integer()]
non_nanInteger = [value for value in non_integer if not np.isnan(value)]
print("Number of non integer values (that are not NaN values):", len(non_nanInteger))

# Check its validity 
integer_irr_values = pd.array(irr_values, dtype="Int64")
diff = np.abs(irr_values - integer_irr_values)
diff.dropna(inplace = True)
mean = np.mean(diff)
std = np.std(diff)
print(f"\nCASTING to Int64: Compute difference to check validity.\nMEAN (diff): {mean}, STD (diff):{std}")

# FINDIGS: Irradiance values are all integer values, but the empty values (numpy NaN) was forcing the column to be a float number
# Out:
# Number of non integer values (that are not NaN values): 0
#
# CASTING to Int64: Compute difference to check validity.
# MEAN (diff): 0.0, STD (diff):0.0

# %% [markdown]
# # fix uniqueness of the datetimes

# %%
# Check uniqueness --> Date/time
def check_datetime_uniqueness():
    index_to_delate = dict()
    
    for inv_name in inv_names:
        df = inv_data[inv_name]
        print(f"\nAnalysing {inv_name}...")
        
        if set(check_emptiness).issubset(df.columns):
            df = df.drop(columns = ["Irr. medio (W/mq)"] + check_emptiness)

        # Check duplicates
        condition = df["Date/Time"].duplicated(keep=False)
        duplicated_datetime = df[condition]
        
        # Continue to analyse other inverter in case of no duplicated observations
        if len(duplicated_datetime) == 0:
            print(f"Oh, that's good. No duplicated observations have been found for {inv_name}!")
            continue
        
        # Extraxct unique datetimes
        unique_duplicated_dt = [pd.to_datetime(datetime) for datetime in duplicated_datetime["Date/Time"].unique()]
        print(f"DUPLICATE DATES: {len(unique_duplicated_dt)}: {[dt.strftime('%Y-%m-%d, %H:%M') for dt in unique_duplicated_dt]} "\
              f"(Total observations: {len(duplicated_datetime)})")
        #display(duplicated_datetime)

        # Investigate to this behaviour for a duplicate observations
        datetime_to_investigate = unique_duplicated_dt[0]
        delta = pd.Timedelta(15, unit="minutes") #datetime.timedelta(minutes=60)
        period = (datetime_to_investigate - delta, datetime_to_investigate + delta)
        #display(df.loc[df["Date/Time"].between(period[0], period[1]), :])

        # Compute difference 
        to_discard = set()
        for datetime in unique_duplicated_dt:
            daily_duplicated_indexes = df[df["Date/Time"] == datetime].index
            duplicated_obs = df.loc[daily_duplicated_indexes, :].drop(columns = "Date/Time")
            obs = pd.Series()
            
            daily_duplicated_indexes
            
            if len(unique_duplicated_dt) > 300:
                clear_output(wait=True)
            print(f"\nAnalysing {datetime} - (observations: {len(daily_duplicated_indexes)})")
            print("-"*120)
            
            equal_observations = set()
            for idk_check, index_obs in enumerate(daily_duplicated_indexes):
                
                other_duplicated_obs = duplicated_obs.drop(index_obs, axis=0)

                check = duplicated_obs.loc[index_obs,:].eq(other_duplicated_obs)
                find_equal_obs = check.all(axis=1)[check.all(axis=1) == True].index.tolist()

                print(f"--> Analysing idk: {index_obs}...")                
                if find_equal_obs:
                    print(f"    Equal observation(s) have been found: {find_equal_obs}")
                    idk_equal_obs = [index_obs] + [idk for idk in find_equal_obs]
                    idk_equal_obs.sort()
                    
                    #display(duplicated_obs.loc[idk_equal_obs, :])
                    #idk_equal_obs = [idk for idk in find_equal_obs]

                    # Save pairs of equal duplicated observations
                    equal_observations.add(tuple(idk_equal_obs))
   
            # Keep the first equal and discard the other equal observations
            duplicated_diff_obs = sorted([obs_to_discard for pairs in equal_observations for obs_to_discard in pairs[1:]])
            
            if len(duplicated_diff_obs) != 0:
                to_discard.update(duplicated_diff_obs)
                print("\n--> OK, discarding the identical observations: ", duplicated_diff_obs)
            else:
                print("No equal observations have been found")
        
            # Highlight potential issues: same timestamp not equal values
            remaining_duplicated_obs = sorted(set(daily_duplicated_indexes) - set(duplicated_diff_obs))
            
            if len(remaining_duplicated_obs) > 1:
                print(f"\n--> Issue, duplicated observations with different values have been found! --> {remaining_duplicated_obs}")
                
                mean_deltas = []
                to_discard_strat_2 = []
                for idk_observation in remaining_duplicated_obs:
                    print(f"    FOCUSING ON IDK: {idk_observation}")

                    # Compute the idk of previous and upcoming observations
                    prev_idk = idk_observation - 1
                    if prev_idk in daily_duplicated_indexes:
                        prev_idk = idk_observation - len(duplicated_diff_obs) - 1 
      
                    upcom_idk = idk_observation + 1
                    if upcom_idk in daily_duplicated_indexes:
                        upcom_idk = idk_observation + len(duplicated_diff_obs) + 1

                    # Compute previous and upcoming observations
                    obs_kwh = df.loc[idk_observation, :]["E. totale (kWh)"]
                    prev = df.loc[prev_idk, :]["E. totale (kWh)"]
                    upcom = df.loc[upcom_idk, :]["E. totale (kWh)"]

                    # Compute delta
                    mean_deltas.append((idk_observation,np.mean([np.abs(obs_kwh - prev),np.abs(upcom - obs_kwh)]) ))

                    # Check validity 
                    if prev <= obs_kwh <= upcom:
                        print("    Valid observation.")
                    else:
                        print("    Invalid values of E. total (kWH) the observation will be discarded. ")
                        to_discard_strat_2.append(idk_observation)
                        
                if len(to_discard_strat_2) == len(remaining_duplicated_obs):
                    print(prev_idk, "- ",idk_observation, "-", upcom_idk)
                    neighbours = df.loc[prev_idk:upcom_idk, :]
                    display(neighbours)
                    to_discard_strat_2 = to_discard_strat_2[1:]
                    print(to_discard_strat_2)
                    
                # IN CASE: Multiple valid observations (according to the )
                if len(remaining_duplicated_obs) - len(to_discard_strat_2) > 1:
                    print("\n    Multiple valid duplicated observations have been found. "\
                          f"{sorted(set(remaining_duplicated_obs) - set(to_discard_strat_2))}")

                    # Delete deltas of already selected discarted observations
                    if to_discard_strat_2:
                        idx_to_delate = [item for item in to_discard_strat_2]
                        mean_deltas = [delta for delta in mean_deltas if delta[0] not in idx_to_delate]

                    # Sort according to the deltas
                    mean_deltas.sort(key = lambda item: item[1])

                    if len(mean_deltas) >= 3: # Multiple items to discard
                        to_discard_strat_2.extend([item[0] for item in mean_deltas[1:]])
                    else:
                        to_discard_strat_2.append(*[item[0] for item in mean_deltas[1:]])
                    print(f"    Keeping the one (idk: {mean_deltas[0][0]}) with the less delta with the previous and next observations")                        
            
                # Add the discarted index found with this stategy
                to_discard.update(to_discard_strat_2)
                    
                # Visualize final outcome for the day
                idx_to_discard = to_discard_strat_2 + duplicated_diff_obs
                print(f"\n--> TO KEEP: {set(daily_duplicated_indexes) - set(idx_to_discard)} \---/ "\
                      f"TO DISCARD ({len(idx_to_discard)} out of {len(daily_duplicated_indexes)}): "\
                      f"{sorted(to_discard_strat_2)} + {sorted(duplicated_diff_obs)}")
                print("-"*120)
        
        # Select the index to remove (keep the first one, as they are the equal)
        idx_to_delate = set(obs_to_discard for pairs in equal_observations for obs_to_discard in pairs[1:])
        item_to_delate = sorted(idx_to_delate.union(to_discard))
        print(f"TO DELATE ({len(item_to_delate)} out of {len(duplicated_datetime)}):", item_to_delate)
        
        # Delate the equal duplicate
        index_to_delate[inv_name] = item_to_delate
        
    return index_to_delate
# -------------------------------------------------------------------------------
index_to_delate = check_datetime_uniqueness()
# Out:
# Analysing INV1...
# DUPLICATE DATES: 49: ['2018-08-08, 12:15', '2018-08-08, 12:25', '2018-08-08, 12:35', '2018-08-08, 12:40', '2018-08-08, 13:55', '2018-08-08, 14:00', '2018-08-08, 14:10', '2018-08-08, 14:15', '2018-08-08, 14:20', '2018-08-08, 14:25', '2018-08-08, 14:30', '2018-08-08, 14:35', '2018-08-08, 14:40', '2018-08-08, 14:50', '2018-08-08, 14:55', '2018-08-08, 15:25', '2018-09-19, 14:40', '2018-10-17, 14:55', '2018-10-17, 15:10', '2018-10-17, 15:15', '2018-10-17, 15:20', '2018-10-17, 15:30', '2018-10-17, 15:45', '2018-11-21, 14:40', '2019-06-11, 17:50', '2019-06-13, 14:50', '2019-06-13, 15:05', '2019-06-13, 15:30', '2019-07-08, 14:55', '2019-07-08, 17:05', '2019-09-17, 09:40', '2019-09-17, 09:45', '2019-09-17, 09:50', '2019-09-17, 10:05', '2019-09-17, 10:10', '2019-09-17, 10:15', '2019-09-17, 12:30', '2019-09-17, 12:40', '2019-09-17, 12:50', '2019-11-08, 08:55', '2020-02-17, 11:05', '2020-02-17, 11:15', '2020-02-17, 11:20', '2020-02-17, 11:25', '2020-02-17, 11:30', '2020-02-17, 11:35', '2020-02-17, 11:50', '2020-06-20, 09:40', '2020-09-25, 12:35'] (Total observations: 173)
#
# Analysing 2018-08-08 12:15:00 - (observations: 6)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 13...
#     Equal observation(s) have been found: [14, 15]
# --> Analysing idk: 14...
#     Equal observation(s) have been found: [13, 15]
# --> Analysing idk: 15...
#     Equal observation(s) have been found: [13, 14]
# --> Analysing idk: 16...
#     Equal observation(s) have been found: [17, 18]
# --> Analysing idk: 17...
#     Equal observation(s) have been found: [16, 18]
# --> Analysing idk: 18...
#     Equal observation(s) have been found: [16, 17]
#
# --> OK, discarding the identical observations:  [14, 15, 17, 18]
#
# --> Issue, duplicated observations with different values have been found! --> [13, 16]
#     FOCUSING ON IDK: 13
#     Invalid values of E. total (kWH) the observation will be discarded.
#     FOCUSING ON IDK: 16
#     Valid observation.
#
# --> TO KEEP: {16} \---/ TO DISCARD (5 out of 6): [13] + [14, 15, 17, 18]
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2018-08-08 12:25:00 - (observations: 4)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 19...
#     Equal observation(s) have been found: [20]
# --> Analysing idk: 20...
#     Equal observation(s) have been found: [19]
# --> Analysing idk: 21...
#     Equal observation(s) have been found: [22]
# --> Analysing idk: 22...
#     Equal observation(s) have been found: [21]
#
# --> OK, discarding the identical observations:  [20, 22]
#
# --> Issue, duplicated observations with different values have been found! --> [19, 21]
#     FOCUSING ON IDK: 19
#     Valid observation.
#     FOCUSING ON IDK: 21
#     Valid observation.
#
#     Multiple valid duplicated observations have been found. [19, 21]
#     Keeping the one (idk: 19) with the less delta with the previous and next observations
#
# --> TO KEEP: {19} \---/ TO DISCARD (3 out of 4): [21] + [20, 22]
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2018-08-08 12:35:00 - (observations: 4)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 24...
#     Equal observation(s) have been found: [25]
# --> Analysing idk: 25...
#     Equal observation(s) have been found: [24]
# --> Analysing idk: 26...
#     Equal observation(s) have been found: [27]
# --> Analysing idk: 27...
#     Equal observation(s) have been found: [26]
#
# --> OK, discarding the identical observations:  [25, 27]
#
# --> Issue, duplicated observations with different values have been found! --> [24, 26]
#     FOCUSING ON IDK: 24
#     Valid observation.
#     FOCUSING ON IDK: 26
#     Valid observation.
#
#     Multiple valid duplicated observations have been found. [24, 26]
#     Keeping the one (idk: 24) with the less delta with the previous and next observations
#
# --> TO KEEP: {24} \---/ TO DISCARD (3 out of 4): [26] + [25, 27]
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2018-08-08 12:40:00 - (observations: 4)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 28...
#     Equal observation(s) have been found: [29]
# --> Analysing idk: 29...
#     Equal observation(s) have been found: [28]
# --> Analysing idk: 30...
#     Equal observation(s) have been found: [31]
# --> Analysing idk: 31...
#     Equal observation(s) have been found: [30]
#
# --> OK, discarding the identical observations:  [29, 31]
#
# --> Issue, duplicated observations with different values have been found! --> [28, 30]
#     FOCUSING ON IDK: 28
#     Valid observation.
#     FOCUSING ON IDK: 30
#     Valid observation.
#
#     Multiple valid duplicated observations have been found. [28, 30]
#     Keeping the one (idk: 28) with the less delta with the previous and next observations
#
# --> TO KEEP: {28} \---/ TO DISCARD (3 out of 4): [30] + [29, 31]
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2018-08-08 13:55:00 - (observations: 2)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 42...
# --> Analysing idk: 43...
# No equal observations have been found
#
# --> Issue, duplicated observations with different values have been found! --> [42, 43]
#     FOCUSING ON IDK: 42
#     Valid observation.
#     FOCUSING ON IDK: 43
#     Valid observation.
#
#     Multiple valid duplicated observations have been found. [42, 43]
#     Keeping the one (idk: 43) with the less delta with the previous and next observations
#
# --> TO KEEP: {43} \---/ TO DISCARD (1 out of 2): [42] + []
# ------------------------------------------------------------------------------------------------------------------------
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# Analysing 2018-08-08 14:00:00 - (observations: 4)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 44...
#     Equal observation(s) have been found: [45]
# --> Analysing idk: 45...
#     Equal observation(s) have been found: [44]
# --> Analysing idk: 46...
#     Equal observation(s) have been found: [47]
# --> Analysing idk: 47...
#     Equal observation(s) have been found: [46]
#
# --> OK, discarding the identical observations:  [45, 47]
#
# --> Issue, duplicated observations with different values have been found! --> [44, 46]
#     FOCUSING ON IDK: 44
#     Valid observation.
#     FOCUSING ON IDK: 46
#     Valid observation.
#
#     Multiple valid duplicated observations have been found. [44, 46]
#     Keeping the one (idk: 44) with the less delta with the previous and next observations
#
# --> TO KEEP: {44} \---/ TO DISCARD (3 out of 4): [46] + [45, 47]
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2018-08-08 14:10:00 - (observations: 4)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 48...
#     Equal observation(s) have been found: [49]
# --> Analysing idk: 49...
#     Equal observation(s) have been found: [48]
# --> Analysing idk: 50...
#     Equal observation(s) have been found: [51]
# --> Analysing idk: 51...
#     Equal observation(s) have been found: [50]
#
# --> OK, discarding the identical observations:  [49, 51]
#
# --> Issue, duplicated observations with different values have been found! --> [48, 50]
#     FOCUSING ON IDK: 48
#     Invalid values of E. total (kWH) the observation will be discarded.
#     FOCUSING ON IDK: 50
#     Valid observation.
#
# --> TO KEEP: {50} \---/ TO DISCARD (3 out of 4): [48] + [49, 51]
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2018-08-08 14:15:00 - (observations: 4)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 52...
#     Equal observation(s) have been found: [53]
# --> Analysing idk: 53...
#     Equal observation(s) have been found: [52]
# --> Analysing idk: 54...
#     Equal observation(s) have been found: [55]
# --> Analysing idk: 55...
#     Equal observation(s) have been found: [54]
#
# --> OK, discarding the identical observations:  [53, 55]
#
# --> Issue, duplicated observations with different values have been found! --> [52, 54]
#     FOCUSING ON IDK: 52
#     Valid observation.
#     FOCUSING ON IDK: 54
#     Valid observation.
#
#     Multiple valid duplicated observations have been found. [52, 54]
#     Keeping the one (idk: 52) with the less delta with the previous and next observations
#
# --> TO KEEP: {52} \---/ TO DISCARD (3 out of 4): [54] + [53, 55]
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2018-08-08 14:20:00 - (observations: 4)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 56...
#     Equal observation(s) have been found: [57]
# --> Analysing idk: 57...
#     Equal observation(s) have been found: [56]
# --> Analysing idk: 58...
#     Equal observation(s) have been found: [59]
# --> Analysing idk: 59...
#     Equal observation(s) have been found: [58]
#
# --> OK, discarding the identical observations:  [57, 59]
#
# --> Issue, duplicated observations with different values have been found! --> [56, 58]
#     FOCUSING ON IDK: 56
#     Invalid values of E. total (kWH) the observation will be discarded.
#     FOCUSING ON IDK: 58
#     Valid observation.
#
# --> TO KEEP: {58} \---/ TO DISCARD (3 out of 4): [56] + [57, 59]
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2018-08-08 14:25:00 - (observations: 4)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 60...
#     Equal observation(s) have been found: [61]
# --> Analysing idk: 61...
#     Equal observation(s) have been found: [60]
# --> Analysing idk: 62...
#     Equal observation(s) have been found: [63]
# --> Analysing idk: 63...
#     Equal observation(s) have been found: [62]
#
# --> OK, discarding the identical observations:  [61, 63]
#
# --> Issue, duplicated observations with different values have been found! --> [60, 62]
#     FOCUSING ON IDK: 60
#     Valid observation.
#     FOCUSING ON IDK: 62
#     Valid observation.
#
#     Multiple valid duplicated observations have been found. [60, 62]
#     Keeping the one (idk: 60) with the less delta with the previous and next observations
#
# --> TO KEEP: {60} \---/ TO DISCARD (3 out of 4): [62] + [61, 63]
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2018-08-08 14:30:00 - (observations: 4)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 64...
#     Equal observation(s) have been found: [67]
# --> Analysing idk: 65...
#     Equal observation(s) have been found: [66]
# --> Analysing idk: 66...
#     Equal observation(s) have been found: [65]
# --> Analysing idk: 67...
#     Equal observation(s) have been found: [64]
#
# --> OK, discarding the identical observations:  [66, 67]
#
# --> Issue, duplicated observations with different values have been found! --> [64, 65]
#     FOCUSING ON IDK: 64
#     Valid observation.
#     FOCUSING ON IDK: 65
#     Valid observation.
#
#     Multiple valid duplicated observations have been found. [64, 65]
#     Keeping the one (idk: 64) with the less delta with the previous and next observations
#
# --> TO KEEP: {64} \---/ TO DISCARD (3 out of 4): [65] + [66, 67]
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2018-08-08 14:35:00 - (observations: 4)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 68...
#     Equal observation(s) have been found: [69]
# --> Analysing idk: 69...
#     Equal observation(s) have been found: [68]
# --> Analysing idk: 70...
#     Equal observation(s) have been found: [71]
# --> Analysing idk: 71...
#     Equal observation(s) have been found: [70]
#
# --> OK, discarding the identical observations:  [69, 71]
#
# --> Issue, duplicated observations with different values have been found! --> [68, 70]
#     FOCUSING ON IDK: 68
#     Invalid values of E. total (kWH) the observation will be discarded.
#     FOCUSING ON IDK: 70
#     Valid observation.
#
# --> TO KEEP: {70} \---/ TO DISCARD (3 out of 4): [68] + [69, 71]
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2018-08-08 14:40:00 - (observations: 4)
# ------------------------------------------------------------------------------------------------------------------------
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# --> Analysing idk: 72...
#     Equal observation(s) have been found: [73]
# --> Analysing idk: 73...
#     Equal observation(s) have been found: [72]
# --> Analysing idk: 74...
#     Equal observation(s) have been found: [75]
# --> Analysing idk: 75...
#     Equal observation(s) have been found: [74]
#
# --> OK, discarding the identical observations:  [73, 75]
#
# --> Issue, duplicated observations with different values have been found! --> [72, 74]
#     FOCUSING ON IDK: 72
#     Valid observation.
#     FOCUSING ON IDK: 74
#     Valid observation.
#
#     Multiple valid duplicated observations have been found. [72, 74]
#     Keeping the one (idk: 72) with the less delta with the previous and next observations
#
# --> TO KEEP: {72} \---/ TO DISCARD (3 out of 4): [74] + [73, 75]
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2018-08-08 14:50:00 - (observations: 2)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 76...
# --> Analysing idk: 77...
# No equal observations have been found
#
# --> Issue, duplicated observations with different values have been found! --> [76, 77]
#     FOCUSING ON IDK: 76
#     Valid observation.
#     FOCUSING ON IDK: 77
#     Valid observation.
#
#     Multiple valid duplicated observations have been found. [76, 77]
#     Keeping the one (idk: 77) with the less delta with the previous and next observations
#
# --> TO KEEP: {77} \---/ TO DISCARD (1 out of 2): [76] + []
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2018-08-08 14:55:00 - (observations: 2)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 78...
#     Equal observation(s) have been found: [79]
# --> Analysing idk: 79...
#     Equal observation(s) have been found: [78]
#
# --> OK, discarding the identical observations:  [79]
#
# Analysing 2018-08-08 15:25:00 - (observations: 4)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 84...
#     Equal observation(s) have been found: [85]
# --> Analysing idk: 85...
#     Equal observation(s) have been found: [84]
# --> Analysing idk: 86...
#     Equal observation(s) have been found: [87]
# --> Analysing idk: 87...
#     Equal observation(s) have been found: [86]
#
# --> OK, discarding the identical observations:  [85, 87]
#
# --> Issue, duplicated observations with different values have been found! --> [84, 86]
#     FOCUSING ON IDK: 84
#     Invalid values of E. total (kWH) the observation will be discarded.
#     FOCUSING ON IDK: 86
#     Invalid values of E. total (kWH) the observation will be discarded.
# 83 -  86 - 89
#              Date/Time  Iac R (A)  Iac S (A)  Iac T (A)  Vac R (V)  Vac S (V)  \
# 83 2018-08-08 15:15:00         79         78         79        116        116
# 84 2018-08-08 15:25:00        103        103        103        117        116
# 85 2018-08-08 15:25:00        103        103        103        117        116
# 86 2018-08-08 15:25:00        108        108        108        117        116
# 87 2018-08-08 15:25:00        108        108        108        117        116
# 88 2018-08-08 15:35:00        112        112        108        117        116
# 89 2018-08-08 15:55:00        212        209        205        117        116
#
#     Vac T (V)  Pac R (kW)  E. totale (kWh)  Cc 1 (A)  Vcc 1 (V)    Allarme  \
# 83        116          28        2964550.0        76        398  553701696
# 84        116          36        2964550.3        91        395  553701696
# 85        116          36        2964550.3        91        395  553701696
# 86        116          37        2964549.6        92        401  553701696
# 87        116          37        2964549.6        92        401  553701696
# 88        117          39        2964556.4        94        411  553701696
# 89        117          74        2964577.2       182        411  553701696
#
#     Inverter temp. (°C)
# 83                   35
# 84                   35
# 85                   35
# 86                   35
# 87                   35
# 88                   33
# 89                   33
# [86]
#
# --> TO KEEP: {84} \---/ TO DISCARD (3 out of 4): [86] + [85, 87]
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2018-09-19 14:40:00 - (observations: 4)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 3424...
#     Equal observation(s) have been found: [3425]
# --> Analysing idk: 3425...
#     Equal observation(s) have been found: [3424]
# --> Analysing idk: 3426...
#     Equal observation(s) have been found: [3427]
# --> Analysing idk: 3427...
#     Equal observation(s) have been found: [3426]
#
# --> OK, discarding the identical observations:  [3425, 3427]
#
# --> Issue, duplicated observations with different values have been found! --> [3424, 3426]
#     FOCUSING ON IDK: 3424
#     Invalid values of E. total (kWH) the observation will be discarded.
#     FOCUSING ON IDK: 3426
#     Valid observation.
#
# --> TO KEEP: {3426} \---/ TO DISCARD (3 out of 4): [3424] + [3425, 3427]
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2018-10-17 14:55:00 - (observations: 6)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 5650...
#     Equal observation(s) have been found: [5651, 5652]
# --> Analysing idk: 5651...
#     Equal observation(s) have been found: [5650, 5652]
# --> Analysing idk: 5652...
#     Equal observation(s) have been found: [5650, 5651]
# --> Analysing idk: 5653...
#     Equal observation(s) have been found: [5654, 5655]
# --> Analysing idk: 5654...
#     Equal observation(s) have been found: [5653, 5655]
# --> Analysing idk: 5655...
#     Equal observation(s) have been found: [5653, 5654]
#
# --> OK, discarding the identical observations:  [5651, 5652, 5654, 5655]
#
# --> Issue, duplicated observations with different values have been found! --> [5650, 5653]
#     FOCUSING ON IDK: 5650
#     Invalid values of E. total (kWH) the observation will be discarded.
#     FOCUSING ON IDK: 5653
#     Valid observation.
#
# --> TO KEEP: {5653} \---/ TO DISCARD (5 out of 6): [5650] + [5651, 5652, 5654, 5655]
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2018-10-17 15:10:00 - (observations: 2)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 5657...
# --> Analysing idk: 5658...
# No equal observations have been found
#
# --> Issue, duplicated observations with different values have been found! --> [5657, 5658]
#     FOCUSING ON IDK: 5657
#     Valid observation.
#     FOCUSING ON IDK: 5658
#     Valid observation.
#
#     Multiple valid duplicated observations have been found. [5657, 5658]
#     Keeping the one (idk: 5658) with the less delta with the previous and next observations
#
# --> TO KEEP: {5658} \---/ TO DISCARD (1 out of 2): [5657] + []
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2018-10-17 15:15:00 - (observations: 6)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 5659...
#     Equal observation(s) have been found: [5660, 5661]
# --> Analysing idk: 5660...
#     Equal observation(s) have been found: [5659, 5661]
# --> Analysing idk: 5661...
#     Equal observation(s) have been found: [5659, 5660]
# --> Analysing idk: 5662...
#     Equal observation(s) have been found: [5663, 5664]
# --> Analysing idk: 5663...
#     Equal observation(s) have been found: [5662, 5664]
# --> Analysing idk: 5664...
#     Equal observation(s) have been found: [5662, 5663]
#
# --> OK, discarding the identical observations:  [5660, 5661, 5663, 5664]
#
# --> Issue, duplicated observations with different values have been found! --> [5659, 5662]
#     FOCUSING ON IDK: 5659
#     Invalid values of E. total (kWH) the observation will be discarded.
#     FOCUSING ON IDK: 5662
#     Valid observation.
#
# --> TO KEEP: {5662} \---/ TO DISCARD (5 out of 6): [5659] + [5660, 5661, 5663, 5664]
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2018-10-17 15:20:00 - (observations: 4)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 5665...
#     Equal observation(s) have been found: [5666]
# --> Analysing idk: 5666...
#     Equal observation(s) have been found: [5665]
# --> Analysing idk: 5667...
#     Equal observation(s) have been found: [5668]
# --> Analysing idk: 5668...
#     Equal observation(s) have been found: [5667]
#
# --> OK, discarding the identical observations:  [5666, 5668]
#
# --> Issue, duplicated observations with different values have been found! --> [5665, 5667]
#     FOCUSING ON IDK: 5665
#     Valid observation.
#     FOCUSING ON IDK: 5667
#     Valid observation.
#
#     Multiple valid duplicated observations have been found. [5665, 5667]
#     Keeping the one (idk: 5665) with the less delta with the previous and next observations
#
# --> TO KEEP: {5665} \---/ TO DISCARD (3 out of 4): [5667] + [5666, 5668]
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2018-10-17 15:30:00 - (observations: 4)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 5670...
#     Equal observation(s) have been found: [5671]
# --> Analysing idk: 5671...
#     Equal observation(s) have been found: [5670]
# --> Analysing idk: 5672...
#     Equal observation(s) have been found: [5673]
# --> Analysing idk: 5673...
#     Equal observation(s) have been found: [5672]
#
# --> OK, discarding the identical observations:  [5671, 5673]
#
# --> Issue, duplicated observations with different values have been found! --> [5670, 5672]
#     FOCUSING ON IDK: 5670
#     Invalid values of E. total (kWH) the observation will be discarded.
#     FOCUSING ON IDK: 5672
#     Valid observation.
#
# --> TO KEEP: {5672} \---/ TO DISCARD (3 out of 4): [5670] + [5671, 5673]
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2018-10-17 15:45:00 - (observations: 2)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 5675...
#     Equal observation(s) have been found: [5676]
# --> Analysing idk: 5676...
#     Equal observation(s) have been found: [5675]
#
# --> OK, discarding the identical observations:  [5676]
#
# Analysing 2018-11-21 14:40:00 - (observations: 4)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 6089...
#     Equal observation(s) have been found: [6090]
# --> Analysing idk: 6090...
#     Equal observation(s) have been found: [6089]
# --> Analysing idk: 6091...
#     Equal observation(s) have been found: [6092]
# --> Analysing idk: 6092...
#     Equal observation(s) have been found: [6091]
#
# --> OK, discarding the identical observations:  [6090, 6092]
#
# --> Issue, duplicated observations with different values have been found! --> [6089, 6091]
#     FOCUSING ON IDK: 6089
#     Invalid values of E. total (kWH) the observation will be discarded.
#     FOCUSING ON IDK: 6091
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
#     Valid observation.
#
# --> TO KEEP: {6091} \---/ TO DISCARD (3 out of 4): [6089] + [6090, 6092]
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2019-06-11 17:50:00 - (observations: 2)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 32774...
#     Equal observation(s) have been found: [32775]
# --> Analysing idk: 32775...
#     Equal observation(s) have been found: [32774]
#
# --> OK, discarding the identical observations:  [32775]
#
# Analysing 2019-06-13 14:50:00 - (observations: 4)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 33081...
#     Equal observation(s) have been found: [33082]
# --> Analysing idk: 33082...
#     Equal observation(s) have been found: [33081]
# --> Analysing idk: 33083...
#     Equal observation(s) have been found: [33084]
# --> Analysing idk: 33084...
#     Equal observation(s) have been found: [33083]
#
# --> OK, discarding the identical observations:  [33082, 33084]
#
# --> Issue, duplicated observations with different values have been found! --> [33081, 33083]
#     FOCUSING ON IDK: 33081
#     Valid observation.
#     FOCUSING ON IDK: 33083
#     Valid observation.
#
#     Multiple valid duplicated observations have been found. [33081, 33083]
#     Keeping the one (idk: 33081) with the less delta with the previous and next observations
#
# --> TO KEEP: {33081} \---/ TO DISCARD (3 out of 4): [33083] + [33082, 33084]
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2019-06-13 15:05:00 - (observations: 2)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 33087...
#     Equal observation(s) have been found: [33088]
# --> Analysing idk: 33088...
#     Equal observation(s) have been found: [33087]
#
# --> OK, discarding the identical observations:  [33088]
#
# Analysing 2019-06-13 15:30:00 - (observations: 4)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 33090...
#     Equal observation(s) have been found: [33091]
# --> Analysing idk: 33091...
#     Equal observation(s) have been found: [33090]
# --> Analysing idk: 33092...
#     Equal observation(s) have been found: [33093]
# --> Analysing idk: 33093...
#     Equal observation(s) have been found: [33092]
#
# --> OK, discarding the identical observations:  [33091, 33093]
#
# --> Issue, duplicated observations with different values have been found! --> [33090, 33092]
#     FOCUSING ON IDK: 33090
#     Valid observation.
#     FOCUSING ON IDK: 33092
#     Valid observation.
#
#     Multiple valid duplicated observations have been found. [33090, 33092]
#     Keeping the one (idk: 33090) with the less delta with the previous and next observations
#
# --> TO KEEP: {33090} \---/ TO DISCARD (3 out of 4): [33092] + [33091, 33093]
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2019-07-08 14:55:00 - (observations: 2)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 37134...
# --> Analysing idk: 37135...
# No equal observations have been found
#
# --> Issue, duplicated observations with different values have been found! --> [37134, 37135]
#     FOCUSING ON IDK: 37134
#     Valid observation.
#     FOCUSING ON IDK: 37135
#     Valid observation.
#
#     Multiple valid duplicated observations have been found. [37134, 37135]
#     Keeping the one (idk: 37134) with the less delta with the previous and next observations
#
# --> TO KEEP: {37134} \---/ TO DISCARD (1 out of 2): [37135] + []
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2019-07-08 17:05:00 - (observations: 4)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 37154...
#     Equal observation(s) have been found: [37155]
# --> Analysing idk: 37155...
#     Equal observation(s) have been found: [37154]
# --> Analysing idk: 37156...
#     Equal observation(s) have been found: [37157]
# --> Analysing idk: 37157...
#     Equal observation(s) have been found: [37156]
#
# --> OK, discarding the identical observations:  [37155, 37157]
#
# --> Issue, duplicated observations with different values have been found! --> [37154, 37156]
#     FOCUSING ON IDK: 37154
#     Valid observation.
#     FOCUSING ON IDK: 37156
#     Valid observation.
#
#     Multiple valid duplicated observations have been found. [37154, 37156]
#     Keeping the one (idk: 37154) with the less delta with the previous and next observations
#
# --> TO KEEP: {37154} \---/ TO DISCARD (3 out of 4): [37156] + [37155, 37157]
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2019-09-17 09:40:00 - (observations: 2)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 46416...
# --> Analysing idk: 46417...
# No equal observations have been found
#
# --> Issue, duplicated observations with different values have been found! --> [46416, 46417]
#     FOCUSING ON IDK: 46416
#     Valid observation.
#     FOCUSING ON IDK: 46417
#     Valid observation.
#
#     Multiple valid duplicated observations have been found. [46416, 46417]
#     Keeping the one (idk: 46417) with the less delta with the previous and next observations
#
# --> TO KEEP: {46417} \---/ TO DISCARD (1 out of 2): [46416] + []
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2019-09-17 09:45:00 - (observations: 4)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 46418...
#     Equal observation(s) have been found: [46419]
# --> Analysing idk: 46419...
#     Equal observation(s) have been found: [46418]
# --> Analysing idk: 46420...
#     Equal observation(s) have been found: [46421]
# --> Analysing idk: 46421...
#     Equal observation(s) have been found: [46420]
#
# --> OK, discarding the identical observations:  [46419, 46421]
#
# --> Issue, duplicated observations with different values have been found! --> [46418, 46420]
#     FOCUSING ON IDK: 46418
#     Invalid values of E. total (kWH) the observation will be discarded.
#     FOCUSING ON IDK: 46420
#     Valid observation.
#
# --> TO KEEP: {46420} \---/ TO DISCARD (3 out of 4): [46418] + [46419, 46421]
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2019-09-17 09:50:00 - (observations: 2)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 46422...
#     Equal observation(s) have been found: [46423]
# --> Analysing idk: 46423...
#     Equal observation(s) have been found: [46422]
#
# --> OK, discarding the identical observations:  [46423]
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# Analysing 2019-09-17 10:05:00 - (observations: 4)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 46425...
#     Equal observation(s) have been found: [46426]
# --> Analysing idk: 46426...
#     Equal observation(s) have been found: [46425]
# --> Analysing idk: 46427...
#     Equal observation(s) have been found: [46428]
# --> Analysing idk: 46428...
#     Equal observation(s) have been found: [46427]
#
# --> OK, discarding the identical observations:  [46426, 46428]
#
# --> Issue, duplicated observations with different values have been found! --> [46425, 46427]
#     FOCUSING ON IDK: 46425
#     Invalid values of E. total (kWH) the observation will be discarded.
#     FOCUSING ON IDK: 46427
#     Valid observation.
#
# --> TO KEEP: {46427} \---/ TO DISCARD (3 out of 4): [46425] + [46426, 46428]
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2019-09-17 10:10:00 - (observations: 2)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 46429...
# --> Analysing idk: 46430...
# No equal observations have been found
#
# --> Issue, duplicated observations with different values have been found! --> [46429, 46430]
#     FOCUSING ON IDK: 46429
#     Valid observation.
#     FOCUSING ON IDK: 46430
#     Valid observation.
#
#     Multiple valid duplicated observations have been found. [46429, 46430]
#     Keeping the one (idk: 46430) with the less delta with the previous and next observations
#
# --> TO KEEP: {46430} \---/ TO DISCARD (1 out of 2): [46429] + []
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2019-09-17 10:15:00 - (observations: 4)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 46431...
#     Equal observation(s) have been found: [46432]
# --> Analysing idk: 46432...
#     Equal observation(s) have been found: [46431]
# --> Analysing idk: 46433...
#     Equal observation(s) have been found: [46434]
# --> Analysing idk: 46434...
#     Equal observation(s) have been found: [46433]
#
# --> OK, discarding the identical observations:  [46432, 46434]
#
# --> Issue, duplicated observations with different values have been found! --> [46431, 46433]
#     FOCUSING ON IDK: 46431
#     Valid observation.
#     FOCUSING ON IDK: 46433
#     Valid observation.
#
#     Multiple valid duplicated observations have been found. [46431, 46433]
#     Keeping the one (idk: 46431) with the less delta with the previous and next observations
#
# --> TO KEEP: {46431} \---/ TO DISCARD (3 out of 4): [46433] + [46432, 46434]
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2019-09-17 12:30:00 - (observations: 2)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 46435...
#     Equal observation(s) have been found: [46436]
# --> Analysing idk: 46436...
#     Equal observation(s) have been found: [46435]
#
# --> OK, discarding the identical observations:  [46436]
#
# Analysing 2019-09-17 12:40:00 - (observations: 2)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 46438...
# --> Analysing idk: 46439...
# No equal observations have been found
#
# --> Issue, duplicated observations with different values have been found! --> [46438, 46439]
#     FOCUSING ON IDK: 46438
#     Valid observation.
#     FOCUSING ON IDK: 46439
#     Valid observation.
#
#     Multiple valid duplicated observations have been found. [46438, 46439]
#     Keeping the one (idk: 46439) with the less delta with the previous and next observations
#
# --> TO KEEP: {46439} \---/ TO DISCARD (1 out of 2): [46438] + []
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2019-09-17 12:50:00 - (observations: 4)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 46441...
#     Equal observation(s) have been found: [46442]
# --> Analysing idk: 46442...
#     Equal observation(s) have been found: [46441]
# --> Analysing idk: 46443...
#     Equal observation(s) have been found: [46444]
# --> Analysing idk: 46444...
#     Equal observation(s) have been found: [46443]
#
# --> OK, discarding the identical observations:  [46442, 46444]
#
# --> Issue, duplicated observations with different values have been found! --> [46441, 46443]
#     FOCUSING ON IDK: 46441
#     Valid observation.
#     FOCUSING ON IDK: 46443
#     Valid observation.
#
#     Multiple valid duplicated observations have been found. [46441, 46443]
#     Keeping the one (idk: 46441) with the less delta with the previous and next observations
#
# --> TO KEEP: {46441} \---/ TO DISCARD (3 out of 4): [46443] + [46442, 46444]
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2019-11-08 08:55:00 - (observations: 4)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 52329...
#     Equal observation(s) have been found: [52330]
# --> Analysing idk: 52330...
#     Equal observation(s) have been found: [52329]
# --> Analysing idk: 52331...
#     Equal observation(s) have been found: [52332]
# --> Analysing idk: 52332...
#     Equal observation(s) have been found: [52331]
#
# --> OK, discarding the identical observations:  [52330, 52332]
#
# --> Issue, duplicated observations with different values have been found! --> [52329, 52331]
#     FOCUSING ON IDK: 52329
#     Valid observation.
#     FOCUSING ON IDK: 52331
#     Valid observation.
#
#     Multiple valid duplicated observations have been found. [52329, 52331]
#     Keeping the one (idk: 52329) with the less delta with the previous and next observations
#
# --> TO KEEP: {52329} \---/ TO DISCARD (3 out of 4): [52331] + [52330, 52332]
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2020-02-17 11:05:00 - (observations: 2)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 66963...
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# ...
#
# --> Issue, duplicated observations with different values have been found! --> [46441, 46443, 46445]
#     FOCUSING ON IDK: 46441
#     Valid observation.
#     FOCUSING ON IDK: 46443
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
#     Valid observation.
#     FOCUSING ON IDK: 46445
#     Valid observation.
#
#     Multiple valid duplicated observations have been found. [46441, 46443, 46445]
#     Keeping the one (idk: 46441) with the less delta with the previous and next observations
#
# --> TO KEEP: {46441} \---/ TO DISCARD (5 out of 6): [46443, 46445] + [46442, 46444, 46446]
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2019-09-17 12:30:00 - (observations: 2)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 46447...
#     Equal observation(s) have been found: [46448]
# --> Analysing idk: 46448...
#     Equal observation(s) have been found: [46447]
#
# --> OK, discarding the identical observations:  [46448]
#
# Analysing 2019-09-17 12:40:00 - (observations: 2)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 46450...
# --> Analysing idk: 46451...
# No equal observations have been found
#
# --> Issue, duplicated observations with different values have been found! --> [46450, 46451]
#     FOCUSING ON IDK: 46450
#     Valid observation.
#     FOCUSING ON IDK: 46451
#     Valid observation.
#
#     Multiple valid duplicated observations have been found. [46450, 46451]
#     Keeping the one (idk: 46451) with the less delta with the previous and next observations
#
# --> TO KEEP: {46451} \---/ TO DISCARD (1 out of 2): [46450] + []
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2019-09-17 12:50:00 - (observations: 4)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 46453...
#     Equal observation(s) have been found: [46454]
# --> Analysing idk: 46454...
#     Equal observation(s) have been found: [46453]
# --> Analysing idk: 46455...
#     Equal observation(s) have been found: [46456]
# --> Analysing idk: 46456...
#     Equal observation(s) have been found: [46455]
#
# --> OK, discarding the identical observations:  [46454, 46456]
#
# --> Issue, duplicated observations with different values have been found! --> [46453, 46455]
#     FOCUSING ON IDK: 46453
#     Valid observation.
#     FOCUSING ON IDK: 46455
#     Valid observation.
#
#     Multiple valid duplicated observations have been found. [46453, 46455]
#     Keeping the one (idk: 46453) with the less delta with the previous and next observations
#
# --> TO KEEP: {46453} \---/ TO DISCARD (3 out of 4): [46455] + [46454, 46456]
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2019-11-08 08:55:00 - (observations: 4)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 52346...
#     Equal observation(s) have been found: [52347]
# --> Analysing idk: 52347...
#     Equal observation(s) have been found: [52346]
# --> Analysing idk: 52348...
#     Equal observation(s) have been found: [52349]
# --> Analysing idk: 52349...
#     Equal observation(s) have been found: [52348]
#
# --> OK, discarding the identical observations:  [52347, 52349]
#
# --> Issue, duplicated observations with different values have been found! --> [52346, 52348]
#     FOCUSING ON IDK: 52346
#     Valid observation.
#     FOCUSING ON IDK: 52348
#     Valid observation.
#
#     Multiple valid duplicated observations have been found. [52346, 52348]
#     Keeping the one (idk: 52346) with the less delta with the previous and next observations
#
# --> TO KEEP: {52346} \---/ TO DISCARD (3 out of 4): [52348] + [52347, 52349]
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2020-02-17 11:05:00 - (observations: 2)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 64335...
# --> Analysing idk: 64336...
# No equal observations have been found
#
# --> Issue, duplicated observations with different values have been found! --> [64335, 64336]
#     FOCUSING ON IDK: 64335
#     Valid observation.
#     FOCUSING ON IDK: 64336
#     Valid observation.
#
#     Multiple valid duplicated observations have been found. [64335, 64336]
#     Keeping the one (idk: 64335) with the less delta with the previous and next observations
#
# --> TO KEEP: {64335} \---/ TO DISCARD (1 out of 2): [64336] + []
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2020-02-17 11:15:00 - (observations: 4)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 64337...
#     Equal observation(s) have been found: [64338]
# --> Analysing idk: 64338...
#     Equal observation(s) have been found: [64337]
# --> Analysing idk: 64339...
#     Equal observation(s) have been found: [64340]
# --> Analysing idk: 64340...
#     Equal observation(s) have been found: [64339]
#
# --> OK, discarding the identical observations:  [64338, 64340]
#
# --> Issue, duplicated observations with different values have been found! --> [64337, 64339]
#     FOCUSING ON IDK: 64337
#     Valid observation.
#     FOCUSING ON IDK: 64339
#     Valid observation.
#
#     Multiple valid duplicated observations have been found. [64337, 64339]
#     Keeping the one (idk: 64337) with the less delta with the previous and next observations
#
# --> TO KEEP: {64337} \---/ TO DISCARD (3 out of 4): [64339] + [64338, 64340]
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2020-02-17 11:20:00 - (observations: 4)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 64341...
#     Equal observation(s) have been found: [64342]
# --> Analysing idk: 64342...
#     Equal observation(s) have been found: [64341]
# --> Analysing idk: 64343...
#     Equal observation(s) have been found: [64344]
# --> Analysing idk: 64344...
#     Equal observation(s) have been found: [64343]
#
# --> OK, discarding the identical observations:  [64342, 64344]
#
# --> Issue, duplicated observations with different values have been found! --> [64341, 64343]
#     FOCUSING ON IDK: 64341
#     Valid observation.
#     FOCUSING ON IDK: 64343
#     Valid observation.
#
#     Multiple valid duplicated observations have been found. [64341, 64343]
#     Keeping the one (idk: 64341) with the less delta with the previous and next observations
#
# --> TO KEEP: {64341} \---/ TO DISCARD (3 out of 4): [64343] + [64342, 64344]
# ------------------------------------------------------------------------------------------------------------------------
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# Analysing 2020-02-17 11:30:00 - (observations: 4)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 64346...
#     Equal observation(s) have been found: [64347]
# --> Analysing idk: 64347...
#     Equal observation(s) have been found: [64346]
# --> Analysing idk: 64348...
#     Equal observation(s) have been found: [64349]
# --> Analysing idk: 64349...
#     Equal observation(s) have been found: [64348]
#
# --> OK, discarding the identical observations:  [64347, 64349]
#
# --> Issue, duplicated observations with different values have been found! --> [64346, 64348]
#     FOCUSING ON IDK: 64346
#     Invalid values of E. total (kWH) the observation will be discarded.
#     FOCUSING ON IDK: 64348
#     Valid observation.
#
# --> TO KEEP: {64348} \---/ TO DISCARD (3 out of 4): [64346] + [64347, 64349]
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2020-02-17 11:35:00 - (observations: 4)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 64350...
#     Equal observation(s) have been found: [64351]
# --> Analysing idk: 64351...
#     Equal observation(s) have been found: [64350]
# --> Analysing idk: 64352...
#     Equal observation(s) have been found: [64353]
# --> Analysing idk: 64353...
#     Equal observation(s) have been found: [64352]
#
# --> OK, discarding the identical observations:  [64351, 64353]
#
# --> Issue, duplicated observations with different values have been found! --> [64350, 64352]
#     FOCUSING ON IDK: 64350
#     Valid observation.
#     FOCUSING ON IDK: 64352
#     Valid observation.
#
#     Multiple valid duplicated observations have been found. [64350, 64352]
#     Keeping the one (idk: 64350) with the less delta with the previous and next observations
#
# --> TO KEEP: {64350} \---/ TO DISCARD (3 out of 4): [64352] + [64351, 64353]
# ------------------------------------------------------------------------------------------------------------------------
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()
# Analysing 2020-02-17 11:50:00 - (observations: 2)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 64356...
#     Equal observation(s) have been found: [64357]
# --> Analysing idk: 64357...
#     Equal observation(s) have been found: [64356]
#
# --> OK, discarding the identical observations:  [64357]
#
# Analysing 2020-06-20 09:40:00 - (observations: 9)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 82914...
#     Equal observation(s) have been found: [82915, 82916]
# --> Analysing idk: 82915...
#     Equal observation(s) have been found: [82914, 82916]
# --> Analysing idk: 82916...
#     Equal observation(s) have been found: [82914, 82915]
# --> Analysing idk: 82917...
#     Equal observation(s) have been found: [82918, 82919]
# --> Analysing idk: 82918...
#     Equal observation(s) have been found: [82917, 82919]
# --> Analysing idk: 82919...
#     Equal observation(s) have been found: [82917, 82918]
# --> Analysing idk: 82920...
#     Equal observation(s) have been found: [82921, 82922]
# --> Analysing idk: 82921...
#     Equal observation(s) have been found: [82920, 82922]
# --> Analysing idk: 82922...
#     Equal observation(s) have been found: [82920, 82921]
#
# --> OK, discarding the identical observations:  [82915, 82916, 82918, 82919, 82921, 82922]
#
# --> Issue, duplicated observations with different values have been found! --> [82914, 82917, 82920]
#     FOCUSING ON IDK: 82914
#     Invalid values of E. total (kWH) the observation will be discarded.
#     FOCUSING ON IDK: 82917
#     Valid observation.
#     FOCUSING ON IDK: 82920
#     Valid observation.
#
#     Multiple valid duplicated observations have been found. [82917, 82920]
#     Keeping the one (idk: 82917) with the less delta with the previous and next observations
#
# --> TO KEEP: {82917} \---/ TO DISCARD (8 out of 9): [82914, 82920] + [82915, 82916, 82918, 82919, 82921, 82922]
# ------------------------------------------------------------------------------------------------------------------------
#
# Analysing 2020-09-25 12:35:00 - (observations: 4)
# ------------------------------------------------------------------------------------------------------------------------
# --> Analysing idk: 97911...
#     Equal observation(s) have been found: [97912]
# --> Analysing idk: 97912...
#     Equal observation(s) have been found: [97911]
# --> Analysing idk: 97913...
#     Equal observation(s) have been found: [97914]
# --> Analysing idk: 97914...
#     Equal observation(s) have been found: [97913]
#
# --> OK, discarding the identical observations:  [97912, 97914]
#
# --> Issue, duplicated observations with different values have been found! --> [97911, 97913]
#     FOCUSING ON IDK: 97911
#     Invalid values of E. total (kWH) the observation will be discarded.
#     FOCUSING ON IDK: 97913
#     Valid observation.
#
# --> TO KEEP: {97913} \---/ TO DISCARD (3 out of 4): [97911] + [97912, 97914]
# ------------------------------------------------------------------------------------------------------------------------
# TO DELATE (128 out of 175): [15, 16, 17, 19, 20, 22, 23, 24, 27, 28, 29, 30, 31, 33, 45, 46, 47, 49, 51, 52, 53, 54, 55, 57, 59, 60, 61, 63, 64, 65, 66, 67, 69, 71, 72, 73, 75, 76, 77, 78, 81, 87, 88, 89, 3424, 3425, 3426, 5649, 5650, 5651, 5652, 5653, 5656, 5657, 5658, 5659, 5661, 5662, 5663, 5664, 5666, 5669, 5670, 5671, 5674, 6110, 6111, 6113, 32746, 32747, 32748, 33055, 33056, 33057, 33058, 33061, 33066, 33067, 33068, 37146, 37167, 37168, 37169, 46430, 46431, 46432, 46434, 46437, 46438, 46439, 46442, 46443, 46444, 46445, 46446, 46448, 46450, 46454, 46455, 46456, 52347, 52348, 52349, 64336, 64338, 64339, 64340, 64342, 64343, 64344, 64346, 64347, 64349, 64351, 64352, 64353, 64357, 82914, 82915, 82916, 82918, 82919, 82920, 82921, 82922, 97911, 97912, 97914]
# /tmp/ipykernel_19401/3828637059.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   obs = pd.Series()

# %% [markdown]
# # Carry out some transformations

# %%
# TASK: Carry out the necessary stategies to tackle the issues discovered in the above analyses
for inv_name in inv_names:
    print(f"\n{inv_name.upper()}...")
    
    # TASK: Delate duplicate observations (same timestamps)
    inv_data[inv_name].drop(index = index_to_delate[inv_name], inplace=True)
    inv_data[inv_name].reset_index(drop=True, inplace = True)
    print(f"--> Discared some duplicated observations (i.e., same timestamps) ({len(index_to_delate[inv_name])})")
    
    # TASK: Delate the columns (i.e., variables) that have been confirmed empty
    inv_data[inv_name].drop(columns = check_emptiness, inplace=True)
    print(f"--> Discared some empty columns (i.e., {check_emptiness})")
    
     # TASK: Remove the irradiance column that was joined previously --> it'll be re-added after fixing the sampling of both side
    inv_data[inv_name].drop(columns = ["Irr. medio (W/mq)"], inplace=True)
    print("--> Removed the column of irradiance values, since it will be re-added after tackling the sampling issue.")
# ---------------------------------------------------------------------------------
# TASK: Carry out some minor changes on the "raw irradiance file"
print("\nRAW IRRADIANCE FILE ...")
# Rename the column of the data
raw_irr_data.rename(columns = {"data":"Date/Time", "irr. medio 1 W/mq":"Irradiance (W/mq)"}, inplace=True)
print("--> Renamed the columns to improve readability and compatibility with other datasets")
# Out:
# INV1...
# --> Discared some duplicated observations (i.e., same timestamps) (124)
# --> Discared some empty columns (i.e., ['Pac S (kW)', 'Pac T (kW)', 'Stato', 'Fac (Hz)'])
# --> Removed the column of irradiance values, since it will be re-added after tackling the sampling issue.
#
# INV2...
# --> Discared some duplicated observations (i.e., same timestamps) (122)
# --> Discared some empty columns (i.e., ['Pac S (kW)', 'Pac T (kW)', 'Stato', 'Fac (Hz)'])
# --> Removed the column of irradiance values, since it will be re-added after tackling the sampling issue.
#
# INV3...
# --> Discared some duplicated observations (i.e., same timestamps) (112)
# --> Discared some empty columns (i.e., ['Pac S (kW)', 'Pac T (kW)', 'Stato', 'Fac (Hz)'])
# --> Removed the column of irradiance values, since it will be re-added after tackling the sampling issue.
#
# INV4...
# --> Discared some duplicated observations (i.e., same timestamps) (128)
# --> Discared some empty columns (i.e., ['Pac S (kW)', 'Pac T (kW)', 'Stato', 'Fac (Hz)'])
# --> Removed the column of irradiance values, since it will be re-added after tackling the sampling issue.
#
# RAW IRRADIANCE FILE ...
# --> Renamed the columns to improve readability and compatibility with other datasets

# %% [markdown]
# #### check

# %% [raw]
# # Check validity of the transformation
# inv_data[inv_names[0]].info()
# print("-"*80)
# index_to_delate = check_datetime_uniqueness()

# %% [markdown]
# # Detect and correct outliers

# %%
# -----------------------------------------------------
# FUNCTION: Find the outliers by adopting the z-score
# -----------------------------------------------------
def find_outliers(df, threshold = 3, verbose = False): 
    numerical_df = df.select_dtypes(include = np.number)
    
    # THE MEASURAMENT: Z-score
    # It describes a value's relationship to the mean of a group of values 
    # It's the number of standard deviations by which the observed value is above/below the mean value of what is being measured
    z_score = np.abs(zscore(numerical_df)) 

    # Filter the observations that are above the threshold (from literature: 3 is a typical cut-off point to detect the outliers)
    if len(z_score.columns) == 3:
        cond_outlier = (z_score.iloc[:, 0] > threshold) & (z_score.iloc[:, 1] > threshold) & (z_score.iloc[:, 2] > threshold)
    elif len(z_score.columns) == 2:
         cond_outlier = (z_score.iloc[:, 0] > threshold) & (z_score.iloc[:, 1] > threshold)
    else:
        cond_outlier = z_score.iloc[:, 0] > threshold 

    # Find the outliers according to the threshold of the z-scores
    outliers_idk = z_score[cond_outlier].index
    outliers = df.loc[outliers_idk, :]
    
    if verbose & len(outliers) != 0:
        print(f"Z-score values (threshold: {threshold})")
        print("MIN:", round(np.min(min(z_score[cond_outlier].values.tolist())), 2), \
              "\nMAX:",round(np.max(max(z_score[cond_outlier].values.tolist())), 2))
              
        display(z_score[cond_outlier])
        
    return outliers
# ------------------------------------------------------------------------------------------
# FUNCTION: Compute a weighted average value according to the observation's neighbours (KNN)
# ------------------------------------------------------------------------------------------
def weighted_knn(df, idk_position, list_outliers, column,  K = 6, verbose=True):
    # Define the interval before and after the position
    k_before = K//2 
    k_after = K//2
    
    # Define the range of neighbours 
    idk_range = np.arange(idk_outlier - k_before, idk_outlier + k_after + 1)
    
    # Find the indexes of other outliers (for excluding them in the weighted average)
    if idk_position in list_outliers:
        list_outliers.remove(idk_position)
    
    # Detect potential outliers in its neighbours
    problematic_idk_neighbours = [idk_outlier for idk_outlier in list_outliers if idk_outlier in idk_range]
        
    if len(problematic_idk_neighbours) != 0:
        if verbose:
            print(f"\nOPS: Problematic IDK neighbours discovered {len(problematic_idk_neighbours)} "\
                  f"({round(((len(problematic_idk_neighbours)/len(idk_range))*100), 2)} %) --> {problematic_idk_neighbours}")
        
        # Try to increase the number of neighbours 
        MAX_K = 30
        if len(problematic_idk_neighbours) >= K//2:
            new_k = K*2 
            if new_k <= MAX_K:
                if verbose: 
                    print(f"Trying with more neighbours ({new_k})...")
                weighted_knn(df, idk_position, list_outliers, column,  K = new_k, verbose=False)
            else:
                if verbose:
                    print("Reach maximum of K neighbours")
        
        # Remove problematic neighbours
        idk_range = idk_range[~ np.isin(idk_range, problematic_idk_neighbours)]
        
        if verbose:
            print("\nEnd process of increasing number of neighbours (i.e., number of problematic neigbours is acceptable (fewer than K/2)")
            print(f"The problematic neighbours ({len(problematic_idk_neighbours)}) have been removed from the neighbour list")
    
    # Find the neigbourhood 
    idk_outlier_pos = np.argwhere(idk_range == idk_position)[0][0]
    neighbours_idk = np.delete(idk_range, idk_outlier_pos)
    
    neighbours = np.array(df.loc[neighbours_idk, :][column]) # iloc
    outlier_value = df.loc[idk_position, :][column]
    
    if verbose:
        print(f"\nVARIABLE: {column}")
        print(f"NEIGHBOURES ({len(neighbours)} out of {K}):{neighbours[:idk_outlier_pos]} \--/ {neighbours[idk_outlier_pos:]}")
    
    # Define the weights
    dist_idk = [np.abs(idk - idk_position) for idk in neighbours_idk]
    penalize = lambda dist: min(dist_idk)/dist if dist != min(dist_idk) else 1 #min(dist_idk)/(1 + (dist/10))
    weights = [round(penalize(dist), 2) for dist in dist_idk]
    
    if verbose:
        print("WEIGHTS:", weights)

    # Compute the weighted average 
    weighted_average_value = np.average(neighbours, weights = weights)
    
    # Round and cast the value to an integer value
    candidate_value = int(round(weighted_average_value, 0))
    
    if verbose:
        print(f"COMPUTED VALUE: {candidate_value}")
        print("-" * 80)
    return candidate_value

# %% [markdown]
# ### Variable: *AC voltage values* (Vac R/S/T)

# %%
# TASK: A) Analyse and correct the outliers
# VARIABLES: AC voltage values (Vac R/S/T)
# MOTIVATION: Some invalid values (i.e., zero values) have been detected visually (i.e., numerical distribution graphs)
columns = ["Date/Time", "Vac R (V)", "Vac S (V)", "Vac T (V)"]

# Carry out the analysis (and correction) on all the inverters
for inv_name in inv_names:
    print("INVERTER NAME:", inv_name, "\n", "-"*80)
    
    # 1A) Detect extreme outliers 
    # Setting threshold: a very high threshold to detect (and correct) only extreme outliers (e.g. zero values)
    # Threshold has been set according to emperical tests (default outlier threshold is equal to 3)
    extreme_vac_outlier = find_outliers(inv_data[inv_name][columns], verbose=True, threshold = 5)
    
    if len(extreme_vac_outlier) == 0:
        print("Oh, no extreme outliers found. That's good.\n")
        continue
        
    print(f"The extreme outliers ({len(extreme_vac_outlier)}) of Vac")
    display(extreme_vac_outlier)

    # 1B) Replacing criterion --> Weighted KNN (k = 6)
    # Identfy the index of the outliers 
    idk_outliers = extreme_vac_outlier.index.tolist()
    list_outliers = idk_outliers.copy()
    
    # Compute and assign the estimated value (weighted average value from its neigbours)
    for idk_outlier in idk_outliers:
        
        # Visualize the outlier and its neighours
        print(f"Outlier (idk: {idk_outlier}) and its neighborhood")
        display(inv_data[inv_name][columns].loc[range(idk_outlier - 3, idk_outlier + 4), :])
        
        # Compute the estimated value and assign the the original dataframe
        inv_data[inv_name].loc[idk_outlier, "Vac R (V)"] = weighted_knn(inv_data[inv_name][columns], 
                                                                        idk_outlier, list_outliers, "Vac R (V)")
        inv_data[inv_name].loc[idk_outlier, "Vac S (V)"] = weighted_knn(inv_data[inv_name][columns], 
                                                                        idk_outlier, list_outliers, "Vac S (V)")
        inv_data[inv_name].loc[idk_outlier, "Vac T (V)"] = weighted_knn(inv_data[inv_name][columns],
                                                                        idk_outlier, list_outliers, "Vac T (V)")

        # Visualize the outcome
        print("\nNew data (with the filled value(s))")
        display(inv_data[inv_name].loc[idk_outlier][columns])
        print("-" * 80)
# Out:
# INVERTER NAME: INV1
#  --------------------------------------------------------------------------------
# Z-score values (threshold: 5)
# MIN: 42.42
# MAX: 46.52
#        Vac R (V)  Vac S (V)  Vac T (V)
# 59112  42.424222  46.522341   45.31855
# The extreme outliers (1) of Vac
#                 Date/Time  Vac R (V)  Vac S (V)  Vac T (V)
# 59112 2019-11-12 13:00:00          0          0          0
# Outlier (idk: 59112) and its neighborhood
#                 Date/Time  Vac R (V)  Vac S (V)  Vac T (V)
# 59109 2019-11-12 12:40:00        111        112        111
# 59110 2019-11-12 12:45:00        111        111        111
# 59111 2019-11-12 12:55:00        113        113        113
# 59112 2019-11-12 13:00:00          0          0          0
# 59113 2019-11-12 13:05:00        115        115        115
# 59114 2019-11-12 13:10:00        118        118        118
# 59115 2019-11-12 13:15:00        117        117        117
# VARIABLE: Vac R (V)
# NEIGHBOURES (6 out of 6):[111 111 113] \--/ [115 118 117]
# WEIGHTS: [0.33, 0.5, 1, 1, 0.5, 0.33]
# COMPUTED VALUE: 114
# --------------------------------------------------------------------------------
#
# VARIABLE: Vac S (V)
# NEIGHBOURES (6 out of 6):[112 111 113] \--/ [115 118 117]
# WEIGHTS: [0.33, 0.5, 1, 1, 0.5, 0.33]
# COMPUTED VALUE: 114
# --------------------------------------------------------------------------------
#
# VARIABLE: Vac T (V)
# NEIGHBOURES (6 out of 6):[111 111 113] \--/ [115 118 117]
# WEIGHTS: [0.33, 0.5, 1, 1, 0.5, 0.33]
# COMPUTED VALUE: 114
# --------------------------------------------------------------------------------
#
# New data (with the filled value(s))
# Date/Time    2019-11-12 13:00:00
# Vac R (V)                    114
# Vac S (V)                    114
# Vac T (V)                    114
# Name: 59112, dtype: object
# --------------------------------------------------------------------------------
# INVERTER NAME: INV2
#  --------------------------------------------------------------------------------
# Z-score values (threshold: 5)
# MIN: 41.43
# MAX: 46.28
#        Vac R (V)  Vac S (V)  Vac T (V)
# 70876  41.429549  46.277999    43.9042
# The extreme outliers (1) of Vac
#                 Date/Time  Vac R (V)  Vac S (V)  Vac T (V)
# 70876 2020-02-05 13:20:00          0          0          0
# Outlier (idk: 70876) and its neighborhood
#                 Date/Time  Vac R (V)  Vac S (V)  Vac T (V)
# 70873 2020-02-05 13:05:00        121        121        122
# 70874 2020-02-05 13:10:00        119        119        119
# 70875 2020-02-05 13:15:00        121        120        121
# 70876 2020-02-05 13:20:00          0          0          0
# 70877 2020-02-05 13:25:00        120        120        121
# 70878 2020-02-05 13:35:00        121        120        121
# 70879 2020-02-05 13:40:00        121        121        121
# VARIABLE: Vac R (V)
# NEIGHBOURES (6 out of 6):[121 119 121] \--/ [120 121 121]
# WEIGHTS: [0.33, 0.5, 1, 1, 0.5, 0.33]
# COMPUTED VALUE: 120
# --------------------------------------------------------------------------------
#
# VARIABLE: Vac S (V)
# NEIGHBOURES (6 out of 6):[121 119 120] \--/ [120 120 121]
# WEIGHTS: [0.33, 0.5, 1, 1, 0.5, 0.33]
# COMPUTED VALUE: 120
# --------------------------------------------------------------------------------
#
# VARIABLE: Vac T (V)
# NEIGHBOURES (6 out of 6):[122 119 121] \--/ [121 121 121]
# WEIGHTS: [0.33, 0.5, 1, 1, 0.5, 0.33]
# COMPUTED VALUE: 121
# --------------------------------------------------------------------------------
#
# New data (with the filled value(s))
# Date/Time    2020-02-05 13:20:00
# Vac R (V)                    120
# Vac S (V)                    120
# Vac T (V)                    121
# Name: 70876, dtype: object
# --------------------------------------------------------------------------------
# INVERTER NAME: INV3
#  --------------------------------------------------------------------------------
# Z-score values (threshold: 5)
# MIN: 41.28
# MAX: 45.7
#        Vac R (V)  Vac S (V)  Vac T (V)
# 71807  41.280791  45.695119  43.809058
# The extreme outliers (1) of Vac
#                 Date/Time  Vac R (V)  Vac S (V)  Vac T (V)
# 71807 2020-02-05 13:20:00          0          0          0
# Outlier (idk: 71807) and its neighborhood
#                 Date/Time  Vac R (V)  Vac S (V)  Vac T (V)
# 71804 2020-02-05 13:05:00        121        122        122
# 71805 2020-02-05 13:10:00        119        120        120
# 71806 2020-02-05 13:15:00        121        122        121
# 71807 2020-02-05 13:20:00          0          0          0
# 71808 2020-02-05 13:25:00        120        122        121
# 71809 2020-02-05 13:35:00        121        121        121
# 71810 2020-02-05 13:40:00        121        122        121
# VARIABLE: Vac R (V)
# NEIGHBOURES (6 out of 6):[121 119 121] \--/ [120 121 121]
# WEIGHTS: [0.33, 0.5, 1, 1, 0.5, 0.33]
# COMPUTED VALUE: 120
# --------------------------------------------------------------------------------
#
# VARIABLE: Vac S (V)
# NEIGHBOURES (6 out of 6):[122 120 122] \--/ [122 121 122]
# WEIGHTS: [0.33, 0.5, 1, 1, 0.5, 0.33]
# COMPUTED VALUE: 122
# --------------------------------------------------------------------------------
#
# VARIABLE: Vac T (V)
# NEIGHBOURES (6 out of 6):[122 120 121] \--/ [121 121 121]
# WEIGHTS: [0.33, 0.5, 1, 1, 0.5, 0.33]
# COMPUTED VALUE: 121
# --------------------------------------------------------------------------------
#
# New data (with the filled value(s))
# Date/Time    2020-02-05 13:20:00
# Vac R (V)                    120
# Vac S (V)                    122
# Vac T (V)                    121
# Name: 71807, dtype: object
# --------------------------------------------------------------------------------
# INVERTER NAME: INV4
#  --------------------------------------------------------------------------------
# The extreme outliers (2) of Vac
#                 Date/Time  Vac R (V)  Vac S (V)  Vac T (V)
# 67397 2020-01-05 19:00:00         51         48         15
# 95538 2020-07-02 17:10:00          9          6          9
# Outlier (idk: 67397) and its neighborhood
#                 Date/Time  Vac R (V)  Vac S (V)  Vac T (V)
# 67394 2020-01-05 18:45:00        113        114        113
# 67395 2020-01-05 18:50:00        113        114        113
# 67396 2020-01-05 18:55:00        114        114        113
# 67397 2020-01-05 19:00:00         51         48         15
# 67398 2020-01-05 19:10:00        114        114        113
# 67399 2020-01-05 19:15:00        114        115        114
# 67400 2020-01-05 19:20:00        114        114        113
# VARIABLE: Vac R (V)
# NEIGHBOURES (6 out of 6):[113 113 114] \--/ [114 114 114]
# WEIGHTS: [0.33, 0.5, 1, 1, 0.5, 0.33]
# COMPUTED VALUE: 114
# --------------------------------------------------------------------------------
#
# VARIABLE: Vac S (V)
# NEIGHBOURES (6 out of 6):[114 114 114] \--/ [114 115 114]
# WEIGHTS: [0.33, 0.5, 1, 1, 0.5, 0.33]
# COMPUTED VALUE: 114
# --------------------------------------------------------------------------------
#
# VARIABLE: Vac T (V)
# NEIGHBOURES (6 out of 6):[113 113 113] \--/ [113 114 113]
# WEIGHTS: [0.33, 0.5, 1, 1, 0.5, 0.33]
# COMPUTED VALUE: 113
# --------------------------------------------------------------------------------
#
# New data (with the filled value(s))
# Date/Time    2020-01-05 19:00:00
# Vac R (V)                    114
# Vac S (V)                    114
# Vac T (V)                    113
# Name: 67397, dtype: object
# --------------------------------------------------------------------------------
# Outlier (idk: 95538) and its neighborhood
#                 Date/Time  Vac R (V)  Vac S (V)  Vac T (V)
# 95535 2020-07-02 16:50:00        114        114        113
# 95536 2020-07-02 16:55:00        116        115        115
# 95537 2020-07-02 17:00:00        114        114        113
# 95538 2020-07-02 17:10:00          9          6          9
# 95539 2020-07-02 17:15:00        114        115        114
# 95540 2020-07-02 17:20:00        114        114        113
# 95541 2020-07-02 17:25:00        113        114        113
# VARIABLE: Vac R (V)
# NEIGHBOURES (6 out of 6):[114 116 114] \--/ [114 114 113]
# WEIGHTS: [0.33, 0.5, 1, 1, 0.5, 0.33]
# COMPUTED VALUE: 114
# --------------------------------------------------------------------------------
#
# VARIABLE: Vac S (V)
# NEIGHBOURES (6 out of 6):[114 115 114] \--/ [115 114 114]
# WEIGHTS: [0.33, 0.5, 1, 1, 0.5, 0.33]
# COMPUTED VALUE: 114
# --------------------------------------------------------------------------------
#
# VARIABLE: Vac T (V)
# NEIGHBOURES (6 out of 6):[113 115 113] \--/ [114 113 113]
# WEIGHTS: [0.33, 0.5, 1, 1, 0.5, 0.33]
# COMPUTED VALUE: 114
# --------------------------------------------------------------------------------
#
# New data (with the filled value(s))
# Date/Time    2020-07-02 17:10:00
# Vac R (V)                    114
# Vac S (V)                    114
# Vac T (V)                    114
# Name: 95538, dtype: object
# --------------------------------------------------------------------------------

# %%
# TASK: A) Analyse and correct the outliers
# VARIABLES: AC voltage values (Vac R/S/T)
# MOTIVATION: Some invalid values (i.e., zero values) have been detected visually (i.e., numerical distribution graphs)
columns = ["Date/Time", "Iac R (A)", "Iac S (A)", "Iac T (A)"]

# Carry out the analysis (and correction) on all the inverters
for inv_name in inv_names[3:4]:
    print("INVERTER NAME:", inv_name, "\n", "-"*80)
    
    # 1A) Detect extreme outliers 
    # Setting threshold: a very high threshold to detect (and correct) only extreme outliers (e.g. zero values)
    # Threshold has been set according to emperical tests (default outlier threshold is equal to 3)
    extreme_vac_outlier = find_outliers(inv_data[inv_name][columns], verbose=True, threshold = 4)
    
    if len(extreme_vac_outlier) == 0:
        print("Oh, no extreme outliers found. That's good.\n")
        continue
        
    print(f"The extreme outliers ({len(extreme_vac_outlier)}) of Vac")
    display(extreme_vac_outlier)

    # 1B) Replacing criterion --> Weighted KNN (k = 6)
    # Identfy the index of the outliers 
    idk_outliers = extreme_vac_outlier.index.tolist()
    list_outliers = idk_outliers.copy()
    
    # Compute and assign the estimated value (weighted average value from its neigbours)
    for idk_outlier in idk_outliers:
        
        # Visualize the outlier and its neighours
        print(f"Outlier (idk: {idk_outlier}) and its neighborhood")
        display(inv_data[inv_name][columns].loc[range(idk_outlier - 3, idk_outlier + 4), :])
        
        # Compute the estimated value and assign the the original dataframe
        inv_data[inv_name].loc[idk_outlier, "Iac R (A)"] = weighted_knn(idk_outlier, list_outliers, "Iac R (A)")
        inv_data[inv_name].loc[idk_outlier, "Iac S (A)"] = weighted_knn(idk_outlier, list_outliers, "Iac S (A)")
        inv_data[inv_name].loc[idk_outlier, "Iac T (A)"] = weighted_knn(idk_outlier, list_outliers, "Iac T (A)")

        # Visualize the outcome
        print("\nNew data (with the filled value(s))")
        display(inv_data[inv_name].loc[idk_outlier][columns])
        print("-" * 80)

# %%
# Irradiance values
columns = ["Date/Time", "Irradiance (W/mq)"]
irr = raw_irr_data[columns].dropna().copy()
irr.reset_index(inplace=True, drop=True)

extreme_outliers = find_outliers(irr, verbose=True, threshold = 5)

if len(extreme_outliers) == 0:
    print("Oh, no outliers found. That's good.\n")
else:
    print(f"The extreme outliers (N = {len(extreme_outliers)}) of the variable 'inverter Temp'")
    display(extreme_outliers)
    
    idk_outliers = extreme_outliers.index.tolist()
    list_outliers = idk_outliers.copy()

    for idk, idk_outlier in enumerate(idk_outliers):
        print(f"Outlier {idk +1}/{len(idk_outliers)}: ({irr.loc[idk_outlier, 'Irradiance (W/mq)']} W/mq)")

        # Visualize the outlier and its neighours
        print(f"\nOutlier (idk: {idk_outlier}) and its neighborhood")
        display(irr.iloc[range(idk_outlier - 3, idk_outlier + 4), :])

        # Compute the estimated value and assign the the original dataframe
        computed_value = weighted_knn(irr, idk_outlier, list_outliers, "Irradiance (W/mq)", verbose=True)
        irr.loc[idk_outlier, "Irradiance (W/mq)"] = computed_value
        print(f"COMPUTED VALUE: {computed_value}\n","-" * 80)

        # Visualize the outcome
        print("\nNew data (with the filled value(s))")
        display(irr.iloc[range(idk_outlier - 3, idk_outlier + 4)][columns])

    print("-" * 40, f"END correction","-" * 40)
irr["Irradiance (W/mq)"] = irr["Irradiance (W/mq)"].astype("Int64")
raw_irr_data = irr
# Out:
# Oh, no outliers found. That's good.

# %%
display(raw_irr_data.describe())
# Out:
#        Irradiance (W/mq)
# count      238796.000000
# mean          186.836517
# std           270.687225
# min             3.000000
# 25%             8.000000
# 50%            22.000000
# 75%           286.000000
# max          1301.000000

# %% [markdown]
# ### Variable: *Inverter Temp*

# %%
# TASK: B) Analyse and correct the outliers
# VARIABLES: Inverter Temp
# MOTIVATION: Some invalid values have been detected visually (i.e., numerical distribution graphs)
# e.g., Detect around 2K observations with a value in the range [65.529 - 65.535 °C]
columns = ["Date/Time", "Inverter temp. (°C)"]

# Carry out the analysis (and correction) on all the inverters
for inv_name in inv_names:#[3:4]:
    print("INVERTER NAME:", inv_name, "\n", "-"*80)
    
    # 1A) Detect extreme outliers 
    # Setting threshold: a very high threshold to detect (and correct) only extreme outliers (e.g. above 1000 °C)
    # Threshold has been set according to emperical tests (default outlier threshold is equal to 3)
    extreme_outliers = find_outliers(inv_data[inv_name][columns], verbose=True, threshold = 4)
    if len(extreme_outliers) == 0:
        print("Oh, no outliers found. That's good.\n")
        continue
        
    print(f"The extreme outliers (N = {len(extreme_outliers)}) of the variable 'inverter Temp'")
    display(extreme_outliers)
    
    # 1B) Replacing criterion --> Weighted KNN (k = 6)
    # Identfy the index of the outliers 
    idk_outliers = extreme_outliers.index.tolist()
    list_outliers = idk_outliers.copy()
    
    # Compute and assign the estimated value (weighted average value from its neigbours)
    for idk, idk_outlier in enumerate(idk_outliers):
        if len(idk_outliers) > 300:
            clear_output(wait=True)
            
        print(f"Outlier {idk +1}/{len(idk_outliers)}: ({inv_data[inv_name].loc[idk_outlier, 'Inverter temp. (°C)']} °C)")
        
        # Visualize the outlier and its neighours
        # print(f"\nOutlier (idk: {idk_outlier}) and its neighborhood")
        # display(inv_data[inv_name][columns].iloc[range(idk_outlier - 3, idk_outlier + 4), :])
        
        # Compute the estimated value and assign the the original dataframe
        computed_value = weighted_knn(inv_data[inv_name][columns], idk_outlier, list_outliers, "Inverter temp. (°C)", 
                                      verbose=False)
        inv_data[inv_name].loc[idk_outlier, "Inverter temp. (°C)"] = computed_value
        print(f"COMPUTED VALUE: {computed_value}\n","-" * 80)
                                                                      
        # Visualize the outcome
        # print("\nNew data (with the filled value(s))")
        # display(inv_data[inv_name].iloc[range(idk_outlier - 3, idk_outlier + 4)][columns])
        
    print("-" * 40, f"END {inv_name}","-" * 40)
# Out:
# Outlier 389/389: (65535 °C)
# COMPUTED VALUE: 12
#  --------------------------------------------------------------------------------
# ---------------------------------------- END INV3 ----------------------------------------
# INVERTER NAME: INV4
#  --------------------------------------------------------------------------------
# Z-score values (threshold: 4)
# MIN: 51.16
# MAX: 51.16
#         Inverter temp. (°C)
# 12917             51.159046
# 12923             51.159046
# 12925             51.159046
# 12926             51.159046
# 12927             51.159046
# 12930             51.159046
# 12943             51.159046
# 12969             51.159046
# 12971             51.159046
# 12973             51.159046
# 12974             51.159046
# 12978             51.159046
# 12979             51.159046
# 12980             51.159046
# 12981             51.159046
# 12982             51.159046
# 12983             51.159046
# 12985             51.159046
# 12986             51.157483
# 12987             51.159046
# 12988             51.159046
# 12990             51.159046
# 12991             51.157483
# 12992             51.159046
# 12993             51.157483
# 12994             51.157483
# 12995             51.157483
# 12996             51.159046
# 12998             51.157483
# 12999             51.159046
# 13000             51.159046
# 13001             51.159046
# 13002             51.159046
# 13003             51.159046
# 13004             51.159046
# 13005             51.159046
# 13007             51.157483
# 13008             51.159046
# 13009             51.159046
# 13010             51.159046
# 13011             51.159046
# 13227             51.159046
# 13867             51.159046
# 18430             51.159046
# 18431             51.159046
# 18769             51.159046
# 78694             51.159046
# 78844             51.159046
# 127251            51.157483
# 127258            51.159046
# 127259            51.159046
# 127262            51.159046
# 127263            51.159046
# 127264            51.159046
# 127265            51.159046
# 127266            51.159046
# 127267            51.159046
# The extreme outliers (N = 57) of the variable 'inverter Temp'
#                  Date/Time  Inverter temp. (°C)
# 12917  2019-01-04 06:55:00                65535
# 12923  2019-01-04 08:00:00                65535
# 12925  2019-01-04 08:20:00                65535
# 12926  2019-01-04 08:30:00                65535
# 12927  2019-01-04 08:40:00                65535
# 12930  2019-01-04 09:15:00                65535
# 12943  2019-01-04 11:35:00                65535
# 12969  2019-01-04 16:35:00                65535
# 12971  2019-01-04 16:55:00                65535
# 12973  2019-01-04 17:15:00                65535
# 12974  2019-01-04 17:25:00                65535
# 12978  2019-01-04 18:10:00                65535
# 12979  2019-01-04 18:20:00                65535
# 12980  2019-01-04 18:30:00                65535
# 12981  2019-01-04 18:40:00                65535
# 12982  2019-01-04 18:50:00                65535
# 12983  2019-01-04 19:00:00                65535
# 12985  2019-01-04 19:25:00                65535
# 12986  2019-01-04 19:35:00                65533
# 12987  2019-01-04 19:45:00                65535
# 12988  2019-01-04 19:55:00                65535
# 12990  2019-01-05 06:00:00                65535
# 12991  2019-01-05 06:10:00                65533
# 12992  2019-01-05 06:25:00                65535
# 12993  2019-01-05 06:35:00                65533
# 12994  2019-01-05 06:45:00                65533
# 12995  2019-01-05 06:55:00                65533
# 12996  2019-01-05 07:05:00                65535
# 12998  2019-01-05 07:25:00                65533
# 12999  2019-01-05 07:35:00                65535
# 13000  2019-01-05 07:50:00                65535
# 13001  2019-01-05 08:00:00                65535
# 13002  2019-01-05 08:10:00                65535
# 13003  2019-01-05 08:20:00                65535
# 13004  2019-01-05 08:30:00                65535
# 13005  2019-01-05 08:40:00                65535
# 13007  2019-01-05 09:00:00                65533
# 13008  2019-01-05 09:15:00                65535
# 13009  2019-01-05 09:25:00                65535
# 13010  2019-01-05 09:35:00                65535
# 13011  2019-01-05 09:45:00                65535
# 13227  2019-01-08 06:30:00                65535
# 13867  2019-01-16 08:10:00                65535
# 18430  2019-02-23 08:40:00                65535
# 18431  2019-02-23 08:45:00                65535
# 18769  2019-02-25 14:15:00                65535
# 78694  2020-03-24 06:20:00                65535
# 78844  2020-03-25 08:30:00                65535
# 127251 2021-02-14 06:05:00                65533
# 127258 2021-02-14 06:45:00                65535
# 127259 2021-02-14 06:50:00                65535
# 127262 2021-02-14 07:05:00                65535
# 127263 2021-02-14 07:10:00                65535
# 127264 2021-02-14 07:20:00                65535
# 127265 2021-02-14 07:25:00                65535
# 127266 2021-02-14 07:30:00                65535
# 127267 2021-02-14 07:35:00                65535
# Outlier 1/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 2/57: (65535 °C)
# COMPUTED VALUE: 2
#  --------------------------------------------------------------------------------
# Outlier 3/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 4/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 5/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 6/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 7/57: (65535 °C)
# COMPUTED VALUE: 2
#  --------------------------------------------------------------------------------
# Outlier 8/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 9/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 10/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 11/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 12/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 13/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 14/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 15/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 16/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 17/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 18/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 19/57: (65533 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 20/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 21/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 22/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 23/57: (65533 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 24/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 25/57: (65533 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 26/57: (65533 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 27/57: (65533 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 28/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 29/57: (65533 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 30/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 31/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 32/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 33/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 34/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 35/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 36/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 37/57: (65533 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 38/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 39/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 40/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 41/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 42/57: (65535 °C)
# COMPUTED VALUE: 2
#  --------------------------------------------------------------------------------
# Outlier 43/57: (65535 °C)
# COMPUTED VALUE: 2
#  --------------------------------------------------------------------------------
# Outlier 44/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 45/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 46/57: (65535 °C)
# COMPUTED VALUE: 2
#  --------------------------------------------------------------------------------
# Outlier 47/57: (65535 °C)
# COMPUTED VALUE: 2
#  --------------------------------------------------------------------------------
# Outlier 48/57: (65535 °C)
# COMPUTED VALUE: 3
#  --------------------------------------------------------------------------------
# Outlier 49/57: (65533 °C)
# COMPUTED VALUE: 4
#  --------------------------------------------------------------------------------
# Outlier 50/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 51/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 52/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 53/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 54/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 55/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 56/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# Outlier 57/57: (65535 °C)
# COMPUTED VALUE: 1
#  --------------------------------------------------------------------------------
# ---------------------------------------- END INV4 ----------------------------------------

# %%
# TASK: B2) Check validity of the outlier correction for the inverter temperature
validity = []
inv_temp_values = []
for inv_name in inv_names:
    inv_temp = inv_data[inv_name]["Inverter temp. (°C)"]
    inv_temp_values.append(inv_temp.rename(index = inv_name))
    
    # Check invalid values
    threshold_inv_temp = 100
    invalid_values = inv_temp.loc[inv_temp >= threshold_inv_temp]
    
    if len(invalid_values) == 0:
        validity.append(True)
    else: 
        validity.append(False)

display(pd.concat(inv_temp_values, axis=1, names =inv_names).describe().round(decimals=2))
if all(validity):
    print(f"The outlier correction is valid for all the {len(inv_names)} inverters!")
else:
    print("There is some error in the outlier conversion")
# Out:
#             INV1       INV2       INV3       INV4
# count  149861.00  149636.00  148146.00  149243.00
# mean       16.70      23.29      19.39      21.61
# std         8.17       7.31       8.46       6.76
# min         1.00       1.00       1.00       1.00
# 25%        11.00      19.00      13.00      17.00
# 50%        17.00      25.00      19.00      23.00
# 75%        23.00      29.00      25.00      27.00
# max        41.00      49.00      45.00      45.00
# The outlier correction is valid for all the 4 inverters!

# %% [markdown]
# # Final task: Save outcomes

# %%
# FINAL TASK: Save the cleared datasets 
saving_folder_name = "Cleaned"
saving_folder_path = path.join(path_file, saving_folder_name)

print("PV System --> ", system_name.upper())

# Create the saving folder
if not path.exists(saving_folder_path):
    makedirs(saving_folder_path)
    print(f"A new saving folder has been created: {saving_folder_path}\n")
    
# Save the files as CSV files 
for inv_name in inv_names:
    file_name = f"cleaned_{inv_name.upper()}_data.csv"
    inv_data[inv_name].to_csv(path.join(saving_folder_path, file_name), index=False)
    print(f"The cleaned data for '{inv_name}' has been saved.")

raw_irr_data.to_csv(path.join(saving_folder_path, "raw_irr_data.csv"), index=False) 
print("\nThe cleaned data for the 'irradiance values' has been saved.")
# Out:
# PV System -->  EMI
# The cleaned data for 'INV1' has been saved.
# The cleaned data for 'INV2' has been saved.
# The cleaned data for 'INV3' has been saved.
# The cleaned data for 'INV4' has been saved.
#
# The cleaned data for the 'irradiance values' has been saved.
