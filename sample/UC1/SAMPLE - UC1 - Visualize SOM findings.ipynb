# %%
from sys import path
if '..' not in path:
    path.insert(0, '..')

# %%
import _library.som_outcome_utils as som_outcome_utils
from _library.fault_utils import load_priorities
import _library.utils as utils
import sys
import numpy as np
import pandas as pd
from os import path, makedirs
from collections import defaultdict, Counter
from tabulate import tabulate

# %%
# %cd /mnt/data/vieri/projects/SAMPLE/
# Out:
# /mnt/data/vieri/projects/SAMPLE

# %% [markdown]
# # The PV systems

# %%
print(utils.SYSTEM_NAMES, "-->", utils.SUBFOLDERS)
# --- 0 ---------- 1 ---------- 2 --------- 3 ---------- 4 -------- (for ALL) ------- (For SOL 1, SOL 2 & GALATINA) ---------
# Out:
# ['Binetto 1', 'Binetto 2', 'Soleto 1', 'Soleto 2', 'Galatina'] --> ['Cleaned', '1-hour sampling', '1-hour averaged sampling', 'Residuals', 'Residuals_analytical', 'Failure events', None]

# %% [markdown]
# # Select the PV systems and its path

# %%
system_name = utils.SYSTEM_NAMES[4]
system_path = path.join("data", system_name.upper(), system_name.upper())
print("PV SYSTEM -->", system_name.upper())
# Out:
# PV SYSTEM --> GALATINA

# %% [markdown]
# # A) Visualize findings of the GRID SERCH
# **PRE-PROCESSING STEPS**: 1hour_averaged_fullLinReg_detrended

# %% [markdown]
# ## A.1) Select the version of the grid serch

# %%
file_versions = [
    # [0] -- FINAL GRID SEARCH - with shuffling
    "1hour_averaged_fullReg_detrended",
    # [1] -- AutoEncoder
    "L2_N16", 
    # [1] -- FINAL GRID SEARCH - with shuffling
    "1hour_averaged_fullReg_detrended_Shuffling",
    # [2] -- FINAL GRID SEARCH - without shuffling
    "1hour_averaged_fullReg_detrended_noShuffle",
    # [3] -- OLD outcomes
    "old", 
    # [5:7]-------------- Test hyperparameter behaviours ------------------------
    "1hour_averaged_reg_FixedEpoch", "1hour_averaged_sigma_reg", "1hour_averaged_dimGrid_reg" 
]
file_version = file_versions[0]
print(f"VERSION: {file_version}")
# Out:
# VERSION: 1hour_averaged_fullReg_detrended

# %% [markdown]
# ## A.2 ) Load the CSV file

# %%
dataset_type = "folds"

# %%
variable_to_sort_out = "f1"

# %%
folder_path = path.join(system_path, "SOMs", "Trained SOM")

inv_som_performance = dict()
for inv_number in [1, 2, 3, 4]:
    
    # Paths and file name
    file_name = f"INV{inv_number}_" + f"som_{dataset_type}_performance_" + file_version + "_ALT" + ".txt"
    file_path = path.join(folder_path, file_name)
    
    if not path.exists(file_path):
        print(f"\n[INV {inv_number}] ISSUE: File not found. Sorry :/")
        continue

    # Read and save the som perfomance of each inverter
    perfomance_list = som_outcome_utils.read_som_perfomance_file(file_path, variable_to_sort_out)
    som_perfomance, best_configurations, best_score_performance = perfomance_list
    
    inv_som_performance[f"INV{inv_number}"] = {
        "perfomance": som_perfomance, 
        "best_configs": best_configurations, 
        "best_scores": best_score_performance
    }
    
    print(f"[INV {inv_number}] The SOM perfomance has been loaded: '{file_name}'")
# Out:
# [INV 1] The SOM perfomance has been loaded: 'INV1_som_folds_performance_1hour_averaged_fullReg_detrended_ALT.txt'
# [INV 2] The SOM perfomance has been loaded: 'INV2_som_folds_performance_1hour_averaged_fullReg_detrended_ALT.txt'
# [INV 3] The SOM perfomance has been loaded: 'INV3_som_folds_performance_1hour_averaged_fullReg_detrended_ALT.txt'
# [INV 4] The SOM perfomance has been loaded: 'INV4_som_folds_performance_1hour_averaged_fullReg_detrended_ALT.txt'

# %% [markdown]
# ## A.3) Create the saving folder

# %%
save_to_file = {"view1": True, "view2": True}

# %%
saving_folder_path = path.join(system_path, "SOMs", "Hyperparameter behaviour", file_version)
log_folder_name = "Best Configs"
    
# Create the sub-folder
if save_to_file["view1"]:     
    log_folder_path = path.join(saving_folder_path, log_folder_name)
    
    if not path.exists(log_folder_path):
        makedirs(log_folder_path)
    
    print(f"The findings will be saved in a txt file...\n(folder: {log_folder_path}).")
else:
    print("Enjoy the awesome findings here :)")
# Out:
# The findings will be saved in a txt file...
# (folder: data/GALATINA/GALATINA/SOMs/Hyperparameter behaviour/1hour_averaged_fullReg_detrended/Best Configs).

# %% [markdown]
# ### A.4) [VIEW 1] Visualize the perfomance

# %%
inv_to_visualize = -1

# %%
top_config_to_visualize = -1

# %%
console_stdout = sys.stdout 

# Visualize the findings
for inv_name, som_perfomance in inv_som_performance.items():
    if inv_to_visualize != -1:
        if inv_name != f"INV{inv_to_visualize}":
            continue
            
    # Retrieve the ordered list of the configs       
    inv_best_configs = som_perfomance["best_configs"]
    best_quantiz, best_f1, best_recall, best_precision = som_perfomance["best_scores"]
    
    # LOG FILE (txt file) 
    if save_to_file["view1"]: 
        log_file_name = f"{inv_name}_top_som_{dataset_type}_performance"+ ".txt"
        log_file_path = path.join(log_folder_path, log_file_name)
        log_file = open(log_file_path,  mode = "w+")
        
        print(f"[{inv_name}] The findings will be saved in a txt file (i.e., ./{log_folder_name}/{log_file_name})")
        sys.stdout = log_file
    
    print("-" * 15 + f" [{system_name}] ({inv_name}) "\
          f"{'TOP' + top_config_to_visualize if top_config_to_visualize != -1 else 'ALL'} "\
          f"CONFIGURATIONS (Version: {file_version}) " + "-" * 15, "\n")
    
    if top_config_to_visualize != -1:
        inv_best_configs[:top_config_to_visualize]
    
    for idk, (config, metrics) in enumerate(inv_best_configs):
        print(f"TOP {idk + 1}: " + config + "\n" + "-" * 70)

        # Retrieve all the metrics 
        quantization_error, f1_score, recall, precision, fold_f1_scores, comp_times = metrics
        
        # Compute the deltas from the best scores
        delta_quantization = (quantization_error - best_quantiz)
        delta_f1 = (f1_score - best_f1) * 100
        delta_recall = (recall - best_recall) * 100
        delta_precision = (precision - best_precision) * 100
        
        # Visualize the perfomance
        print(f"--> F1 score: {f1_score} ({', '.join([str(score) for idk, score in enumerate(fold_f1_scores)])})"\
              f" {'--> delta from the best config: ' + str(round(delta_f1, 2)) +' %' if abs(delta_f1) > 0 else ''}")
        print(f"--> RECALL: {recall} {'--> delta from the best config: ' + str(round(delta_recall, 2)) +' %' if abs(delta_recall) > 0 else ''}")
        print(f"--> PRECISION: {precision} "\
              f"{'--> delta from the best config: ' + str(round(delta_precision, 2)) +' %' if abs(delta_precision) > 0 else ''}")
        print(f"--> QUANTIZATION ERROR: {quantization_error} "\
              f"{'--> delta from the best config: ' + str(round(delta_quantization, 4)) if abs(delta_quantization) > 0 else ''}")
        print(f"--> {comp_times[0]} --> {comp_times[1]}\n")

    if save_to_file["view1"]:
        sys.stdout.close()
        sys.stdout = console_stdout
# Out:
# [INV1] The findings will be saved in a txt file (i.e., ./Best Configs/INV1_top_som_folds_performance.txt)
# [INV2] The findings will be saved in a txt file (i.e., ./Best Configs/INV2_top_som_folds_performance.txt)
# [INV3] The findings will be saved in a txt file (i.e., ./Best Configs/INV3_top_som_folds_performance.txt)
# [INV4] The findings will be saved in a txt file (i.e., ./Best Configs/INV4_top_som_folds_performance.txt)

# %% [markdown]
# ## A.5) Weighted perfomance: Find the best SOM configuration across all the inverters

# %% [markdown]
# ### A.5.1) Set the threshold for selecting the best som configurations
# 1. **[0:1]**: Consider only the configuration included in the 'top k % '
# 2. **(-1)**: Consider all the configurations

# %%
threshold_top_configs = [-1, 0.3]

# %% [markdown]
# ### A.5.2) Merge and weigh all the som configuration

# %%
list_perfomance = dict()

for threshold in threshold_top_configs:
    list_perfomance[threshold] = som_outcome_utils.merge_and_weigh_som_perfomance(inv_som_performance, threshold)
# Out:
# [INV1] Reading and merging som perfomance  (i.e., 1540 configs.)
# [INV2] Reading and merging som perfomance  (i.e., 1540 configs.)
# [INV3] Reading and merging som perfomance  (i.e., 1540 configs.)
# [INV4] Reading and merging som perfomance  (i.e., 1540 configs.)
#
# Consider only the configuration included in the 'top 30%
# --------------------------------------------------------------------------------
# [INV1] Reading and merging som perfomance with threshold 30% (i.e., 1540 configs.)
# [INV2] Reading and merging som perfomance with threshold 30% (i.e., 1540 configs.)
# [INV3] Reading and merging som perfomance with threshold 30% (i.e., 1540 configs.)
# [INV4] Reading and merging som perfomance with threshold 30% (i.e., 1540 configs.)

# %% [markdown]
# ### A.5.3) Compute an avereage score between all the f1 score retrieved from the inverters

# %%
for threshold in threshold_top_configs:
    weighted_som_perfomance = list_perfomance[threshold]
    list_perfomance[threshold] = som_outcome_utils.compute_average_scores(weighted_som_perfomance, threshold)

# %% [markdown]
# ### A.5.4) [View 2] Visualize the weighted som configurations

# %%
for threshold in threshold_top_configs:
    weighted_som_perfomance = list_perfomance[threshold]
    
    # Create the sub-folder
    allPerfomance_folder_path = path.join(saving_folder_path, log_folder_name, "Weighted perfomance")
    if not path.exists(allPerfomance_folder_path):
        makedirs(allPerfomance_folder_path)
        
    labels = ["INV1", "INV2", "INV3", "INV4"]
    som_outcome_utils.visualize_weighted_som_configurations(weighted_som_perfomance, threshold, system_name, dataset_type,
                                                            labels, file_version, allPerfomance_folder_path,
                                                            save_to_file["view2"])
# Out:
# [Galatina] The findings will be saved in a txt file (i.e., weighted_som_folds_performance.txt)
# [Galatina] The findings will be saved in a txt file (i.e., weighted_som_folds_performance_top30%.txt)

# %% [markdown]
# ## A.5bis) Weighted perfomance: Find the best SOM configuration across all the PV systems [View 2.bis]

# %%
system_to_visualize = utils.SYSTEM_NAMES[2:5]

# %%
for threshold in threshold_top_configs:
    weighted_general_som_perfomance = defaultdict(list)
    labels = []
    
    print(f"VERSION: SELECTING '{'THE TOP: '+ str(threshold*100) + '%' if threshold > 0 else 'ALL'} CONFIGS'")
    for pv_system_name in system_to_visualize:
        print("\n" + "-" * 30 + f" PV SYSTEM: {pv_system_name} " + "-" * 30 )

        # 0) FOLDERS
        pv_system_folder = path.join("data", pv_system_name.upper(), pv_system_name.upper())
        log_file_folder = path.join(pv_system_folder, "SOMs", "Trained SOM")

        # 1) READ THE CSV FILES of all the PV system
        print("-" * 20 + " (A.1) LOADING THE CSV FILES " +"-" * 20)
        pv_inv_som_performance = dict()
        for inv_number in [1, 2, 3, 4]:
            
            # Paths and file name
            perfomance_file_name = f"INV{inv_number}_" + f"som_{dataset_type}_performance_" + file_version + ".txt"
            perfomance_file_path = path.join(log_file_folder, perfomance_file_name)

            if not path.exists(perfomance_file_path):
                print(f"\n[INV {inv_number}] ISSUE: File not found. Sorry :/")
                continue

            # Read and save the som perfomance of each inverter
            som_perfomance, best_configurations, *_ = som_outcome_utils.read_som_perfomance_file(perfomance_file_path, 
                                                                                                 variable_to_sort_out = "f1")
            pv_inv_som_performance[f"INV{inv_number}"] = {"perfomance": som_perfomance, "best_configs": best_configurations}
            print(f"[INV{inv_number}] The SOM perfomance has been loaded")
            
            name_parts = pv_system_name.split(" ")
            if len(name_parts) == 1:
                simplified_sys_name = pv_system_name[:3]
            else:
                simplified_sys_name = name_parts[0][:3] + name_parts[1]
            labels.append(f"{simplified_sys_name}:INV{inv_number}")

        # 2.1) Get the normalized f1 scores for the pv system
        print("\n" + "-" * 20 + " (A.2) Merging inverter perfomance " +"-" * 20)
        weighted_pvSystem_som_perfomance = som_outcome_utils.merge_and_weigh_som_perfomance(pv_inv_som_performance, threshold)

        # 2.2) Save the normalized scores for each pv system
        if not weighted_general_som_perfomance:
            weighted_general_som_perfomance = weighted_pvSystem_som_perfomance
        else:
            for config, score_list in weighted_pvSystem_som_perfomance.items():
                weighted_general_som_perfomance[config].extend(score_list)

    # 3) Compute the average values
    print("\n" + "-" * 20 + " (B) Computing the average score values " +"-" * 20)
    avg_general_som_perfomance = som_outcome_utils.compute_average_scores(weighted_general_som_perfomance, threshold)

    # 4) Generate the ranked list
    # 4.1) Create the folder
    system_label = "All systems" 
    overall_perfomance_folder_path = path.join("data", "Overall SOM perfomance")
    if not path.exists(overall_perfomance_folder_path):
        makedirs(overall_perfomance_folder_path)
        
    # 4.2) Generate the list
    print("\n" + "-" * 20 + " (C) Generated the ranked list " +"-" * 20)
    som_outcome_utils.visualize_weighted_som_configurations(avg_general_som_perfomance, threshold, system_label, dataset_type,
                                                            labels, file_version, overall_perfomance_folder_path, 
                                                            save_to_file = True)
# Out:
# VERSION: SELECTING 'ALL CONFIGS'
#
# ------------------------------ PV SYSTEM: Soleto 1 ------------------------------
# -------------------- (A.1) LOADING THE CSV FILES --------------------
# [INV1] The SOM perfomance has been loaded
# [INV2] The SOM perfomance has been loaded
# [INV3] The SOM perfomance has been loaded
# [INV4] The SOM perfomance has been loaded
#
# -------------------- (A.2) Merging inverter perfomance --------------------
# [INV1] Reading and merging som perfomance  (i.e., 1540 configs.)
# [INV2] Reading and merging som perfomance  (i.e., 1540 configs.)
# [INV3] Reading and merging som perfomance  (i.e., 1540 configs.)
# [INV4] Reading and merging som perfomance  (i.e., 1540 configs.)
#
# ------------------------------ PV SYSTEM: Soleto 2 ------------------------------
# -------------------- (A.1) LOADING THE CSV FILES --------------------
# [INV1] The SOM perfomance has been loaded
# [INV2] The SOM perfomance has been loaded
#
# [INV 3] ISSUE: File not found. Sorry :/
#
# [INV 4] ISSUE: File not found. Sorry :/
#
# -------------------- (A.2) Merging inverter perfomance --------------------
# [INV1] Reading and merging som perfomance  (i.e., 1540 configs.)
# [INV2] Reading and merging som perfomance  (i.e., 1540 configs.)
#
# ------------------------------ PV SYSTEM: Galatina ------------------------------
# -------------------- (A.1) LOADING THE CSV FILES --------------------
# [INV1] The SOM perfomance has been loaded
# [INV2] The SOM perfomance has been loaded
# [INV3] The SOM perfomance has been loaded
# [INV4] The SOM perfomance has been loaded
#
# -------------------- (A.2) Merging inverter perfomance --------------------
# [INV1] Reading and merging som perfomance  (i.e., 1540 configs.)
# [INV2] Reading and merging som perfomance  (i.e., 1540 configs.)
# [INV3] Reading and merging som perfomance  (i.e., 1540 configs.)
# [INV4] Reading and merging som perfomance  (i.e., 1540 configs.)
#
# -------------------- (B) Computing the average score values --------------------
#
# -------------------- (C) Generated the ranked list --------------------
# [All systems] The findings will be saved in a txt file (i.e., weighted_som_folds_performance.txt)
# VERSION: SELECTING 'THE TOP: 30.0% CONFIGS'
#
# ------------------------------ PV SYSTEM: Soleto 1 ------------------------------
# -------------------- (A.1) LOADING THE CSV FILES --------------------
# [INV1] The SOM perfomance has been loaded
# [INV2] The SOM perfomance has been loaded
# [INV3] The SOM perfomance has been loaded
# [INV4] The SOM perfomance has been loaded
#
# -------------------- (A.2) Merging inverter perfomance --------------------
#
# Consider only the configuration included in the 'top 30%
# --------------------------------------------------------------------------------
# [INV1] Reading and merging som perfomance with threshold 30% (i.e., 1540 configs.)
# [INV2] Reading and merging som perfomance with threshold 30% (i.e., 1540 configs.)
# [INV3] Reading and merging som perfomance with threshold 30% (i.e., 1540 configs.)
# [INV4] Reading and merging som perfomance with threshold 30% (i.e., 1540 configs.)
#
# ------------------------------ PV SYSTEM: Soleto 2 ------------------------------
# -------------------- (A.1) LOADING THE CSV FILES --------------------
# [INV1] The SOM perfomance has been loaded
# [INV2] The SOM perfomance has been loaded
#
# [INV 3] ISSUE: File not found. Sorry :/
#
# [INV 4] ISSUE: File not found. Sorry :/
#
# -------------------- (A.2) Merging inverter perfomance --------------------
#
# Consider only the configuration included in the 'top 30%
# --------------------------------------------------------------------------------
# [INV1] Reading and merging som perfomance with threshold 30% (i.e., 1540 configs.)
# [INV2] Reading and merging som perfomance with threshold 30% (i.e., 1540 configs.)
#
# ------------------------------ PV SYSTEM: Galatina ------------------------------
# -------------------- (A.1) LOADING THE CSV FILES --------------------
# [INV1] The SOM perfomance has been loaded
# [INV2] The SOM perfomance has been loaded
# [INV3] The SOM perfomance has been loaded
# [INV4] The SOM perfomance has been loaded
#
# -------------------- (A.2) Merging inverter perfomance --------------------
#
# Consider only the configuration included in the 'top 30%
# --------------------------------------------------------------------------------
# [INV1] Reading and merging som perfomance with threshold 30% (i.e., 1540 configs.)
# [INV2] Reading and merging som perfomance with threshold 30% (i.e., 1540 configs.)
# [INV3] Reading and merging som perfomance with threshold 30% (i.e., 1540 configs.)
# [INV4] Reading and merging som perfomance with threshold 30% (i.e., 1540 configs.)
#
# -------------------- (B) Computing the average score values --------------------
#
# -------------------- (C) Generated the ranked list --------------------
# [All systems] The findings will be saved in a txt file (i.e., weighted_som_folds_performance_top30%.txt)

# %% [markdown]
# ## A.6) Visualize the findings using some graphs

# %% [markdown]
# ### A.6.0) Some useful functions

# %% [markdown]
# ### A.6.1)  [View 3 ] Generate and visualize the graphs

# %%
skip_this_step = True

# %%
visualize_graphs = False

# %%
if not skip_this_step:
    for inv_name in inv_som_performance.keys():
        print("-" * 30 + f" {inv_name} " + "-" * 30)

        # Retrieve the som perfomance for each inverter
        som_perfomance = inv_som_performance[inv_name]["perfomance"]
        som_perfomance = som_perfomance.drop(columns = ["Fold F1 scores"])

        # Visualize the columns (i.e., metrics) available as well as the som configurations computed with the grid search
        columns = som_perfomance.columns.tolist()
        print(f"COLUMNS AVAILABLE ({len(columns)}): {', '.join(columns)}")
        print(f"CONFIGURATIONS TESTED OUT: {len(som_perfomance)}\n")

        # Create, visualze and save the graph
        som_outcome_utils.plot_analysis(som_perfomance, system_name, inv_name, saving_folder_path, dataset_type,
                                        var_panels = "Function", var_graphColums = "Dim grid", 
                                        var_graphRows = "Dim grid",
                                        verbose = visualize_graphs)
        print("-" * 66 + "\n")
    print("\n" + "-" * 50 + "\nGraph generation has been finished. Nice :)\n" + "-" * 50)
else:
    print("This visualization has been skipped. Sorry :/")
# Out:
# This visualization has been skipped. Sorry :/

# %% [markdown]
# # B) Comparison of the combinations of pre-processing steps

# %%
consider_only_failure_starts = False

# %% [markdown]
# ## B.1.1) SELECT: the 'SOM versions'

# %%
SYSTEM_SOM_CONFIGS = {
    "Soleto 1": {
        "INV1": [
            "16grid_6Kepoch_0.001lr_9sigma_gaussianFunc", # TOP 1
            "18grid_5Kepoch_0.001lr_1sigma_gaussianFunc", # TOP 1
            "20grid_6Kepoch_0.001lr_1sigma_gaussianFunc" # TOP 1
        ],  
        "INV2": [
            "12grid_5Kepoch_0.001lr_1sigma_gaussianFunc", # TOP 11 (F1: - 6% from its TOP 1)
            "18grid_5Kepoch_0.001lr_1sigma_gaussianFunc", # TOP 1
            "20grid_6Kepoch_0.001lr_1sigma_gaussianFunc" # TOP 1
        ],
        "INV3": [
            "10grid_6Kepoch_0.001lr_1sigma_gaussianFunc", # TOP 1
            "18grid_5Kepoch_0.001lr_1sigma_gaussianFunc", # TOP 1
            "20grid_6Kepoch_0.001lr_1sigma_gaussianFunc" # TOP 1
        ],
        "INV4": [
            "18grid_5Kepoch_0.001lr_1sigma_gaussianFunc", # TOP 1
            "18grid_5Kepoch_0.001lr_1sigma_gaussianFunc", # TOP 1
            "20grid_6Kepoch_0.001lr_1sigma_gaussianFunc" # TOP 1
        ]
    },
    "Soleto 2": {
        "INV1": [
            "12grid_30Kepoch_0.001lr_1sigma_gaussianFunc", # TOP 1
            "18grid_7Kepoch_0.001lr_6sigma_gaussianFunc", # TOP 1 (AVG)
            "20grid_6Kepoch_0.001lr_1sigma_gaussianFunc" # TOP 1
        ],  
        "INV2": [
            "28grid_20Kepoch_0.01lr_10sigma_gaussianFunc", # TOP 2 (F1: -0.16 %)
            "18grid_7Kepoch_0.001lr_6sigma_gaussianFunc", # TOP 1 (AVG)
            "20grid_6Kepoch_0.001lr_1sigma_gaussianFunc" # TOP 1
        ],
    },
    "Galatina": {
        "INV1": [
            "26grid_10Kepoch_0.01lr_2sigma_gaussianFunc",  # TOP 1
            "26grid_8Kepoch_0.01lr_4sigma_gaussianFunc", # TOP 1 (AVG)
            "20grid_6Kepoch_0.001lr_1sigma_gaussianFunc" # TOP 1
        ],  
        "INV2":  [
            "30grid_30Kepoch_0.01lr_1sigma_gaussianFunc", # TOP 3 (F1: -1.65 %)
            "26grid_8Kepoch_0.01lr_4sigma_gaussianFunc", # TOP 1 (AVG)
            "20grid_6Kepoch_0.001lr_1sigma_gaussianFunc" # TOP 1
        ],
        "INV3":  [
            "26grid_2Kepoch_0.01lr_10sigma_gaussianFunc", # TOP 1
            "26grid_8Kepoch_0.01lr_4sigma_gaussianFunc", # TOP 1 (AVG)
            "20grid_6Kepoch_0.001lr_1sigma_gaussianFunc" # TOP 1
        ],
        "INV4":  [
            "30grid_8Kepoch_0.01lr_5sigma_gaussianFunc", # TOP 2 (F1: -17.22 %)
            "26grid_8Kepoch_0.01lr_4sigma_gaussianFunc", # TOP 1 (AVG)
            "20grid_6Kepoch_0.001lr_1sigma_gaussianFunc" # TOP 1
        ]
    }
}
som_configs = SYSTEM_SOM_CONFIGS[system_name]

# %% [markdown]
# # Alternative metrics (i.e., considering only the starting timestamps of failure events)

# %%
if consider_only_failure_starts:
    SYSTEM_SOM_CONFIGS = {
        "Soleto 1": {
            "INV1": [
                "30grid_3Kepoch_0.01lr_10sigma_gaussianFunc",
                "24grid_2Kepoch_0.01lr_10sigma_gaussianFunc", 
                "" 
            ],  
            "INV2": [
                "22grid_2Kepoch_0.01lr_9sigma_gaussianFunc",
                "24grid_2Kepoch_0.01lr_10sigma_gaussianFunc", 
                "" 
            ],
            "INV3": [
                "18grid_7Kepoch_0.001lr_1sigma_gaussianFunc",
                "24grid_2Kepoch_0.01lr_10sigma_gaussianFunc", 
                "" 
            ],
            "INV4": [
                "22grid_2Kepoch_0.01lr_8sigma_gaussianFunc",
                "24grid_2Kepoch_0.01lr_10sigma_gaussianFunc", 
                "" 
            ]
        },
        "Soleto 2": {
            "INV1": [
                "14grid_4Kepoch_0.001lr_1sigma_gaussianFunc",
                "12grid_4Kepoch_0.001lr_2sigma_gaussianFunc", 
                "" 
            ],  
            "INV2": [
                "10grid_10Kepoch_0.001lr_2sigma_gaussianFunc",
                "12grid_4Kepoch_0.001lr_2sigma_gaussianFunc", 
                "" 
            ],
        },
        "Galatina": {
            "INV1": [
                "26grid_8Kepoch_0.01lr_4sigma_gaussianFunc",
                "12grid_3Kepoch_0.001lr_6sigma_gaussianFunc", 
                "" 
            ],  
            "INV2":  [
                "16grid_9Kepoch_0.001lr_1sigma_gaussianFunc",
                "12grid_3Kepoch_0.001lr_6sigma_gaussianFunc", 
                "" 
            ],
            "INV3":  [
                "14grid_6Kepoch_0.001lr_8sigma_gaussianFunc",
                "12grid_3Kepoch_0.001lr_6sigma_gaussianFunc", 
                "" 
            ],
            "INV4":  [
                "10grid_4Kepoch_0.001lr_7sigma_gaussianFunc",
                "12grid_3Kepoch_0.001lr_6sigma_gaussianFunc", 
                "" 
            ]
        }
    }
    som_configs = SYSTEM_SOM_CONFIGS[system_name]
else:
    print(f"[{system_name}] using the tradictional approach")
# Out:
# [Galatina] using the tradictional approach

# %% [markdown]
# ## B.1.2) SELECT: the combination of pre-processing steps

# %%
pre_steps_configs = ["1hour_averaged_fullReg_detrended"]
print(f"COMBINATIONS CHOOSEN: {len(pre_steps_configs)}\n" + "-" * 60)
print('\n'.join([f"({idk +1}) " + ' || '.join(config.split('_')) for idk, config in enumerate(pre_steps_configs)]))
# Out:
# COMBINATIONS CHOOSEN: 1
# ------------------------------------------------------------
# (1) 1hour || averaged || fullReg || detrended

# %% [markdown]
# ## B.2) Load all the CSV files

# %%
methods = ["SOMs", "AutoEncoder"]
selected_method = methods[0]
if selected_method == methods[1]:
    ae_config = 'L2_N16'
    print(f"METHOD: '{selected_method}: {ae_config}'")
else:
    print(f"METHOD: '{selected_method}")
# Out:
# METHOD: 'SOMs

# %%
folder_path = path.join(system_path, selected_method, "Metrics")

# %%
num_selected_configs = len(som_configs[list(som_configs.keys())[0]])
test_names = [
    f"TEST(0): best_for_inverter ({system_name})",
    f"TEST(1): averaged_across_inverter ({system_name})",
    "TEST(2): averaged_across_pvSystems"
]

# %%
only_failure_starts_prefix = 'ALT2'

# %%
all_system_configs_available = dict()
for idk_config in range(num_selected_configs):
    test_name = test_names[idk_config]
    print("-" * 20 + f"Loading the metrics... [{test_name}]" + "-" * 20 + "\n")

    # Load each inverter data
    df_inv_metrics = dict()
    for inv_name in som_configs.keys():
        som_config = som_configs[inv_name][idk_config]

        # Load each configuration selected
        df_metrics_configs = dict()
        for config in pre_steps_configs:

            # File path
            if selected_method == methods[0]:
                full_config = som_config + "_" + config
            else: 
                full_config = ae_config 
                
            # Create the file name
            file_name = f"{inv_name}_performance"
            if consider_only_failure_starts:
                file_name += "_" + only_failure_starts_prefix
            file_path = path.join(folder_path, full_config,file_name + ".csv" )

            # (Try to) read the csv file with the metrics
            try:
                df_metrics_configs[config] = pd.read_csv(file_path, index_col = 0)
                df_inv_metrics[inv_name] = df_metrics_configs
                
                #print(f"{inv_name}: the config '{config}' has been loaded successfully.")
            except FileNotFoundError:
                print(f"ISSUE ({inv_name}): File not found!\n--> The configuration {config.split('_')} \n    with the SOM: "\
                      f"{som_config.split('_')}'\n")

        print(f"---------- {inv_name}: Hey, {len(df_metrics_configs.keys())} configurations have been loaded. --------------\n")
    all_system_configs_available[test_name] = df_inv_metrics
# Out:
# --------------------Loading the metrics... [TEST(0): best_for_inverter (Galatina)]--------------------
#
# ---------- INV1: Hey, 1 configurations have been loaded. --------------
#
# ---------- INV2: Hey, 1 configurations have been loaded. --------------
#
# ---------- INV3: Hey, 1 configurations have been loaded. --------------
#
# ---------- INV4: Hey, 1 configurations have been loaded. --------------
#
# --------------------Loading the metrics... [TEST(1): averaged_across_inverter (Galatina)]--------------------
#
# ---------- INV1: Hey, 1 configurations have been loaded. --------------
#
# ---------- INV2: Hey, 1 configurations have been loaded. --------------
#
# ---------- INV3: Hey, 1 configurations have been loaded. --------------
#
# ---------- INV4: Hey, 1 configurations have been loaded. --------------
#
# --------------------Loading the metrics... [TEST(2): averaged_across_pvSystems]--------------------
#
# ---------- INV1: Hey, 1 configurations have been loaded. --------------
#
# ---------- INV2: Hey, 1 configurations have been loaded. --------------
#
# ---------- INV3: Hey, 1 configurations have been loaded. --------------
#
# ---------- INV4: Hey, 1 configurations have been loaded. --------------

# %%
configs_available = list(all_system_configs_available.keys())
print(f"SYSTEM CONFIGS LOADED ({len(configs_available)})\n" + "-" * 40)
print('\n'.join([f'{idk + 1}) {config}'for idk, config in enumerate(configs_available)]))
# Out:
# SYSTEM CONFIGS LOADED (3)
# ----------------------------------------
# 1) TEST(0): best_for_inverter (Galatina)
# 2) TEST(1): averaged_across_inverter (Galatina)
# 3) TEST(2): averaged_across_pvSystems

# %% [markdown]
# ## B.3) [View 4] Visualize a filtered metrics dataframe
# - *Fault profiles* (default: only "General faults")
# - *prediction window* of the warnings (default: 7 days in advance)

# %%
save_metrics_to_file = False

# %% [markdown]
# ### B.3.1) SET: 'Prediction window' to visualize(i.e., days in advance of the warnings)

# %%
prediction_window = 7

# %% [markdown]
# ### B.3.2) SET: 'Fault profiles' to visualize

# %%
fault_profiles_available = [
    ["General Fault", "Log - High"],
    ['General Fault']
]

# %% [markdown]
# ### B.3.3) Create the saving sub-folder

# %%
perfomance_folder_name = 'Perfomance'

# %%
perfomance_saving_folder = path.join(saving_folder_path, perfomance_folder_name)

if save_metrics_to_file:
    if not path.exists(perfomance_saving_folder):
        makedirs(perfomance_saving_folder)
        print(f"The folder '{perfomance_folder_name}' has been created")

# %% [markdown]
# ## B.4) Comparision between different combinations of pre-processing steps

# %%
def visualize_perfomance(fault_profile, visualize_details = True):
    console_stdout = sys.stdout
    
    inv_ranked_configs_faultProfiles = dict()
    fault_anticipation = dict()
    inv_best_perfomance = dict()
    
    if save_metrics_to_file:
        profile_name = '_'.join([''.join(word.capitalize() for word in profile.replace('-', '').split(' ')) 
                                 for profile in fault_profile])
        file_name = f"perfomance_configs_{profile_name}.txt"
        if consider_only_failure_starts:
            file_name += "_" + only_failure_starts_prefix
        log_file_path = path.join(perfomance_saving_folder, file_name + ".txt")
        log_file = open(log_file_path,  mode="w+")
        print(f"The findings will be saved in a txt file --> {file_name}\n(folder: {perfomance_saving_folder}).\n")
        sys.stdout = log_file
     
    for inv_name in df_inv_metrics.keys():
        metrics_configs = df_inv_metrics[inv_name]

        print("\n" + "-" * 50 + f" PV SYSTEM: {system_name} " + "-" * 50)
        print("\n" + "-" * 45 + f" SOM CONFIGURATION " + "-" * 45)
        configs_pairs = list(zip(test_names, som_configs[inv_name][:num_selected_configs]))
        print('\n'.join([f"({idk + 1}) {config_type.upper()} --> { ' || '.join(config.split('_'))}\n" +"-" * 100
                         for idk, (config_type, config) in enumerate(configs_pairs)]))
        print("\n\n" + "-" * 30 + f" INVERTER: N°{inv_name[-1:]} (FAULT PROFILE: {' || '.join(fault_profile)})" + "-" * 30)
        
        # Visualize the metrics
        outcomes = som_outcome_utils.visualize_metrics(metrics_configs, fault_profile, fault_profiles_available,
                                                       prediction_window, save_metrics_to_file, 
                                                       verbose = visualize_details)
        inv_ranked_configs, inv_fault_anticipation, inv_best_perfomance[inv_name] = outcomes

        
        #  Save and visualize anticipation
        if inv_fault_anticipation:
            fault_anticipation[inv_name] = inv_fault_anticipation

    # Save it 
    key_name = "_".join([item.replace(" ", "") for item in fault_profile])
    inv_ranked_configs_faultProfiles[key_name] = inv_ranked_configs 

    if save_metrics_to_file:       
        sys.stdout.close()
        sys.stdout = console_stdout
        
    return inv_ranked_configs_faultProfiles, fault_anticipation, inv_best_perfomance

# %%
df_inv_metrics = dict()            
for test_available in all_system_configs_available.keys():
    print("\n"+"-" * 30 + f" {test_available} " + "-" * 30)
    system_metrics = all_system_configs_available[test_available]
    
    if len(system_metrics.keys()) == 0:
        print("-" * 10 + " WARNING: There are not configurations available for this test " + "-" * 10)
        continue
        
    for inv_name in system_metrics.keys():
        print("-" * 10 + f" [{inv_name}]  Merging the metrics from all the SOM configs " + "-" * 10)
        inv_metrics = system_metrics[inv_name]
        
        renamed_dict = dict()
        for config in inv_metrics.keys():
            full_config = config + "_" + test_available.split(':')[1].split('(')[0].strip()
            renamed_dict[full_config] = inv_metrics[config]

        try:   
            df_inv_metrics[inv_name].update(renamed_dict)
        except KeyError:
            df_inv_metrics[inv_name] = renamed_dict
# Out:
# ------------------------------ TEST(0): best_for_inverter (Galatina) ------------------------------
# ---------- [INV1]  Merging the metrics from all the SOM configs ----------
# ---------- [INV2]  Merging the metrics from all the SOM configs ----------
# ---------- [INV3]  Merging the metrics from all the SOM configs ----------
# ---------- [INV4]  Merging the metrics from all the SOM configs ----------
#
# ------------------------------ TEST(1): averaged_across_inverter (Galatina) ------------------------------
# ---------- [INV1]  Merging the metrics from all the SOM configs ----------
# ---------- [INV2]  Merging the metrics from all the SOM configs ----------
# ---------- [INV3]  Merging the metrics from all the SOM configs ----------
# ---------- [INV4]  Merging the metrics from all the SOM configs ----------
#
# ------------------------------ TEST(2): averaged_across_pvSystems ------------------------------
# ---------- [INV1]  Merging the metrics from all the SOM configs ----------
# ---------- [INV2]  Merging the metrics from all the SOM configs ----------
# ---------- [INV3]  Merging the metrics from all the SOM configs ----------
# ---------- [INV4]  Merging the metrics from all the SOM configs ----------

# %% [markdown]
# ### B.4.1) [VIEW 5] General Fault & Alarm Logs with 'High priority'

# %%
fault_profile = fault_profiles_available[0]

# %%
inv_ranked_configs_faultProfiles = dict()

inv_ranked_configs, fault_anticipation, inv_best_perfomance = visualize_perfomance(fault_profile, visualize_details = True)
inv_ranked_configs_faultProfiles = inv_ranked_configs
# Out:
# -------------------------------------------------- PV SYSTEM: Galatina --------------------------------------------------
#
# --------------------------------------------- SOM CONFIGURATION ---------------------------------------------
# (1) TEST(0): BEST_FOR_INVERTER (GALATINA) --> 26grid || 10Kepoch || 0.01lr || 2sigma || gaussianFunc
# ----------------------------------------------------------------------------------------------------
# (2) TEST(1): AVERAGED_ACROSS_INVERTER (GALATINA) --> 26grid || 8Kepoch || 0.01lr || 4sigma || gaussianFunc
# ----------------------------------------------------------------------------------------------------
# (3) TEST(2): AVERAGED_ACROSS_PVSYSTEMS --> 20grid || 6Kepoch || 0.001lr || 1sigma || gaussianFunc
# ----------------------------------------------------------------------------------------------------
#
#
# ------------------------------ INVERTER: N°1 (FAULT PROFILE: General Fault || Log - High)------------------------------
# ----------------------------------------
# ALL 5 FAILURE EVENTS (types: 'General Fault, Log - High')
# ----------------------------------------
# 1) ['LOG - HIGH (Allarme inverter): Inverter 1 250kWp U090063: [0x200000] Tensione rete fuori dai limiti (0x3020D240)
#    [FROM 2020-12-03 (17:55) TO 2020-12-04 (08:02)]'
# 2) 'LOG - HIGH (Allarme inverter): Inverter 1 250kWp U090063: [0x200000] Tensione rete fuori dai limiti (0x3020D240)
#    [FROM 2020-03-09 (17:26) TO 2020-03-09 (17:34)]'
# 3) 'LOG - HIGH (Allarme inverter): Inverter 1 250kWp U090063: [0x200000] Tensione rete fuori dai limiti (0x3020D240)
#    [FROM 2020-10-12 (08:05) TO 2020-10-12 (08:13)]'
# 4) 'LOG - HIGH (Allarme inverter): Inverter 1 250kWp U090063: [0x200000] Tensione rete fuori dai limiti (0x3020D240)
#    [FROM 2020-05-29 (13:45) TO 2020-05-29 (13:53)]'
# 5) 'LOG - HIGH (Allarme inverter): Inverter 1 250kWp U090063: [0x200000] Tensione rete fuori dai limiti (0x3020D240)
#    [FROM 2021-02-05 (16:57) TO 2021-02-05 (17:04)]']
# ----------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------
# 		COMPARISONS of the combinations of pre-processing steps
# -------------------------------------------------------------------------------------
#
# ---------------------------------------- A) COMPARISION OF THE PRE-PROCESSING STEPS --------------------------------
# ------------------------------------------- WARNINGS with (levels >= 4) --------------------------------------------
#
# ----------------------------------------
# CONFIG 1/3: 1hour_averaged_fullReg_detrended_best_for_inverter
# FAILURE EVENTS DETECTED: 0/5 (0.0 %)
# ----------------------------------------
#
# ----------------------------------------
# CONFIG 2/3: 1hour_averaged_fullReg_detrended_averaged_across_inverter
# FAILURE EVENTS DETECTED: 0/5 (0.0 %)
# ----------------------------------------
#
# ----------------------------------------
# CONFIG 3/3: 1hour_averaged_fullReg_detrended_averaged_across_pvSystems
# FAILURE EVENTS DETECTED: 0/5 (0.0 %)
# ----------------------------------------
#                                                     F1 score (%)  Recall (%)  \
# (CONFIG. 1) 1hour_averaged_fullReg_detrended_be...           NaN         0.0
# (CONFIG. 2) 1hour_averaged_fullReg_detrended_av...           NaN         0.0
# (CONFIG. 3) 1hour_averaged_fullReg_detrended_av...           NaN         0.0
#
#                                                     Miss rate (%)  \
# (CONFIG. 1) 1hour_averaged_fullReg_detrended_be...          100.0
# (CONFIG. 2) 1hour_averaged_fullReg_detrended_av...          100.0
# (CONFIG. 3) 1hour_averaged_fullReg_detrended_av...          100.0
#
#                                                     Precision (%)  \
# (CONFIG. 1) 1hour_averaged_fullReg_detrended_be...            0.0
# (CONFIG. 2) 1hour_averaged_fullReg_detrended_av...            NaN
# (CONFIG. 3) 1hour_averaged_fullReg_detrended_av...            NaN
#
#                                                     Fall out (%)
# (CONFIG. 1) 1hour_averaged_fullReg_detrended_be...          0.06
# (CONFIG. 2) 1hour_averaged_fullReg_detrended_av...          0.00
# (CONFIG. 3) 1hour_averaged_fullReg_detrended_av...          0.00
# -------------------------------------------------- F1 score (%) --------------------------------------------------
#
# -------------------------------------------------- Recall (%) --------------------------------------------------
# --------------------------------------------------------------------------------------------------------------
# REFERENCE: (CONFIG. 1) 1hour||averaged||fullReg||detrended||best||for||inverter --> Recall (%): 0.0 %
# --------------------------------------------------------------------------------------------------------------
# --> (CONFIG. 2) 1hour||averaged||fullReg||detrended||averaged||across||inverter --> [0.0%]
# --> (CONFIG. 3) 1hour||averaged||fullReg||detrended||averaged||across||pvSystems --> [0.0%]
#
# -------------------------------------------------- Precision (%) --------------------------------------------------
# --------------------------------------------------------------------------------------------------------------
# REFERENCE: (CONFIG. 1) 1hour||averaged||fullReg||detrended||best||for||inverter --> Precision (%): 0.0 %
# --------------------------------------------------------------------------------------------------------------
# --> (CONFIG. 2) 1hour||averaged||fullReg||detrended||averaged||across||inverter --> [nan%]
# --> (CONFIG. 3) 1hour||averaged||fullReg||detrended||averaged||across||pvSystems --> [nan%]
#
# ---------------------------------------- B) COMPARISION OF THE PRE-PROCESSING STEPS --------------------------------
# ------------------------------------------- WARNINGS with (levels >= 3) --------------------------------------------
#
# ----------------------------------------
# CONFIG 1/3: 1hour_averaged_fullReg_detrended_best_for_inverter
# FAILURE EVENTS DETECTED: 0/5 (0.0 %)
# ----------------------------------------
#
# ----------------------------------------
# CONFIG 2/3: 1hour_averaged_fullReg_detrended_averaged_across_inverter
# FAILURE EVENTS DETECTED: 0/5 (0.0 %)
# ----------------------------------------
#
# ----------------------------------------
# CONFIG 3/3: 1hour_averaged_fullReg_detrended_averaged_across_pvSystems
# FAILURE EVENTS DETECTED: 0/5 (0.0 %)
# ----------------------------------------
#                                                     F1 score (%)  Recall (%)  \
# (CONFIG. 1) 1hour_averaged_fullReg_detrended_be...           NaN         0.0
# (CONFIG. 2) 1hour_averaged_fullReg_detrended_av...           NaN         0.0
# (CONFIG. 3) 1hour_averaged_fullReg_detrended_av...           NaN         0.0
#
#                                                     Miss rate (%)  \
# (CONFIG. 1) 1hour_averaged_fullReg_detrended_be...          100.0
# (CONFIG. 2) 1hour_averaged_fullReg_detrended_av...          100.0
# (CONFIG. 3) 1hour_averaged_fullReg_detrended_av...          100.0
#
#                                                     Precision (%)  \
# (CONFIG. 1) 1hour_averaged_fullReg_detrended_be...            0.0
# (CONFIG. 2) 1hour_averaged_fullReg_detrended_av...            NaN
# (CONFIG. 3) 1hour_averaged_fullReg_detrended_av...            NaN
#
#                                                     Fall out (%)
# (CONFIG. 1) 1hour_averaged_fullReg_detrended_be...          0.19
# (CONFIG. 2) 1hour_averaged_fullReg_detrended_av...          0.00
# (CONFIG. 3) 1hour_averaged_fullReg_detrended_av...          0.00
# -------------------------------------------------- F1 score (%) --------------------------------------------------
#
# -------------------------------------------------- Recall (%) --------------------------------------------------
# --------------------------------------------------------------------------------------------------------------
# REFERENCE: (CONFIG. 1) 1hour||averaged||fullReg||detrended||best||for||inverter --> Recall (%): 0.0 %
# --------------------------------------------------------------------------------------------------------------
# --> (CONFIG. 2) 1hour||averaged||fullReg||detrended||averaged||across||inverter --> [0.0%]
# --> (CONFIG. 3) 1hour||averaged||fullReg||detrended||averaged||across||pvSystems --> [0.0%]
#
# -------------------------------------------------- Precision (%) --------------------------------------------------
# --------------------------------------------------------------------------------------------------------------
# REFERENCE: (CONFIG. 1) 1hour||averaged||fullReg||detrended||best||for||inverter --> Precision (%): 0.0 %
# --------------------------------------------------------------------------------------------------------------
# --> (CONFIG. 2) 1hour||averaged||fullReg||detrended||averaged||across||inverter --> [nan%]
# --> (CONFIG. 3) 1hour||averaged||fullReg||detrended||averaged||across||pvSystems --> [nan%]
#
# ---------------------------------------- C) COMPARISION OF THE PRE-PROCESSING STEPS --------------------------------
# ------------------------------------------- WARNINGS with (levels >= 2) --------------------------------------------
#
# ----------------------------------------
# CONFIG 1/3: 1hour_averaged_fullReg_detrended_best_for_inverter
# FAILURE EVENTS DETECTED: 1/5 (20.0 %)
# ----------------------------------------
# 	----------------------------------------
#
# 	FAULT/ALARM (1/1): Inverter 1 250kWp U090063: [0x200000] Tensione rete fuori dai limiti (0x3020D240)
# 	--> FROM 2021-02-05 (16:57) TO 2021-02-05 (17:04)
# 	--> WARNINGS (2):
# 		--> WARNING (L2): 2021-01-31 (16:00)
# 		--> WARNING (L2): 2021-02-01 (07:00)
# 	--> ANTICIPATION (1° Warning): 5 day(s) 0, hour(s) and 57 minute(s).
# 	--> LAST WARNING: 4 day(s), 9 hour(s) and 57 minute(s).
#
# ----------------------------------------
# CONFIG 2/3: 1hour_averaged_fullReg_detrended_averaged_across_inverter
# FAILURE EVENTS DETECTED: 0/5 (0.0 %)
# ----------------------------------------
#
# ----------------------------------------
# CONFIG 3/3: 1hour_averaged_fullReg_detrended_averaged_across_pvSystems
# FAILURE EVENTS DETECTED: 1/5 (20.0 %)
# ----------------------------------------
#                                                     F1 score (%)  Recall (%)  \
# (CONFIG. 1) 1hour_averaged_fullReg_detrended_be...         72.00       75.00
# (CONFIG. 3) 1hour_averaged_fullReg_detrended_av...         28.57       16.67
# (CONFIG. 2) 1hour_averaged_fullReg_detrended_av...           NaN        0.00
#
#                                                     Miss rate (%)  \
# (CONFIG. 1) 1hour_averaged_fullReg_detrended_be...          25.00
# (CONFIG. 3) 1hour_averaged_fullReg_detrended_av...          83.33
# (CONFIG. 2) 1hour_averaged_fullReg_detrended_av...         100.00
#
#                                                     Precision (%)  \
# (CONFIG. 1) 1hour_averaged_fullReg_detrended_be...          69.23
# (CONFIG. 3) 1hour_averaged_fullReg_detrended_av...         100.00
# (CONFIG. 2) 1hour_averaged_fullReg_detrended_av...            NaN
#
#                                                     Fall out (%)
# (CONFIG. 1) 1hour_averaged_fullReg_detrended_be...          0.25
# (CONFIG. 3) 1hour_averaged_fullReg_detrended_av...          0.00
# (CONFIG. 2) 1hour_averaged_fullReg_detrended_av...          0.00
# -------------------------------------------------- F1 score (%) --------------------------------------------------
# --------------------------------------------------------------------------------------------------------------
# REFERENCE: (CONFIG. 1) 1hour||averaged||fullReg||detrended||best||for||inverter --> F1 score (%): 72.0 %
# --------------------------------------------------------------------------------------------------------------
# --> (CONFIG. 3) 1hour||averaged||fullReg||detrended||averaged||across||pvSystems --> [-43.43%]
# --> (CONFIG. 2) 1hour||averaged||fullReg||detrended||averaged||across||inverter --> [nan%]
#
# -------------------------------------------------- Recall (%) --------------------------------------------------
# --------------------------------------------------------------------------------------------------------------
# REFERENCE: (CONFIG. 1) 1hour||averaged||fullReg||detrended||best||for||inverter --> Recall (%): 75.0 %
# --------------------------------------------------------------------------------------------------------------
# --> (CONFIG. 3) 1hour||averaged||fullReg||detrended||averaged||across||pvSystems --> [-58.33%]
# --> (CONFIG. 2) 1hour||averaged||fullReg||detrended||averaged||across||inverter --> [-75.0%]
#
# -------------------------------------------------- Precision (%) --------------------------------------------------
# --------------------------------------------------------------------------------------------------------------
# REFERENCE: (CONFIG. 1) 1hour||averaged||fullReg||detrended||best||for||inverter --> Precision (%): 69.23 %
# --------------------------------------------------------------------------------------------------------------
# --> (CONFIG. 3) 1hour||averaged||fullReg||detrended||averaged||across||pvSystems --> [30.77%]
# --> (CONFIG. 2) 1hour||averaged||fullReg||detrended||averaged||across||inverter --> [nan%]
#
# ---------------------------------------- D) COMPARISION OF THE PRE-PROCESSING STEPS --------------------------------
# ------------------------------------------- WARNINGS with (levels >= 1) --------------------------------------------
#
# ----------------------------------------
# CONFIG 1/3: 1hour_averaged_fullReg_detrended_best_for_inverter
# FAILURE EVENTS DETECTED: 3/5 (60.0 %)
# ----------------------------------------
# 	----------------------------------------
#
# 	FAULT/ALARM (1/3): Inverter 1 250kWp U090063: [0x200000] Tensione rete fuori dai limiti (0x3020D240)
# 	--> FROM 2021-02-05 (16:57) TO 2021-02-05 (17:04)
# 	--> WARNINGS (6):
# 		--> WARNING (L1): 2021-01-31 (13:00)
# 		--> WARNING (L1): 2021-01-31 (15:00)
# 		--> WARNING (L2): 2021-01-31 (16:00)
# 		--> WARNING (L1): 2021-02-01 (06:00)
# 		--> WARNING (L2): 2021-02-01 (07:00)
# 	--> ANTICIPATION (1° Warning): 5 day(s) 3, hour(s) and 57 minute(s).
# 	--> LAST WARNING: 4 day(s), 9 hour(s) and 57 minute(s).
# 	----------------------------------------
#
# 	FAULT/ALARM (2/3): Inverter 1 250kWp U090063: [0x200000] Tensione rete fuori dai limiti (0x3020D240)
# 	--> FROM 2020-03-09 (17:26) TO 2020-03-09 (17:34)
# 	--> WARNINGS (3):
# 		--> WARNING (L1): 2020-03-03 (16:00)
# 		--> WARNING (L1): 2020-03-03 (20:00)
# 	--> ANTICIPATION (1° Warning): 6 day(s) 1, hour(s) and 26 minute(s).
# 	--> LAST WARNING: 5 day(s), 21 hour(s) and 26 minute(s).
# 	----------------------------------------
#
# 	FAULT/ALARM (3/3): Inverter 1 250kWp U090063: [0x200000] Tensione rete fuori dai limiti (0x3020D240)
# 	--> FROM 2020-12-03 (17:55) TO 2020-12-04 (08:02)
# 	--> WARNINGS (2):
# 		--> WARNING (L1): 2020-12-03 (15:00)
# 		--> WARNING (L1): 2020-12-03 (17:00)
# 	--> ANTICIPATION (1° Warning): 0 day(s) 2, hour(s) and 55 minute(s).
# 	--> LAST WARNING: 0 day(s), 0 hour(s) and 55 minute(s).
#
# ----------------------------------------
# CONFIG 2/3: 1hour_averaged_fullReg_detrended_averaged_across_inverter
# FAILURE EVENTS DETECTED: 3/5 (60.0 %)
# ----------------------------------------
#
# ----------------------------------------
# CONFIG 3/3: 1hour_averaged_fullReg_detrended_averaged_across_pvSystems
# FAILURE EVENTS DETECTED: 2/5 (40.0 %)
# ----------------------------------------
#                                                     F1 score (%)  Recall (%)  \
# (CONFIG. 2) 1hour_averaged_fullReg_detrended_av...         81.82       75.00
# (CONFIG. 1) 1hour_averaged_fullReg_detrended_be...         74.07       83.33
# (CONFIG. 3) 1hour_averaged_fullReg_detrended_av...         33.33       25.00
#
#                                                     Miss rate (%)  \
# (CONFIG. 2) 1hour_averaged_fullReg_detrended_av...          25.00
# (CONFIG. 1) 1hour_averaged_fullReg_detrended_be...          16.67
# (CONFIG. 3) 1hour_averaged_fullReg_detrended_av...          75.00
#
#                                                     Precision (%)  \
# (CONFIG. 2) 1hour_averaged_fullReg_detrended_av...          90.00
# (CONFIG. 1) 1hour_averaged_fullReg_detrended_be...          66.67
# (CONFIG. 3) 1hour_averaged_fullReg_detrended_av...          50.00
#
#                                                     Fall out (%)
# (CONFIG. 2) 1hour_averaged_fullReg_detrended_av...          0.06
# (CONFIG. 1) 1hour_averaged_fullReg_detrended_be...          0.31
# (CONFIG. 3) 1hour_averaged_fullReg_detrended_av...          0.19
# -------------------------------------------------- F1 score (%) --------------------------------------------------
# --------------------------------------------------------------------------------------------------------------
# REFERENCE: (CONFIG. 2) 1hour||averaged||fullReg||detrended||averaged||across||inverter --> F1 score (%): 81.82 %
# --------------------------------------------------------------------------------------------------------------
# --> (CONFIG. 1) 1hour||averaged||fullReg||detrended||best||for||inverter --> [-7.75%]
# --> (CONFIG. 3) 1hour||averaged||fullReg||detrended||averaged||across||pvSystems --> [-48.49%]
#
# -------------------------------------------------- Recall (%) --------------------------------------------------
# --------------------------------------------------------------------------------------------------------------
# REFERENCE: (CONFIG. 2) 1hour||averaged||fullReg||detrended||averaged||across||inverter --> Recall (%): 75.0 %
# --------------------------------------------------------------------------------------------------------------
# --> (CONFIG. 1) 1hour||averaged||fullReg||detrended||best||for||inverter --> [8.33%]
# --> (CONFIG. 3) 1hour||averaged||fullReg||detrended||averaged||across||pvSystems --> [-50.0%]
#
# -------------------------------------------------- Precision (%) --------------------------------------------------
# --------------------------------------------------------------------------------------------------------------
# REFERENCE: (CONFIG. 2) 1hour||averaged||fullReg||detrended||averaged||across||inverter --> Precision (%): 90.0 %
# --------------------------------------------------------------------------------------------------------------
# --> (CONFIG. 1) 1hour||averaged||fullReg||detrended||best||for||inverter --> [-23.33%]
# --> (CONFIG. 3) 1hour||averaged||fullReg||detrended||averaged||across||pvSystems --> [-40.0%]
#
# ---------- ANTICIPATIONS --------------------
# WARNING LEVEL >= L2:
# --------------------
# ----------------------
# [AVG] 5 days 00:57:00
#
# WARNING LEVEL >= L1:
# --------------------
# ----------------------
# [AVG] 3 days 18:46:00
#
#
# ---------- METRICS STATED IN THE PAPER ----------
# RECALL (paper): 94.33% --> avg[93, 98, 92]
# MISS RATE (avg paper): 5.67 % --> avg[7, 2, 8]
# FALL-OUT (avg paper): 10.67 % --> avg[13, 18, 1]
#
# -------------------------------------------------- PV SYSTEM: Galatina --------------------------------------------------
#
# --------------------------------------------- SOM CONFIGURATION ---------------------------------------------
# (1) TEST(0): BEST_FOR_INVERTER (GALATINA) --> 30grid || 30Kepoch || 0.01lr || 1sigma || gaussianFunc
# ----------------------------------------------------------------------------------------------------
# (2) TEST(1): AVERAGED_ACROSS_INVERTER (GALATINA) --> 26grid || 8Kepoch || 0.01lr || 4sigma || gaussianFunc
# ----------------------------------------------------------------------------------------------------
# (3) TEST(2): AVERAGED_ACROSS_PVSYSTEMS --> 20grid || 6Kepoch || 0.001lr || 1sigma || gaussianFunc
# ----------------------------------------------------------------------------------------------------
#
#
# ------------------------------ INVERTER: N°2 (FAULT PROFILE: General Fault || Log - High)------------------------------
# ----------------------------------------
# ALL 268 FAILURE EVENTS (types: 'General Fault, Log - High')
# ----------------------------------------
# 1) ['LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2020-01-05 (16:48) TO 2020-01-05 (16:55)]'
# 2) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2020-01-19 (18:56) TO 2020-01-20 (08:00)]'
# 3) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA41)
#    [FROM 2019-12-16 (08:16) TO 2019-12-16 (08:24)]'
# 4) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-06-26 (17:50) TO 2020-06-26 (18:02)]'
# 5) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x40000] Sovracorrente inverter (0x200CD400)
#    [FROM 2018-10-09 (11:33) TO 2018-10-10 (09:04)]'
# 6) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2020-01-31 (18:38) TO 2020-01-31 (18:51)]'
# 7) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x200000] Tensione rete fuori dai limiti (0x3020D240)
#    [FROM 2019-11-12 (09:18) TO 2019-11-12 (10:00)]'
# 8) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-11-15 (08:04) TO 2019-11-15 (08:23)]'
# 9) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-11-18 (08:54) TO 2019-11-18 (09:06)]'
# 10) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-06-23 (18:00) TO 2020-06-23 (18:23)]'
# 11) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-01-19 (16:08) TO 2020-01-19 (16:15)]'
# 12) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2018-09-09 (08:37) TO 2018-09-09 (08:54)]'
# 13) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-03-05 (08:55) TO 2020-03-05 (09:02)]'
# 14) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-04-04 (11:35) TO 2020-04-04 (12:26)]'
# 15) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-06-06 (10:06) TO 2020-06-06 (10:13)]'
# 16) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-04-13 (10:38) TO 2020-04-13 (10:45)]'
# 17) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-12-07 (14:06) TO 2019-12-07 (14:20)]'
# 18) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-04-02 (18:57) TO 2020-04-03 (08:02)]'
# 19) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2018-10-03 (17:51) TO 2018-10-04 (08:00)]'
# 20) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x200000] Tensione rete fuori dai limiti (0x3020D240)
#    [FROM 2019-11-19 (15:29) TO 2019-11-20 (08:01)]'
# 21) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2019-12-17 (18:36) TO 2019-12-18 (08:00)]'
# 22) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2020-03-04 (17:09) TO 2020-03-04 (17:21)]'
# 23) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-04-09 (09:29) TO 2020-04-09 (09:37)]'
# 24) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-11-23 (08:59) TO 2019-11-23 (09:18)]'
# 25) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-04-02 (14:44) TO 2020-04-02 (14:57)]'
# 26) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-03-04 (10:20) TO 2020-03-04 (10:38)]'
# 27) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2020-01-13 (18:08) TO 2020-01-13 (18:26)]'
# 28) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-08-13 (18:27) TO 2019-08-14 (08:02)]'
# 29) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-07-01 (11:53) TO 2019-07-01 (12:06)]'
# 30) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-07-29 (10:25) TO 2019-07-29 (10:38)]'
# 31) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2019-12-13 (16:51) TO 2019-12-13 (16:58)]'
# 32) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-01-13 (10:52) TO 2020-01-13 (11:11)]'
# 33) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2019-01-19 (10:29) TO 2019-01-19 (10:45)]'
# 34) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x10] Mancanza comunicazione CAN (0x3008D250)
#    [FROM 2019-03-19 (14:03) TO 2019-03-19 (14:16)]'
# 35) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2019-11-16 (15:48) TO 2019-11-16 (16:22)]'
# 36) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-02-27 (12:50) TO 2020-02-27 (13:55)]'
# 37) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-02-04 (11:16) TO 2020-02-04 (11:24)]'
# 38) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2020-03-12 (18:39) TO 2020-03-13 (08:01)]'
# 39) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-08-14 (18:47) TO 2019-08-15 (08:03)]'
# 40) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-03-05 (09:35) TO 2020-03-05 (09:59)]'
# 41) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-11-10 (09:53) TO 2019-11-10 (10:05)]'
# 42) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-07-22 (09:37) TO 2019-07-22 (09:49)]'
# 43) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-06-12 (11:46) TO 2020-06-12 (11:54)]'
# 44) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-02-28 (08:39) TO 2020-02-28 (09:08)]'
# 45) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2019-01-28 (17:59) TO 2019-01-28 (18:16)]'
# 46) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2018-09-03 (16:48) TO 2018-09-03 (17:04)]'
# 47) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-04-21 (18:34) TO 2019-04-22 (08:02)]'
# 48) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-07-30 (13:49) TO 2019-07-30 (14:00)]'
# 49) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2019-11-10 (17:11) TO 2019-11-10 (17:22)]'
# 50) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2019-11-24 (13:40) TO 2019-11-24 (13:51)]'
# 51) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2019-12-17 (17:45) TO 2019-12-17 (18:03)]'
# 52) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-04-08 (10:53) TO 2020-04-08 (11:00)]'
# 53) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-05-13 (09:12) TO 2020-05-13 (09:19)]'
# 54) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-04-12 (18:49) TO 2019-04-13 (08:01)]'
# 55) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2020-01-21 (17:59) TO 2020-01-21 (18:06)]'
# 56) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-01-24 (11:39) TO 2020-01-24 (11:47)]'
# 57) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-03-31 (15:04) TO 2020-03-31 (15:17)]'
# 58) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-04-01 (16:28) TO 2020-04-01 (16:36)]'
# 59) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-04-21 (09:42) TO 2020-04-21 (09:50)]'
# 60) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2019-11-23 (18:50) TO 2019-11-24 (08:02)]'
# 61) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-03-20 (08:15) TO 2020-03-20 (08:21)]'
# 62) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-04-01 (12:33) TO 2020-04-01 (12:40)]'
# 63) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-04-11 (17:31) TO 2020-04-11 (17:39)]'
# 64) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-04-13 (09:25) TO 2020-04-13 (09:33)]'
# 65) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2018-10-01 (18:25) TO 2018-10-01 (18:42)]'
# 66) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2019-12-15 (17:25) TO 2019-12-15 (17:33)]'
# 67) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-06-18 (11:43) TO 2020-06-18 (11:50)]'
# 68) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2018-09-06 (18:47) TO 2018-09-07 (08:01)]'
# 69) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-08-02 (10:39) TO 2019-08-02 (10:52)]'
# 70) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-05-05 (10:27) TO 2020-05-05 (10:34)]'
# 71) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-08-21 (13:21) TO 2019-08-21 (13:32)]'
# 72) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2020-03-04 (18:33) TO 2020-03-04 (18:40)]'
# 73) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-03-17 (08:11) TO 2020-03-17 (08:18)]'
# 74) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-04-27 (16:53) TO 2020-04-27 (17:00)]'
# 75) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-06-13 (11:52) TO 2020-06-13 (11:59)]'
# 76) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2018-09-04 (07:46) TO 2018-09-04 (08:56)]'
# 77) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-04-22 (17:58) TO 2019-04-22 (18:33)]'
# 78) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-04-29 (16:31) TO 2020-04-29 (16:37)]'
# 79) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2019-11-13 (18:20) TO 2019-11-14 (08:00)]'
# 80) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2018-09-14 (13:10) TO 2018-09-14 (13:26)]'
# 81) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-01-19 (15:51) TO 2020-01-19 (16:03)]'
# 82) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2019-02-08 (16:46) TO 2019-02-08 (17:05)]'
# 83) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-06-02 (10:21) TO 2020-06-02 (10:28)]'
# 84) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-02-11 (10:58) TO 2020-02-11 (11:04)]'
# 85) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-06-02 (08:59) TO 2019-06-02 (09:11)]'
# 86) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-01-25 (09:58) TO 2020-01-25 (10:05)]'
# 87) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-04-10 (11:24) TO 2020-04-10 (11:56)]'
# 88) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-11-17 (13:04) TO 2019-11-17 (13:38)]'
# 89) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-12-16 (09:06) TO 2019-12-16 (09:13)]'
# 90) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-06-06 (09:23) TO 2019-06-06 (09:36)]'
# 91) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-11-18 (10:11) TO 2019-11-18 (10:21)]'
# 92) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2020-01-22 (16:25) TO 2020-01-22 (16:33)]'
# 93) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-08-07 (10:32) TO 2019-08-07 (10:45)]'
# 94) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2020-01-24 (18:40) TO 2020-01-24 (18:58)]'
# 95) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-11-15 (09:44) TO 2019-11-15 (09:54)]'
# 96) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-08-23 (16:31) TO 2019-08-23 (16:44)]'
# 97) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-01-08 (14:18) TO 2020-01-08 (14:26)]'
# 98) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-05-08 (09:36) TO 2020-05-08 (09:44)]'
# 99) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-06-25 (11:05) TO 2020-06-25 (11:11)]'
# 100) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2018-10-20 (07:45) TO 2018-10-20 (08:03)]'
# 101) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-01-14 (10:01) TO 2020-01-14 (10:08)]'
# 102) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-08-13 (11:31) TO 2019-08-13 (11:50)]'
# 103) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-12-03 (15:43) TO 2019-12-03 (15:51)]'
# 104) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2019-12-10 (18:47) TO 2019-12-11 (08:16)]'
# 105) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2019-12-15 (16:57) TO 2019-12-15 (17:05)]'
# 106) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-03-09 (08:43) TO 2020-03-09 (08:56)]'
# 107) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-02-02 (16:35) TO 2020-02-02 (16:43)]'
# 108) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-08-12 (16:50) TO 2019-08-12 (17:02)]'
# 109) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2020-01-01 (16:26) TO 2020-01-01 (16:39)]'
# 110) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-02-03 (16:19) TO 2020-02-03 (16:26)]'
# 111) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-06-01 (14:07) TO 2019-06-01 (15:39)]'
# 112) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-06-08 (11:54) TO 2020-06-08 (12:01)]'
# 113) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-06-27 (12:44) TO 2019-06-27 (12:56)]'
# 114) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-06-27 (10:06) TO 2020-06-27 (10:13)]'
# 115) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-08-16 (09:42) TO 2019-08-16 (09:52)]'
# 116) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2019-11-10 (18:28) TO 2019-11-11 (08:02)]'
# 117) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2019-12-13 (17:41) TO 2019-12-13 (18:00)]'
# 118) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2019-12-22 (07:58) TO 2019-12-22 (08:06)]'
# 119) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2020-03-05 (16:35) TO 2020-03-05 (16:42)]'
# 120) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-11-25 (09:31) TO 2019-11-25 (09:41)]'
# 121) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-03-03 (09:13) TO 2020-03-03 (09:26)]'
# 122) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-01-19 (14:44) TO 2020-01-19 (14:50)]'
# 123) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-03-24 (09:58) TO 2019-03-24 (10:09)]'
# 124) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-08-20 (18:40) TO 2019-08-20 (18:59)]'
# 125) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-06-15 (18:49) TO 2020-06-15 (18:56)]'
# 126) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-03-13 (09:11) TO 2020-03-13 (09:30)]'
# 127) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-01-29 (14:30) TO 2019-01-29 (14:42)]'
# 128) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-06-25 (16:17) TO 2020-06-25 (16:36)]'
# 129) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2019-11-29 (17:11) TO 2019-11-29 (17:29)]'
# 130) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3020DA40)
#    [FROM 2019-11-19 (18:42) TO 2019-11-20 (08:01)]'
# 131) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-03-04 (13:13) TO 2020-03-04 (13:20)]'
# 132) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-04-28 (18:16) TO 2020-04-28 (18:52)]'
# 133) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-08-05 (18:10) TO 2019-08-05 (18:23)]'
# 134) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-06-25 (14:34) TO 2020-06-25 (14:43)]'
# 135) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2019-11-13 (17:57) TO 2019-11-13 (18:16)]'
# 136) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-04-13 (11:35) TO 2020-04-13 (11:43)]'
# 137) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-03-10 (08:42) TO 2020-03-10 (08:49)]'
# 138) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-05-23 (18:28) TO 2020-05-23 (18:35)]'
# 139) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2019-08-29 (18:51) TO 2019-08-30 (08:02)]'
# 140) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2019-11-29 (18:58) TO 2019-11-30 (08:00)]'
# 141) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2020-03-02 (16:47) TO 2020-03-02 (16:59)]'
# 142) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-08-09 (11:58) TO 2019-08-09 (12:14)]'
# 143) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-12-18 (08:53) TO 2019-12-18 (09:00)]'
# 144) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-06-23 (18:28) TO 2020-06-23 (18:41)]'
# 145) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-06-28 (17:36) TO 2019-06-28 (18:36)]'
# 146) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-03-05 (13:41) TO 2020-03-05 (13:54)]'
# 147) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-06-19 (13:36) TO 2020-06-19 (13:49)]'
# 148) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-01-08 (11:24) TO 2020-01-08 (11:37)]'
# 149) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-06-19 (10:41) TO 2020-06-19 (10:48)]'
# 150) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2020-06-19 (18:53) TO 2020-06-20 (08:01)]'
# 151) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-08-04 (09:58) TO 2019-08-04 (10:11)]'
# 152) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-03-31 (10:38) TO 2019-03-31 (10:50)]'
# 153) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-03-06 (14:42) TO 2020-03-06 (14:49)]'
# 154) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-11-14 (09:19) TO 2019-11-14 (09:37)]'
# 155) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-02-07 (11:38) TO 2019-02-07 (11:50)]'
# 156) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-08-02 (17:44) TO 2019-08-02 (17:57)]'
# 157) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2020-01-20 (16:24) TO 2020-01-20 (16:37)]'
# 158) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3020DA40)
#    [FROM 2019-11-09 (18:47) TO 2019-11-10 (08:00)]'
# 159) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2019-11-15 (16:54) TO 2019-11-15 (17:05)]'
# 160) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-12-17 (12:54) TO 2019-12-17 (13:02)]'
# 161) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-02-10 (09:07) TO 2019-02-10 (09:18)]'
# 162) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2019-12-05 (15:05) TO 2019-12-05 (15:12)]'
# 163) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2019-02-07 (07:53) TO 2019-02-07 (08:21)]'
# 164) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x2000DA40)
#    [FROM 2020-01-21 (10:48) TO 2020-01-21 (10:54)]'
# 165) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2019-12-22 (08:10) TO 2019-12-22 (08:18)]'
# 166) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2019-12-27 (18:39) TO 2019-12-28 (08:24)]'
# 167) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2019-12-16 (17:28) TO 2019-12-16 (17:35)]'
# 168) 'LOG - HIGH (Allarme inverter): Inverter 2 250kWp U090062: [0x800] Intervento protezione esterna (0x3000DA40)
#    [FROM 2020-03-12 (17:38) TO 2020-03-12 (17:45)]'
# ...
# REFERENCE: (CONFIG. 2) 1hour||averaged||fullReg||detrended||averaged||across||inverter --> F1 score (%): 70.0 %
# --------------------------------------------------------------------------------------------------------------
# --> (CONFIG. 1) 1hour||averaged||fullReg||detrended||best||for||inverter --> [-10.54%]
# --> (CONFIG. 3) 1hour||averaged||fullReg||detrended||averaged||across||pvSystems --> [-43.33%]
#
# -------------------------------------------------- Recall (%) --------------------------------------------------
# --------------------------------------------------------------------------------------------------------------
# REFERENCE: (CONFIG. 2) 1hour||averaged||fullReg||detrended||averaged||across||inverter --> Recall (%): 53.85 %
# --------------------------------------------------------------------------------------------------------------
# --> (CONFIG. 1) 1hour||averaged||fullReg||detrended||best||for||inverter --> [-11.54%]
# --> (CONFIG. 3) 1hour||averaged||fullReg||detrended||averaged||across||pvSystems --> [-38.47%]
#
# -------------------------------------------------- Precision (%) --------------------------------------------------
# --------------------------------------------------------------------------------------------------------------
# REFERENCE: (CONFIG. 2) 1hour||averaged||fullReg||detrended||averaged||across||inverter --> Precision (%): 100.0 %
# --------------------------------------------------------------------------------------------------------------
# --> (CONFIG. 1) 1hour||averaged||fullReg||detrended||best||for||inverter --> [0.0%]
# --> (CONFIG. 3) 1hour||averaged||fullReg||detrended||averaged||across||pvSystems --> [0.0%]
#
# ---------------------------------------- C) COMPARISION OF THE PRE-PROCESSING STEPS --------------------------------
# ------------------------------------------- WARNINGS with (levels >= 2) --------------------------------------------
#
# ----------------------------------------
# CONFIG 1/3: 1hour_averaged_fullReg_detrended_best_for_inverter
# FAILURE EVENTS DETECTED: 4/8 (50.0 %)
# ----------------------------------------
# 	----------------------------------------
#
# 	FAULT/ALARM (1/4): Inverter 4 250kWp U090067: [0x200000] Tensione rete fuori dai limiti (0x3020D240)
# 	--> FROM 2019-11-12 (09:18) TO 2019-11-12 (10:00)
# 	--> WARNINGS (3):
# 		--> WARNING (L2): 2019-11-11 (13:00)
# 		--> WARNING (L2): 2019-11-11 (14:00)
# 	--> ANTICIPATION (1° Warning): 0 day(s) 20, hour(s) and 18 minute(s).
# 	--> LAST WARNING: 0 day(s), 19 hour(s) and 18 minute(s).
# 	----------------------------------------
#
# 	FAULT/ALARM (2/4): Inverter 4 250kWp U090067: [0x200000] Tensione rete fuori dai limiti (0x3020D240)
# 	--> FROM 2019-11-17 (18:03) TO 2019-11-18 (08:00)
# 	--> WARNINGS (12):
# 		--> WARNING (L2): 2019-11-11 (13:00)
# 		--> WARNING (L2): 2019-11-11 (14:00)
# 		--> WARNING (L4): 2019-11-12 (10:00)
# 		--> WARNING (L4): 2019-11-12 (13:00)
# 		--> WARNING (L3): 2019-11-12 (15:00)
# 		--> WARNING (L4): 2019-11-12 (16:00)
# 		--> WARNING (L4): 2019-11-12 (17:00)
# 		--> WARNING (L3): 2019-11-12 (19:00)
# 		--> WARNING (L4): 2019-11-12 (20:00)
# 		--> WARNING (L2): 2019-11-13 (14:00)
# 		--> WARNING (L2): 2019-11-13 (17:00)
# 	--> ANTICIPATION (1° Warning): 6 day(s) 5, hour(s) and 3 minute(s).
# 	--> LAST WARNING: 4 day(s), 1 hour(s) and 3 minute(s).
# 	----------------------------------------
#
# 	FAULT/ALARM (3/4): Inverter 4 250kWp U090067: [0x200000] Tensione rete fuori dai limiti (0x3020D240)
# 	--> FROM 2019-11-19 (15:30) TO 2019-11-20 (08:01)
# 	--> WARNINGS (7):
# 		--> WARNING (L4): 2019-11-12 (16:00)
# 		--> WARNING (L4): 2019-11-12 (17:00)
# 		--> WARNING (L3): 2019-11-12 (19:00)
# 		--> WARNING (L4): 2019-11-12 (20:00)
# 		--> WARNING (L2): 2019-11-13 (14:00)
# 		--> WARNING (L2): 2019-11-13 (17:00)
# 	--> ANTICIPATION (1° Warning): 6 day(s) 23, hour(s) and 30 minute(s).
# 	--> LAST WARNING: 5 day(s), 22 hour(s) and 30 minute(s).
# 	----------------------------------------
#
# 	FAULT/ALARM (4/4): Inverter 4 250kWp U090067: [0x200000] Tensione rete fuori dai limiti (0x3020D240)
# 	--> FROM 2019-11-12 (10:04) TO 2019-11-12 (10:54)
# 	--> WARNINGS (3):
# 		--> WARNING (L2): 2019-11-11 (13:00)
# 		--> WARNING (L2): 2019-11-11 (14:00)
# 		--> WARNING (L4): 2019-11-12 (10:00)
# 	--> ANTICIPATION (1° Warning): 0 day(s) 21, hour(s) and 4 minute(s).
# 	--> LAST WARNING: 0 day(s), 0 hour(s) and 4 minute(s).
#
# ----------------------------------------
# CONFIG 2/3: 1hour_averaged_fullReg_detrended_averaged_across_inverter
# FAILURE EVENTS DETECTED: 4/8 (50.0 %)
# ----------------------------------------
#
# ----------------------------------------
# CONFIG 3/3: 1hour_averaged_fullReg_detrended_averaged_across_pvSystems
# FAILURE EVENTS DETECTED: 1/8 (12.5 %)
# ----------------------------------------
#                                                     F1 score (%)  Recall (%)  \
# (CONFIG. 1) 1hour_averaged_fullReg_detrended_be...         70.00       53.85
# (CONFIG. 2) 1hour_averaged_fullReg_detrended_av...         70.00       53.85
# (CONFIG. 3) 1hour_averaged_fullReg_detrended_av...         25.81       15.38
#
#                                                     Miss rate (%)  \
# (CONFIG. 1) 1hour_averaged_fullReg_detrended_be...          46.15
# (CONFIG. 2) 1hour_averaged_fullReg_detrended_av...          46.15
# (CONFIG. 3) 1hour_averaged_fullReg_detrended_av...          84.62
#
#                                                     Precision (%)  \
# (CONFIG. 1) 1hour_averaged_fullReg_detrended_be...          100.0
# (CONFIG. 2) 1hour_averaged_fullReg_detrended_av...          100.0
# (CONFIG. 3) 1hour_averaged_fullReg_detrended_av...           80.0
#
#                                                     Fall out (%)
# (CONFIG. 1) 1hour_averaged_fullReg_detrended_be...          0.00
# (CONFIG. 2) 1hour_averaged_fullReg_detrended_av...          0.00
# (CONFIG. 3) 1hour_averaged_fullReg_detrended_av...          0.08
# -------------------------------------------------- F1 score (%) --------------------------------------------------
# --------------------------------------------------------------------------------------------------------------
# REFERENCE: (CONFIG. 1) 1hour||averaged||fullReg||detrended||best||for||inverter --> F1 score (%): 70.0 %
# --------------------------------------------------------------------------------------------------------------
# --> (CONFIG. 2) 1hour||averaged||fullReg||detrended||averaged||across||inverter --> [0.0%]
# --> (CONFIG. 3) 1hour||averaged||fullReg||detrended||averaged||across||pvSystems --> [-44.19%]
#
# -------------------------------------------------- Recall (%) --------------------------------------------------
# --------------------------------------------------------------------------------------------------------------
# REFERENCE: (CONFIG. 1) 1hour||averaged||fullReg||detrended||best||for||inverter --> Recall (%): 53.85 %
# --------------------------------------------------------------------------------------------------------------
# --> (CONFIG. 2) 1hour||averaged||fullReg||detrended||averaged||across||inverter --> [0.0%]
# --> (CONFIG. 3) 1hour||averaged||fullReg||detrended||averaged||across||pvSystems --> [-38.47%]
#
# -------------------------------------------------- Precision (%) --------------------------------------------------
# --------------------------------------------------------------------------------------------------------------
# REFERENCE: (CONFIG. 1) 1hour||averaged||fullReg||detrended||best||for||inverter --> Precision (%): 100.0 %
# --------------------------------------------------------------------------------------------------------------
# --> (CONFIG. 2) 1hour||averaged||fullReg||detrended||averaged||across||inverter --> [0.0%]
# --> (CONFIG. 3) 1hour||averaged||fullReg||detrended||averaged||across||pvSystems --> [-20.0%]
#
# ---------------------------------------- D) COMPARISION OF THE PRE-PROCESSING STEPS --------------------------------
# ------------------------------------------- WARNINGS with (levels >= 1) --------------------------------------------
#
# ----------------------------------------
# CONFIG 1/3: 1hour_averaged_fullReg_detrended_best_for_inverter
# FAILURE EVENTS DETECTED: 6/8 (75.0 %)
# ----------------------------------------
# 	----------------------------------------
#
# 	FAULT/ALARM (1/6): Inverter 4 250kWp U090067: [0x200000] Tensione rete fuori dai limiti (0x3020D240)
# 	--> FROM 2020-12-03 (17:55) TO 2020-12-04 (08:02)
# 	--> WARNINGS (2):
# 		--> WARNING (L1): 2020-12-03 (17:00)
# 	--> ANTICIPATION (1° Warning): 0 day(s) 0, hour(s) and 55 minute(s).
# 	----------------------------------------
#
# 	FAULT/ALARM (2/6): Inverter 4 250kWp U090067: [0x200000] Tensione rete fuori dai limiti (0x3020D240)
# 	--> FROM 2019-11-12 (09:18) TO 2019-11-12 (10:00)
# 	--> WARNINGS (10):
# 		--> WARNING (L1): 2019-11-09 (10:00)
# 		--> WARNING (L1): 2019-11-11 (09:00)
# 		--> WARNING (L1): 2019-11-11 (12:00)
# 		--> WARNING (L2): 2019-11-11 (13:00)
# 		--> WARNING (L2): 2019-11-11 (14:00)
# 		--> WARNING (L1): 2019-11-11 (17:00)
# 		--> WARNING (L1): 2019-11-11 (20:00)
# 		--> WARNING (L1): 2019-11-12 (07:00)
# 		--> WARNING (L1): 2019-11-12 (09:00)
# 	--> ANTICIPATION (1° Warning): 2 day(s) 23, hour(s) and 18 minute(s).
# 	--> LAST WARNING: 0 day(s), 0 hour(s) and 18 minute(s).
# 	----------------------------------------
#
# 	FAULT/ALARM (3/6): Inverter 4 250kWp U090067: [0x200000] Tensione rete fuori dai limiti (0x3020D240)
# 	--> FROM 2019-11-17 (18:03) TO 2019-11-18 (08:00)
# 	--> WARNINGS (21):
# 		--> WARNING (L1): 2019-11-11 (09:00)
# 		--> WARNING (L1): 2019-11-11 (12:00)
# 		--> WARNING (L2): 2019-11-11 (13:00)
# 		--> WARNING (L2): 2019-11-11 (14:00)
# 		--> WARNING (L1): 2019-11-11 (17:00)
# 		--> WARNING (L1): 2019-11-11 (20:00)
# 		--> WARNING (L1): 2019-11-12 (07:00)
# 		--> WARNING (L1): 2019-11-12 (09:00)
# 		--> WARNING (L4): 2019-11-12 (10:00)
# 		--> WARNING (L1): 2019-11-12 (12:00)
# 		--> WARNING (L4): 2019-11-12 (13:00)
# 		--> WARNING (L3): 2019-11-12 (15:00)
# 		--> WARNING (L4): 2019-11-12 (16:00)
# 		--> WARNING (L4): 2019-11-12 (17:00)
# 		--> WARNING (L3): 2019-11-12 (19:00)
# 		--> WARNING (L4): 2019-11-12 (20:00)
# 		--> WARNING (L1): 2019-11-13 (13:00)
# 		--> WARNING (L2): 2019-11-13 (14:00)
# 		--> WARNING (L1): 2019-11-13 (16:00)
# 		--> WARNING (L2): 2019-11-13 (17:00)
# 	--> ANTICIPATION (1° Warning): 6 day(s) 9, hour(s) and 3 minute(s).
# 	--> LAST WARNING: 4 day(s), 1 hour(s) and 3 minute(s).
# 	----------------------------------------
#
# 	FAULT/ALARM (4/6): Inverter 4 250kWp U090067: [0x200000] Tensione rete fuori dai limiti (0x3020D240)
# 	--> FROM 2019-11-19 (15:30) TO 2019-11-20 (08:01)
# 	--> WARNINGS (13):
# 		--> WARNING (L4): 2019-11-12 (16:00)
# 		--> WARNING (L4): 2019-11-12 (17:00)
# 		--> WARNING (L3): 2019-11-12 (19:00)
# 		--> WARNING (L4): 2019-11-12 (20:00)
# 		--> WARNING (L1): 2019-11-13 (13:00)
# 		--> WARNING (L2): 2019-11-13 (14:00)
# 		--> WARNING (L1): 2019-11-13 (16:00)
# 		--> WARNING (L2): 2019-11-13 (17:00)
# 		--> WARNING (L1): 2019-11-18 (20:00)
# 		--> WARNING (L1): 2019-11-19 (06:00)
# 		--> WARNING (L1): 2019-11-19 (10:00)
# 		--> WARNING (L1): 2019-11-19 (12:00)
# 	--> ANTICIPATION (1° Warning): 6 day(s) 23, hour(s) and 30 minute(s).
# 	--> LAST WARNING: 0 day(s), 3 hour(s) and 30 minute(s).
# 	----------------------------------------
#
# 	FAULT/ALARM (5/6): Inverter 4 250kWp U090067: [0x200000] Tensione rete fuori dai limiti (0x3020D240)
# 	--> FROM 2019-11-12 (10:04) TO 2019-11-12 (10:54)
# 	--> WARNINGS (11):
# 		--> WARNING (L1): 2019-11-09 (10:00)
# 		--> WARNING (L1): 2019-11-11 (09:00)
# 		--> WARNING (L1): 2019-11-11 (12:00)
# 		--> WARNING (L2): 2019-11-11 (13:00)
# 		--> WARNING (L2): 2019-11-11 (14:00)
# 		--> WARNING (L1): 2019-11-11 (17:00)
# 		--> WARNING (L1): 2019-11-11 (20:00)
# 		--> WARNING (L1): 2019-11-12 (07:00)
# 		--> WARNING (L1): 2019-11-12 (09:00)
# 		--> WARNING (L4): 2019-11-12 (10:00)
# 	--> ANTICIPATION (1° Warning): 3 day(s) 0, hour(s) and 4 minute(s).
# 	--> LAST WARNING: 0 day(s), 0 hour(s) and 4 minute(s).
# 	----------------------------------------
#
# 	FAULT/ALARM (6/6): Inverter 4 250kWp U090067: [0x200000] Tensione rete fuori dai limiti (0x3020D240)
# 	--> FROM 2019-11-09 (18:24) TO 2019-11-10 (08:00)
# 	--> WARNINGS (1):
# 		--> WARNING (L1): 2019-11-09 (10:00)
# 	--> ANTICIPATION (1° Warning): 0 day(s) 8, hour(s) and 24 minute(s).
#
# ----------------------------------------
# CONFIG 2/3: 1hour_averaged_fullReg_detrended_averaged_across_inverter
# FAILURE EVENTS DETECTED: 4/8 (50.0 %)
# ----------------------------------------
#
# ----------------------------------------
# CONFIG 3/3: 1hour_averaged_fullReg_detrended_averaged_across_pvSystems
# FAILURE EVENTS DETECTED: 1/8 (12.5 %)
# ----------------------------------------
#                                                     F1 score (%)  Recall (%)  \
# (CONFIG. 1) 1hour_averaged_fullReg_detrended_be...         94.12       92.31
# (CONFIG. 2) 1hour_averaged_fullReg_detrended_av...         68.29       53.85
# (CONFIG. 3) 1hour_averaged_fullReg_detrended_av...         22.86       15.38
#
#                                                     Miss rate (%)  \
# (CONFIG. 1) 1hour_averaged_fullReg_detrended_be...           7.69
# (CONFIG. 2) 1hour_averaged_fullReg_detrended_av...          46.15
# (CONFIG. 3) 1hour_averaged_fullReg_detrended_av...          84.62
#
#                                                     Precision (%)  \
# (CONFIG. 1) 1hour_averaged_fullReg_detrended_be...          96.00
# (CONFIG. 2) 1hour_averaged_fullReg_detrended_av...          93.33
# (CONFIG. 3) 1hour_averaged_fullReg_detrended_av...          44.44
#
#                                                     Fall out (%)
# (CONFIG. 1) 1hour_averaged_fullReg_detrended_be...          0.08
# (CONFIG. 2) 1hour_averaged_fullReg_detrended_av...          0.08
# (CONFIG. 3) 1hour_averaged_fullReg_detrended_av...          0.40
# -------------------------------------------------- F1 score (%) --------------------------------------------------
# --------------------------------------------------------------------------------------------------------------
# REFERENCE: (CONFIG. 1) 1hour||averaged||fullReg||detrended||best||for||inverter --> F1 score (%): 94.12 %
# --------------------------------------------------------------------------------------------------------------
# --> (CONFIG. 2) 1hour||averaged||fullReg||detrended||averaged||across||inverter --> [-25.83%]
# --> (CONFIG. 3) 1hour||averaged||fullReg||detrended||averaged||across||pvSystems --> [-71.26%]
#
# -------------------------------------------------- Recall (%) --------------------------------------------------
# --------------------------------------------------------------------------------------------------------------
# REFERENCE: (CONFIG. 1) 1hour||averaged||fullReg||detrended||best||for||inverter --> Recall (%): 92.31 %
# --------------------------------------------------------------------------------------------------------------
# --> (CONFIG. 2) 1hour||averaged||fullReg||detrended||averaged||across||inverter --> [-38.46%]
# --> (CONFIG. 3) 1hour||averaged||fullReg||detrended||averaged||across||pvSystems --> [-76.93%]
#
# -------------------------------------------------- Precision (%) --------------------------------------------------
# --------------------------------------------------------------------------------------------------------------
# REFERENCE: (CONFIG. 1) 1hour||averaged||fullReg||detrended||best||for||inverter --> Precision (%): 96.0 %
# --------------------------------------------------------------------------------------------------------------
# --> (CONFIG. 2) 1hour||averaged||fullReg||detrended||averaged||across||inverter --> [-2.67%]
# --> (CONFIG. 3) 1hour||averaged||fullReg||detrended||averaged||across||pvSystems --> [-51.56%]
#
# ---------- ANTICIPATIONS --------------------
# WARNING LEVEL >= L2:
# --------------------
# ----------------------
# [AVG] 3 days 17:28:45
#
# WARNING LEVEL >= L1:
# --------------------
# ----------------------
# [AVG] 3 days 06:52:20
#
#
# ---------- METRICS STATED IN THE PAPER ----------
# RECALL (paper): 94.33% --> avg[93, 98, 92]
# MISS RATE (avg paper): 5.67 % --> avg[7, 2, 8]
# FALL-OUT (avg paper): 10.67 % --> avg[13, 18, 1]

# %% [markdown]
# ### B.4.2) [VIEW 5bis] General Fault

# %%
fault_profile = fault_profiles_available[1]

# %%
#inv_ranked_configs, *_ = visualize_perfomance(fault_profile, visualize_details = False)
#inv_ranked_configs_faultProfiles.update(inv_ranked_configs)

# %% [markdown]
# ### B.5) Compute and visualize days in advance of failure events detected

# %%
verbose = False

# %%
if save_metrics_to_file:
    file_name = f"anticipation_GeneralFault_LogHigh"
    if consider_only_failure_starts:
        file_name += "_" + only_failure_starts_prefix
    anticip_file_path = path.join(perfomance_saving_folder, file_name + ".txt")
    anticipation_file = open(anticip_file_path,  mode="w+")
    print(f"The findings will be saved in a txt file --> {file_name}\n(folder: {perfomance_saving_folder}).\n")
    sys.stdout = anticipation_file
    
anticipation = defaultdict(list)
for inv_name in df_inv_metrics.keys():
    temporal_anticipation = fault_anticipation[inv_name]
    
    for warning_level in temporal_anticipation.keys():
         anticipation[warning_level].extend(temporal_anticipation[warning_level])
            
print("-" * 100 + f"\n\t\t\t\t\t\tPV SYSTEM: {system_name}")
print(f"\t\t\t\tEVENTS: General Faults & Alarms with 'High priority'\n"+ "-" * 100)
avg_anticipation = dict()
for warning_level in anticipation.keys():
    deltas = anticipation[warning_level]
    avg_delta = np.mean(deltas)
    
    avg_anticipation[warning_level] = avg_delta
    days, hours, minutes, *_ = avg_delta.components    
    print("-" * 55 + f"\nWARNING LEVEL >= {warning_level} (with {len(deltas)} correct warnings)\n" + "-" * 55)
    
    if verbose:
        for idk, delta in enumerate(deltas):
            delta_days, delta_hours, delta_minutes, *_ = delta.components
            print(f"Failure event detected ({'0' if idk < 9 else ''}{idk + 1}): "\
                  f"{delta_days} days, {delta_hours} hours and {delta_minutes} minutes")
        print("-" * 46)
    print(f"[AVG] TEMPORAL ADVANCE: {days} days, {hours} hours and {minutes} minutes.\n")
    
if save_metrics_to_file: 
    sys.stdout.close()
    sys.stdout = console_stdout
# Out:
# ----------------------------------------------------------------------------------------------------
# 						PV SYSTEM: Galatina
# 				EVENTS: General Faults & Alarms with 'High priority'
# ----------------------------------------------------------------------------------------------------
# -------------------------------------------------------
# WARNING LEVEL >= L2 (with 122 correct warnings)
# -------------------------------------------------------
# [AVG] TEMPORAL ADVANCE: 4 days, 19 hours and 20 minutes.
#
# -------------------------------------------------------
# WARNING LEVEL >= L1 (with 173 correct warnings)
# -------------------------------------------------------
# [AVG] TEMPORAL ADVANCE: 4 days, 15 hours and 55 minutes.

# %% [markdown]
# ### B.6) Error analysis

# %% [markdown]
# #### B.6.0) Utils

# %%
def visualize_error_analysis(fault_profile, warning_levels = 1, prediction_window = 7, 
                             save_metrics_to_file = False, verbose = False):
    console_stdout = sys.stdout
    
    inv_errors_faultProfiles = dict()
    key_name = "_".join([item.replace(" ", "") for item in fault_profile])
    inv_errors_faultProfiles[key_name] = dict() 
    
    # Load priorities 
    alarms_with_priorities = load_priorities(system_name)
    alarm_names = alarms_with_priorities['High']
    
    if save_metrics_to_file:
        profile_name = '_'.join([''.join(word.capitalize() for word in profile.replace('-', '').split(' ')) 
                                 for profile in fault_profile])
        
        file_name = f"error_analysis_{profile_name}"
        if consider_only_failure_starts:
            file_name += "_" + only_failure_starts_prefix
        error_file_path = path.join(perfomance_saving_folder, file_name + ".txt")
        
        error_file = open(error_file_path,  mode="w+")
        print(f"The findings will be saved in a txt file --> {file_name}\n(folder: {perfomance_saving_folder}).\n")
        sys.stdout = error_file
  
    inv_types_counter = defaultdict(int)
    for inv_name in df_inv_metrics.keys():
        metrics_configs = df_inv_metrics[inv_name]

        print("\n" + "-" * 50 + f" PV SYSTEM: {system_name} " + "-" * 50)
        print("\n" + "-" * 45 + f" SOM CONFIGURATION " + "-" * 45)
        configs_pairs = list(zip(test_names, som_configs[inv_name][:num_selected_configs]))
        print('\n'.join([f"({idk + 1}) {config_type.upper()} --> { ' || '.join(config.split('_'))}\n" +"-" * 100
                         for idk, (config_type, config) in enumerate(configs_pairs)]))
        print("\n\n" + "-" * 30 + f" INVERTER: N°{inv_name[-1:]} (FAULT PROFILE: {' || '.join(fault_profile)})" + "-" * 30)
        error_types = dict()
        for idk_type, (config_type, metrics_df) in enumerate(metrics_configs.items()):
            config_type_simplified_name = config_type.replace(pre_steps_configs[0], '').replace("_", ' ').strip().capitalize()
            print("\n" + "-" * 30 + f" TYPE {idk_type}: {config_type_simplified_name} " + "-" * 30)
            
            # Select only a fault profile 
            filtered_metrics = metrics_df[pd.array(metrics_df["Fault Profile"]) == str(fault_profile)]
            filtered_metrics = filtered_metrics[filtered_metrics['Warning levels (>=)']== warning_levels]
            filtered_metrics = filtered_metrics[filtered_metrics['Prediction Window (days)'] == prediction_window]
            
            # Retrieve the faults/alarms 
            raw_failure_events = filtered_metrics['Faults'].unique()[0].split(',')
            dt_format = '%Y-%m-%d (%H:%M)'
            failure_events = []
            failure_event_types = []
            print("-" * 10,"FAILURE EVENTS:", len(raw_failure_events), "-" * 10)
            for idk, raw_event in enumerate(raw_failure_events):
                
                # Extrac information
                event_type = raw_event.split(':')[0].strip("[' ")
                event_message = ':'.join(raw_event.split(':')[1:]).strip().split('\\n')[0].strip()
                period = (pd.to_datetime(raw_event.split('FROM')[1].split('TO')[0].strip("]'").strip(), format = dt_format), 
                          pd.to_datetime(raw_event.split('FROM')[1].split('TO')[1].strip("]'").strip(), format = dt_format))
                event_subType = [name.rstrip() for name in alarm_names if name in event_message]
                event_subType = event_subType[0] if len(event_subType) > 0 else ""
                
                # Save the failure event
                event = {'general_type': event_type,'subtype': event_subType, 'type': event_type + event_subType,
                         'message' : event_message, 'period': period} 
                failure_events.append(event)
                failure_event_types.append(event['type'])
                
                if verbose: 
                    print(f"{idk + 1}) ({event_type}\n\t--> {event_message}\n\t-->",
                          "\n\t--> ".join([ts.strftime(dt_format) for ts in period]))
            num_failure_events = len(failure_events)
            
            types_counter = Counter(failure_event_types)
            print("\t" + "-" * 30, "FAILURE TYPES:", len(types_counter.keys()), "-" * 30)
            print('\t' + '\n\t'.join([f"(x{counter}) {failure_type}" 
                               for failure_type, counter in types_counter.items()]))
            
            # Update the general couter
            if idk_type == 0:
                for failure_event, counter in types_counter.items():
                    inv_types_counter[failure_event] += counter
                
            # Retrieve the warnings
            raw_warnings = filtered_metrics['Fault warnings'].unique()[0].split("('")[1:]
            
            print("\n" + "-" * 25, "TRUE WARNINGS/POSITIVE (i.e., failure events correctly detected)", "-" * 25)
            tp_counter = 0
            tp_types = []
            missed_types = []
            for failure_event in failure_events:
                failure_message = failure_event['message']
                failure_period = failure_event['period']
                failure_type = failure_event['type']
               
                found = False
                for raw_warning in raw_warnings:
                    message = raw_warning.split('_')[0].lstrip()
                    period = (pd.to_datetime(raw_warning.split('_')[1].strip(",[").strip(), format = dt_format),
                              pd.to_datetime(raw_warning.split('_')[2].split(',')[0].strip(",['"), format = dt_format))
             
                    if failure_message == message:
                        if (period[0] == failure_period[0]) and (period[1] == failure_period[1]):                    
                            tp_counter += 1
                            tp_types.append(failure_type)
                            found = True
                            if verbose:
                                print(f"--> ({tp_counter}) FAILURE:", failure_message, "\n\t-->", 
                                      "\n\t--> ".join([ts.strftime(dt_format) for ts in failure_period]))
                if not found:
                    missed_types.append(failure_type)
                
            tp_type_counter = Counter(tp_types)
            missed_types_counter = Counter(missed_types)
            print("\n" + "-" * 35, "METRICS", "-" * 35)                
            print(f"\nFAILURE EVENTS CURRECTLY DETECTED: --> {tp_counter}/{num_failure_events} "\
                  f"({round((tp_counter/num_failure_events)*100, 2)} %)\n" + 60 * "-")
            if len(tp_types) > 0:
                print('-->', '\n--> '.join([f"(x{counter}) {failure_type}"
                                   for failure_type, counter in tp_type_counter.items()]))
            print(f"\nFAILURE EVENTS MISSED --> {num_failure_events - tp_counter}/{num_failure_events} "\
                  f"({round(((num_failure_events - tp_counter)/num_failure_events)*100, 2)} %)\n"+ 60 * "-") 
            print('-->', '\n--> '.join([f"(x{counter}) {failure_type}" 
                               for failure_type, counter in missed_types_counter.items()]))
            
            print("\n" + "-" * 80)
            print("\t\t\t\tERROR ANALYSIS")
            print("-" * 80)
            error_types[config_type_simplified_name] = dict()
            for idk, (failure_type, counter) in enumerate(types_counter.items()):
                missed_counter = missed_types_counter[failure_type]
                print(f"({idk + 1}) {failure_type} --> {missed_counter}/{counter} "\
                      f"({round((missed_counter/counter)*100, 1)} %)")
                error_types[config_type_simplified_name][failure_type] = missed_counter/counter
        
        # Save it 
        inv_errors_faultProfiles[key_name][inv_name] = error_types
    
    # Change organization
    avg_inv_errors_faultProfiles = defaultdict(dict)
    for inv_name, config_errors in inv_errors_faultProfiles[key_name].items():
        for config_type, errors in config_errors.items():
            
            for failure_event, error in errors.items():
                try: 
                    avg_inv_errors_faultProfiles[config_type][failure_event].append(error)
                except KeyError:
                     avg_inv_errors_faultProfiles[config_type][failure_event] = [error]
                        
    error_df = pd.DataFrame.from_dict(avg_inv_errors_faultProfiles)
    error_df.columns = ['[Error %] '+col for col in error_df.columns]
    avg_error_df = error_df.applymap(lambda list_values: np.mean(list_values) * 100)
    
    # Append the total failure events as a new column
    assign_counter = lambda df_row: [counter for failure_event, counter in inv_types_counter.items() 
                                     if failure_event == df_row.name]
    new_col = avg_error_df.apply(func = lambda df_row: assign_counter(df_row)[0] if len(assign_counter(df_row)) else 0, axis = 1) 
    avg_error_df.insert(loc = 0, column = 'Failure events', value = new_col)
    
    # TechnicaL transformation
    avg_error_df = avg_error_df.round(decimals = 2)
    avg_error_df = avg_error_df.sort_index()

    # Create a multi-index
    main_types = [name.split('(')[0].strip() for name in avg_error_df.index]
    sub_types = ['(' + name.split('(')[1] for name in avg_error_df.index]
    print(sub_types)
    sub_types = [name.split(')')[0].upper() + ')' + name.split(')')[1] for name in sub_types]
    new_multindex = pd.MultiIndex.from_tuples(list(zip(main_types, sub_types)))
    avg_error_df.index = new_multindex
    
    # Sort values
    avg_error_df = avg_error_df.sort_index().sort_values(by = ['[Error %] Best for inverter','Failure events'],
                                                         ascending = False, kind = 'stable')
    
    if save_metrics_to_file: 
        print("\n\n" + '-' * 150 + "\n" + '-' * 150)
        print('-' * 71 + " SUMMARY " + '-' * 70)
        print('-' * 150 + "\n" + '-' * 150 + "\n")
        print(tabulate(avg_error_df, headers = 'keys', tablefmt = 'psql'))
        sys.stdout.close()
        sys.stdout = console_stdout
    else: 
        display(avg_error_df)

    return avg_error_df

# %% [markdown]
# #### B6.1) Visualize the error analysis [in details]

# %%
warning_levels = 1
prediction_window = 7

# %%
fault_profile = fault_profiles_available[0]
avg_error_df = visualize_error_analysis(fault_profile, warning_levels, prediction_window, save_metrics_to_file)
# Out:
# -------------------------------------------------- PV SYSTEM: Galatina --------------------------------------------------
#
# --------------------------------------------- SOM CONFIGURATION ---------------------------------------------
# (1) TEST(0): BEST_FOR_INVERTER (GALATINA) --> 26grid || 10Kepoch || 0.01lr || 2sigma || gaussianFunc
# ----------------------------------------------------------------------------------------------------
# (2) TEST(1): AVERAGED_ACROSS_INVERTER (GALATINA) --> 26grid || 8Kepoch || 0.01lr || 4sigma || gaussianFunc
# ----------------------------------------------------------------------------------------------------
# (3) TEST(2): AVERAGED_ACROSS_PVSYSTEMS --> 20grid || 6Kepoch || 0.001lr || 1sigma || gaussianFunc
# ----------------------------------------------------------------------------------------------------
#
#
# ------------------------------ INVERTER: N°1 (FAULT PROFILE: General Fault || Log - High)------------------------------
#
# ------------------------------ TYPE 0: Best for inverter ------------------------------
# ---------- FAILURE EVENTS: 5 ----------
# 	------------------------------ FAILURE TYPES: 1 ------------------------------
# 	(x5) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti
#
# ------------------------- TRUE WARNINGS/POSITIVE (i.e., failure events correctly detected) -------------------------
#
# ----------------------------------- METRICS -----------------------------------
#
# FAILURE EVENTS CURRECTLY DETECTED: --> 3/5 (60.0 %)
# ------------------------------------------------------------
# --> (x3) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti
#
# FAILURE EVENTS MISSED --> 2/5 (40.0 %)
# ------------------------------------------------------------
# --> (x2) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti
#
# --------------------------------------------------------------------------------
# 				ERROR ANALYSIS
# --------------------------------------------------------------------------------
# (1) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti --> 2/5 (40.0 %)
#
# ------------------------------ TYPE 1: Averaged across inverter ------------------------------
# ---------- FAILURE EVENTS: 5 ----------
# 	------------------------------ FAILURE TYPES: 1 ------------------------------
# 	(x5) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti
#
# ------------------------- TRUE WARNINGS/POSITIVE (i.e., failure events correctly detected) -------------------------
#
# ----------------------------------- METRICS -----------------------------------
#
# FAILURE EVENTS CURRECTLY DETECTED: --> 3/5 (60.0 %)
# ------------------------------------------------------------
# --> (x3) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti
#
# FAILURE EVENTS MISSED --> 2/5 (40.0 %)
# ------------------------------------------------------------
# --> (x2) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti
#
# --------------------------------------------------------------------------------
# 				ERROR ANALYSIS
# --------------------------------------------------------------------------------
# (1) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti --> 2/5 (40.0 %)
#
# ------------------------------ TYPE 2: Averaged across pvsystems ------------------------------
# ---------- FAILURE EVENTS: 5 ----------
# 	------------------------------ FAILURE TYPES: 1 ------------------------------
# 	(x5) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti
#
# ------------------------- TRUE WARNINGS/POSITIVE (i.e., failure events correctly detected) -------------------------
#
# ----------------------------------- METRICS -----------------------------------
#
# FAILURE EVENTS CURRECTLY DETECTED: --> 2/5 (40.0 %)
# ------------------------------------------------------------
# --> (x2) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti
#
# FAILURE EVENTS MISSED --> 3/5 (60.0 %)
# ------------------------------------------------------------
# --> (x3) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti
#
# --------------------------------------------------------------------------------
# 				ERROR ANALYSIS
# --------------------------------------------------------------------------------
# (1) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti --> 3/5 (60.0 %)
#
# -------------------------------------------------- PV SYSTEM: Galatina --------------------------------------------------
#
# --------------------------------------------- SOM CONFIGURATION ---------------------------------------------
# (1) TEST(0): BEST_FOR_INVERTER (GALATINA) --> 30grid || 30Kepoch || 0.01lr || 1sigma || gaussianFunc
# ----------------------------------------------------------------------------------------------------
# (2) TEST(1): AVERAGED_ACROSS_INVERTER (GALATINA) --> 26grid || 8Kepoch || 0.01lr || 4sigma || gaussianFunc
# ----------------------------------------------------------------------------------------------------
# (3) TEST(2): AVERAGED_ACROSS_PVSYSTEMS --> 20grid || 6Kepoch || 0.001lr || 1sigma || gaussianFunc
# ----------------------------------------------------------------------------------------------------
#
#
# ------------------------------ INVERTER: N°2 (FAULT PROFILE: General Fault || Log - High)------------------------------
#
# ------------------------------ TYPE 0: Best for inverter ------------------------------
# ---------- FAILURE EVENTS: 268 ----------
# 	------------------------------ FAILURE TYPES: 4 ------------------------------
# 	(x258) LOG - HIGH (Allarme inverter)Intervento protezione esterna
# 	(x1) LOG - HIGH (Allarme inverter)Sovracorrente inverter
# 	(x8) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti
# 	(x1) LOG - HIGH (Allarme inverter)Mancanza comunicazione CAN
#
# ------------------------- TRUE WARNINGS/POSITIVE (i.e., failure events correctly detected) -------------------------
#
# ----------------------------------- METRICS -----------------------------------
#
# FAILURE EVENTS CURRECTLY DETECTED: --> 158/268 (58.96 %)
# ------------------------------------------------------------
# --> (x149) LOG - HIGH (Allarme inverter)Intervento protezione esterna
# --> (x1) LOG - HIGH (Allarme inverter)Sovracorrente inverter
# --> (x7) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti
# --> (x1) LOG - HIGH (Allarme inverter)Mancanza comunicazione CAN
#
# FAILURE EVENTS MISSED --> 110/268 (41.04 %)
# ------------------------------------------------------------
# --> (x109) LOG - HIGH (Allarme inverter)Intervento protezione esterna
# --> (x1) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti
#
# --------------------------------------------------------------------------------
# 				ERROR ANALYSIS
# --------------------------------------------------------------------------------
# (1) LOG - HIGH (Allarme inverter)Intervento protezione esterna --> 109/258 (42.2 %)
# (2) LOG - HIGH (Allarme inverter)Sovracorrente inverter --> 0/1 (0.0 %)
# (3) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti --> 1/8 (12.5 %)
# (4) LOG - HIGH (Allarme inverter)Mancanza comunicazione CAN --> 0/1 (0.0 %)
#
# ------------------------------ TYPE 1: Averaged across inverter ------------------------------
# ---------- FAILURE EVENTS: 268 ----------
# 	------------------------------ FAILURE TYPES: 4 ------------------------------
# 	(x258) LOG - HIGH (Allarme inverter)Intervento protezione esterna
# 	(x1) LOG - HIGH (Allarme inverter)Mancanza comunicazione CAN
# 	(x8) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti
# 	(x1) LOG - HIGH (Allarme inverter)Sovracorrente inverter
#
# ------------------------- TRUE WARNINGS/POSITIVE (i.e., failure events correctly detected) -------------------------
#
# ----------------------------------- METRICS -----------------------------------
#
# FAILURE EVENTS CURRECTLY DETECTED: --> 122/268 (45.52 %)
# ------------------------------------------------------------
# --> (x117) LOG - HIGH (Allarme inverter)Intervento protezione esterna
# --> (x1) LOG - HIGH (Allarme inverter)Mancanza comunicazione CAN
# --> (x3) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti
# --> (x1) LOG - HIGH (Allarme inverter)Sovracorrente inverter
#
# FAILURE EVENTS MISSED --> 146/268 (54.48 %)
# ------------------------------------------------------------
# --> (x141) LOG - HIGH (Allarme inverter)Intervento protezione esterna
# --> (x5) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti
#
# --------------------------------------------------------------------------------
# 				ERROR ANALYSIS
# --------------------------------------------------------------------------------
# (1) LOG - HIGH (Allarme inverter)Intervento protezione esterna --> 141/258 (54.7 %)
# (2) LOG - HIGH (Allarme inverter)Mancanza comunicazione CAN --> 0/1 (0.0 %)
# (3) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti --> 5/8 (62.5 %)
# (4) LOG - HIGH (Allarme inverter)Sovracorrente inverter --> 0/1 (0.0 %)
#
# ------------------------------ TYPE 2: Averaged across pvsystems ------------------------------
# ---------- FAILURE EVENTS: 268 ----------
# 	------------------------------ FAILURE TYPES: 4 ------------------------------
# 	(x258) LOG - HIGH (Allarme inverter)Intervento protezione esterna
# 	(x8) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti
# 	(x1) LOG - HIGH (Allarme inverter)Mancanza comunicazione CAN
# 	(x1) LOG - HIGH (Allarme inverter)Sovracorrente inverter
#
# ------------------------- TRUE WARNINGS/POSITIVE (i.e., failure events correctly detected) -------------------------
#
# ----------------------------------- METRICS -----------------------------------
#
# FAILURE EVENTS CURRECTLY DETECTED: --> 104/268 (38.81 %)
# ------------------------------------------------------------
# --> (x97) LOG - HIGH (Allarme inverter)Intervento protezione esterna
# --> (x5) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti
# --> (x1) LOG - HIGH (Allarme inverter)Mancanza comunicazione CAN
# --> (x1) LOG - HIGH (Allarme inverter)Sovracorrente inverter
#
# FAILURE EVENTS MISSED --> 164/268 (61.19 %)
# ------------------------------------------------------------
# --> (x161) LOG - HIGH (Allarme inverter)Intervento protezione esterna
# --> (x3) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti
#
# --------------------------------------------------------------------------------
# 				ERROR ANALYSIS
# --------------------------------------------------------------------------------
# (1) LOG - HIGH (Allarme inverter)Intervento protezione esterna --> 161/258 (62.4 %)
# (2) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti --> 3/8 (37.5 %)
# (3) LOG - HIGH (Allarme inverter)Mancanza comunicazione CAN --> 0/1 (0.0 %)
# (4) LOG - HIGH (Allarme inverter)Sovracorrente inverter --> 0/1 (0.0 %)
#
# -------------------------------------------------- PV SYSTEM: Galatina --------------------------------------------------
#
# --------------------------------------------- SOM CONFIGURATION ---------------------------------------------
# (1) TEST(0): BEST_FOR_INVERTER (GALATINA) --> 26grid || 2Kepoch || 0.01lr || 10sigma || gaussianFunc
# ----------------------------------------------------------------------------------------------------
# (2) TEST(1): AVERAGED_ACROSS_INVERTER (GALATINA) --> 26grid || 8Kepoch || 0.01lr || 4sigma || gaussianFunc
# ----------------------------------------------------------------------------------------------------
# (3) TEST(2): AVERAGED_ACROSS_PVSYSTEMS --> 20grid || 6Kepoch || 0.001lr || 1sigma || gaussianFunc
# ----------------------------------------------------------------------------------------------------
#
#
# ------------------------------ INVERTER: N°3 (FAULT PROFILE: General Fault || Log - High)------------------------------
#
# ------------------------------ TYPE 0: Best for inverter ------------------------------
# ---------- FAILURE EVENTS: 7 ----------
# 	------------------------------ FAILURE TYPES: 1 ------------------------------
# 	(x7) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti
#
# ------------------------- TRUE WARNINGS/POSITIVE (i.e., failure events correctly detected) -------------------------
#
# ----------------------------------- METRICS -----------------------------------
#
# FAILURE EVENTS CURRECTLY DETECTED: --> 6/7 (85.71 %)
# ------------------------------------------------------------
# --> (x6) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti
#
# FAILURE EVENTS MISSED --> 1/7 (14.29 %)
# ------------------------------------------------------------
# --> (x1) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti
#
# --------------------------------------------------------------------------------
# 				ERROR ANALYSIS
# --------------------------------------------------------------------------------
# (1) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti --> 1/7 (14.3 %)
#
# ------------------------------ TYPE 1: Averaged across inverter ------------------------------
# ---------- FAILURE EVENTS: 7 ----------
# 	------------------------------ FAILURE TYPES: 1 ------------------------------
# 	(x7) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti
#
# ------------------------- TRUE WARNINGS/POSITIVE (i.e., failure events correctly detected) -------------------------
#
# ----------------------------------- METRICS -----------------------------------
#
# FAILURE EVENTS CURRECTLY DETECTED: --> 2/7 (28.57 %)
# ------------------------------------------------------------
# --> (x2) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti
#
# FAILURE EVENTS MISSED --> 5/7 (71.43 %)
# ------------------------------------------------------------
# --> (x5) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti
#
# --------------------------------------------------------------------------------
# 				ERROR ANALYSIS
# --------------------------------------------------------------------------------
# (1) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti --> 5/7 (71.4 %)
#
# ------------------------------ TYPE 2: Averaged across pvsystems ------------------------------
# ---------- FAILURE EVENTS: 7 ----------
# 	------------------------------ FAILURE TYPES: 1 ------------------------------
# 	(x7) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti
#
# ------------------------- TRUE WARNINGS/POSITIVE (i.e., failure events correctly detected) -------------------------
#
# ----------------------------------- METRICS -----------------------------------
#
# FAILURE EVENTS CURRECTLY DETECTED: --> 2/7 (28.57 %)
# ------------------------------------------------------------
# --> (x2) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti
#
# FAILURE EVENTS MISSED --> 5/7 (71.43 %)
# ------------------------------------------------------------
# --> (x5) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti
#
# --------------------------------------------------------------------------------
# 				ERROR ANALYSIS
# --------------------------------------------------------------------------------
# (1) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti --> 5/7 (71.4 %)
#
# -------------------------------------------------- PV SYSTEM: Galatina --------------------------------------------------
#
# --------------------------------------------- SOM CONFIGURATION ---------------------------------------------
# (1) TEST(0): BEST_FOR_INVERTER (GALATINA) --> 30grid || 8Kepoch || 0.01lr || 5sigma || gaussianFunc
# ----------------------------------------------------------------------------------------------------
# (2) TEST(1): AVERAGED_ACROSS_INVERTER (GALATINA) --> 26grid || 8Kepoch || 0.01lr || 4sigma || gaussianFunc
# ----------------------------------------------------------------------------------------------------
# (3) TEST(2): AVERAGED_ACROSS_PVSYSTEMS --> 20grid || 6Kepoch || 0.001lr || 1sigma || gaussianFunc
# ----------------------------------------------------------------------------------------------------
#
#
# ------------------------------ INVERTER: N°4 (FAULT PROFILE: General Fault || Log - High)------------------------------
#
# ------------------------------ TYPE 0: Best for inverter ------------------------------
# ---------- FAILURE EVENTS: 8 ----------
# 	------------------------------ FAILURE TYPES: 1 ------------------------------
# 	(x8) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti
#
# ------------------------- TRUE WARNINGS/POSITIVE (i.e., failure events correctly detected) -------------------------
#
# ----------------------------------- METRICS -----------------------------------
#
# FAILURE EVENTS CURRECTLY DETECTED: --> 6/8 (75.0 %)
# ------------------------------------------------------------
# --> (x6) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti
#
# FAILURE EVENTS MISSED --> 2/8 (25.0 %)
# ------------------------------------------------------------
# --> (x2) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti
#
# --------------------------------------------------------------------------------
# 				ERROR ANALYSIS
# --------------------------------------------------------------------------------
# (1) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti --> 2/8 (25.0 %)
#
# ------------------------------ TYPE 1: Averaged across inverter ------------------------------
# ---------- FAILURE EVENTS: 8 ----------
# 	------------------------------ FAILURE TYPES: 1 ------------------------------
# 	(x8) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti
#
# ------------------------- TRUE WARNINGS/POSITIVE (i.e., failure events correctly detected) -------------------------
#
# ----------------------------------- METRICS -----------------------------------
#
# FAILURE EVENTS CURRECTLY DETECTED: --> 4/8 (50.0 %)
# ------------------------------------------------------------
# --> (x4) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti
#
# FAILURE EVENTS MISSED --> 4/8 (50.0 %)
# ------------------------------------------------------------
# --> (x4) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti
#
# --------------------------------------------------------------------------------
# 				ERROR ANALYSIS
# --------------------------------------------------------------------------------
# (1) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti --> 4/8 (50.0 %)
#
# ------------------------------ TYPE 2: Averaged across pvsystems ------------------------------
# ---------- FAILURE EVENTS: 8 ----------
# 	------------------------------ FAILURE TYPES: 1 ------------------------------
# 	(x8) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti
#
# ------------------------- TRUE WARNINGS/POSITIVE (i.e., failure events correctly detected) -------------------------
#
# ----------------------------------- METRICS -----------------------------------
#
# FAILURE EVENTS CURRECTLY DETECTED: --> 1/8 (12.5 %)
# ------------------------------------------------------------
# --> (x1) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti
#
# FAILURE EVENTS MISSED --> 7/8 (87.5 %)
# ------------------------------------------------------------
# --> (x7) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti
#
# --------------------------------------------------------------------------------
# 				ERROR ANALYSIS
# --------------------------------------------------------------------------------
# (1) LOG - HIGH (Allarme inverter)Tensione rete fuori dai limiti --> 7/8 (87.5 %)
# ['(Allarme inverter)Intervento protezione esterna', '(Allarme inverter)Mancanza comunicazione CAN', '(Allarme inverter)Sovracorrente inverter', '(Allarme inverter)Tensione rete fuori dai limiti']
#                                                              Failure events  \
# LOG - HIGH (ALLARME INVERTER)Intervento protezione esterna              258
#            (ALLARME INVERTER)Tensione rete fuori dai limiti              28
#            (ALLARME INVERTER)Mancanza comunicazione CAN                   1
#            (ALLARME INVERTER)Sovracorrente inverter                       1
#
#                                                              [Error %] Best for inverter  \
# LOG - HIGH (ALLARME INVERTER)Intervento protezione esterna                         42.25
#            (ALLARME INVERTER)Tensione rete fuori dai limiti                        22.95
#            (ALLARME INVERTER)Mancanza comunicazione CAN                             0.00
#            (ALLARME INVERTER)Sovracorrente inverter                                 0.00
#
#                                                              [Error %] Averaged across inverter  \
# LOG - HIGH (ALLARME INVERTER)Intervento protezione esterna                                54.65
#            (ALLARME INVERTER)Tensione rete fuori dai limiti                               55.98
#            (ALLARME INVERTER)Mancanza comunicazione CAN                                    0.00
#            (ALLARME INVERTER)Sovracorrente inverter                                        0.00
#
#                                                              [Error %] Averaged across pvsystems
# LOG - HIGH (ALLARME INVERTER)Intervento protezione esterna                                 62.40
#            (ALLARME INVERTER)Tensione rete fuori dai limiti                                64.11
#            (ALLARME INVERTER)Mancanza comunicazione CAN                                     0.00
#            (ALLARME INVERTER)Sovracorrente inverter                                         0.00

# %% [markdown]
# #### B6.2) GIST: Error analysis

# %%
print("-" * 120, "\n\t\t\t\t\t\t\tError Analysis\n","-" * 120)
display(avg_error_df)
# Out:
# ------------------------------------------------------------------------------------------------------------------------
# 							Error Analysis
#  ------------------------------------------------------------------------------------------------------------------------
#                                                              Failure events  \
# LOG - HIGH (ALLARME INVERTER)Intervento protezione esterna              258
#            (ALLARME INVERTER)Tensione rete fuori dai limiti              28
#            (ALLARME INVERTER)Mancanza comunicazione CAN                   1
#            (ALLARME INVERTER)Sovracorrente inverter                       1
#
#                                                              [Error %] Best for inverter  \
# LOG - HIGH (ALLARME INVERTER)Intervento protezione esterna                         42.25
#            (ALLARME INVERTER)Tensione rete fuori dai limiti                        22.95
#            (ALLARME INVERTER)Mancanza comunicazione CAN                             0.00
#            (ALLARME INVERTER)Sovracorrente inverter                                 0.00
#
#                                                              [Error %] Averaged across inverter  \
# LOG - HIGH (ALLARME INVERTER)Intervento protezione esterna                                54.65
#            (ALLARME INVERTER)Tensione rete fuori dai limiti                               55.98
#            (ALLARME INVERTER)Mancanza comunicazione CAN                                    0.00
#            (ALLARME INVERTER)Sovracorrente inverter                                        0.00
#
#                                                              [Error %] Averaged across pvsystems
# LOG - HIGH (ALLARME INVERTER)Intervento protezione esterna                                 62.40
#            (ALLARME INVERTER)Tensione rete fuori dai limiti                                64.11
#            (ALLARME INVERTER)Mancanza comunicazione CAN                                     0.00
#            (ALLARME INVERTER)Sovracorrente inverter                                         0.00

# %% [markdown]
# ## Various stuff

# %% [raw]
# # CONFIG 1 --> np.mean(warning 4, warning 3)
# # ci saranno 8 casistiche --> 4 inv x 2 warning (warning = 4, 3)
# configs_perfomance_highWarning = dict()
# configs_perfomance_lowWarning = dict()
# verbose = False
# metrics_name = ["F1", "Recall", "Precision", "Fall-Out"]
#
# # CASE 1: test set --> FAULT
# rankedList_fault = inv_ranked_configs_faultProfiles["GeneralFault"]
# print("CASE 1: [ONLY FAULTS] Warning levels >=3, >=4")
# for idk, inv_perfomance in enumerate(rankedList_fault):
#     #print("INVERTER N° ", idk + 1)
#     for warning_level in ["warning4", "warning3"]:
#
#         rankedConfigs = inv_perfomance[warning_level]
#         for rank, config, f1_score, recall, precision, fallOut in rankedConfigs:
#             metrics = {"metrics": (f1_score, recall, precision, fallOut), "rank": rank}
#             try:
#                 configs_perfomance_highWarning[config].append(metrics)
#             except KeyError:
#                 configs_perfomance_highWarning[config] = [metrics]
#
#     for config, perfomance in configs_perfomance_highWarning.items():
#         metrics = [item["metrics"] for item in perfomance]
#         avg_metrics = np.mean(metrics, axis = 0)
#         if verbose:
#             print(f"\nCONFIG: {config} --> \n{list(zip(metrics_name, avg_metrics))}")
#
# # CASO 2: test set --> FAULT + allarmi
# rankedList = inv_ranked_configs_faultProfiles["GeneralFault_Log-High"]
# for inv_perfomance in rankedList:
#     for warning_level in ["warning1", "warning2"]:
#         rankedConfigs = inv_perfomance[warning_level]
#         for rank, config, f1_score, recall, precision, fallOut in rankedConfigs:
#             metrics = {"metrics": (f1_score, recall, precision, fallOut), "rank": rank}
#             try:
#                 configs_perfomance_lowWarning[config].append(metrics)
#             except KeyError:
#                 configs_perfomance_lowWarning[config] = [metrics]
# #display(configs_perfomance_lowWarning)
#
# # -------------------------------------------------------------
# avg_series = []
# for config, perfomance in configs_perfomance_highWarning.items():
#     metrics = [item["metrics"] for item in perfomance if not np.isnan(item["metrics"][0])]
#     ranks = [item["rank"] for item in perfomance if not np.isnan(item["metrics"][0])]
#
#     avg_metrics = np.mean(metrics, axis = 0)
#     avg_rank = np.mean(ranks)
#
#     x = pd.Series(data = avg_metrics, index = [item + " [AVG]" for item in metrics_name], name = config)
#     y = pd.Series(data = [avg_rank, ranks], index = ["RANK [AVG]", "RANKS"], name = config)
#
#     avg_series.append(pd.concat([x, y]))
#
# df_high = pd.DataFrame(avg_series)
# df_high = df_high.sort_values(by = ["F1 [AVG]"], ascending = False)
# k = 3
# list_ranks = range(1, k +1)
# display(df_high)
#
# # frequecies
# exploded = df_high.explode(column = "RANKS")
# exploded["CONFIG"] = exploded.index
# exploded["TOP3"] = exploded["RANKS"].apply(lambda rank: True if rank in list_ranks else False)
# exploded_filtered = exploded[exploded["TOP3"] == True]
#
# groupedRanks = exploded_filtered.groupby(by = ["CONFIG", "TOP3"]).count()["F1 [AVG]"].to_frame()
# groupedRanks = groupedRanks.rename(columns = {"F1 [AVG]":"FREQ"})
# groupedRanks = groupedRanks.sort_values(by = ["FREQ", "TOP3"], ascending = False)
# display(groupedRanks)
#
# groupedRanks_raw = exploded.groupby(by = ["CONFIG", "RANKS"]).count()["F1 [AVG]"].to_frame()
# groupedRanks_raw = groupedRanks.rename(columns = {"F1 [AVG]":"FREQ"})
# groupedRanks_raw = groupedRanks.sort_values(by = ["FREQ"], ascending = [False])
# display(groupedRanks_raw)
#
# # -------------------------------------
# avg_series_low = []
# for config, perfomance in configs_perfomance_lowWarning.items():
#     metrics = [item["metrics"] for item in perfomance if not np.isnan(item["metrics"][0])]
#     ranks = [item["rank"] for item in perfomance if not np.isnan(item["metrics"][0])]
#
#     avg_metrics = np.mean(metrics, axis = 0)
#     avg_rank = np.mean(ranks)
#
#     x = pd.Series(data = avg_metrics, index = [item + " [AVG]" for item in metrics_name], name = config)
#     y = pd.Series(data = [avg_rank, ranks], index = ["RANK [AVG]", "RANKS"], name = config)
#
#     avg_series_low.append(pd.concat([x, y]))
#
# print("CASE 2: [FAULTS + LOG_HIGH] Warning levels >=1, >=2")
# df_low = pd.DataFrame(avg_series_low)
# df_low = df_low.sort_values(by = ["F1 [AVG]"], ascending = False)
# display(df_low)
#
# # frequecies
# exploded2 = df_low.explode(column = "RANKS")
# exploded2["CONFIG"] = exploded2.index
# exploded2["TOP3"] = exploded2["RANKS"].apply(lambda rank: True if rank in list_ranks else False)
# exploded2 = exploded2[exploded2["TOP3"] == True]
#
# groupedRanks2 = exploded2.groupby(by = ["CONFIG", "TOP3"]).count()["F1 [AVG]"].to_frame()
# groupedRanks2 = groupedRanks2.rename(columns = {"F1 [AVG]":"FREQ"})
# groupedRanks2 = groupedRanks2.sort_values(by = ["FREQ", "TOP3"], ascending = False)
# display(groupedRanks2)
#
# #inv_ranked_configs_faultProfiles["GeneralFault_Log-High"]
# # (CONFIG. 22) 1hour_averaged_fullLinReg_detrended

# %% [markdown]
# # Various [OLD STUFF]

# %% [raw]
# # METRICS 1: AVG F1 score for each case
# warning_groups_perfomance = []
# for idk, inv_perfomance in enumerate(inv_ranked_configs):
#     print("-" * 20 + f" INVERTER N° {idk +1}" + "-" * 20 )
#     #print("KEYS:", inv_perfomance.keys())
#
#     case_fault_a = inv_perfomance["warning4"]
#     avg_f1_list4 = np.nanmean([item[2] for item in inv_perfomance["warning4"]])
#     avg_f1_list3 = np.nanmean([item[2] for item in inv_perfomance["warning3"]])
#     avg_f1_list2 = np.nanmean([item[2] for item in inv_perfomance["warning2"]])
#     avg_f1_list1 = np.nanmean([item[2] for item in inv_perfomance["warning1"]])
#
#     avg_warnHigh = np.mean([avg_f1_list3, avg_f1_list4])
#     avg_warnLow = np.mean([avg_f1_list1, avg_f1_list2])
#     warning_groups_perfomance.append({"Group3_4": avg_warnHigh, "Group1_2": avg_warnLow})
#
#     print(f"WARNING >= 4: [AVG] F1-SCORE --> {round(avg_f1_list4, 2) } %")
#     print(f"WARNING >= 3: [AVG] F1-SCORE --> {round(avg_f1_list3, 2) } %")
#     print(f"WARNING >= 2: [AVG] F1-SCORE --> {round(avg_f1_list2, 2) } %")
#     print(f"WARNING >= 1: [AVG] F1-SCORE --> {round(avg_f1_list1, 2) } %")
#     print(f"\n[G1] WARNING >= 3 & >= 4: [AVG] F1-SCORE --> {round(avg_warnHigh, 2)} %")
#     print(f"[G2] WARNING >= 1 & >= 2: [AVG] F1-SCORE --> {round(avg_warnLow, 2)} %\n")
#
# print("-" * 10 + " OVERALL PERFORMANCE " + "-" * 10 )
# avg_group3_4 = np.nanmean([inv_perfomance["Group3_4"] for inv_perfomance in warning_groups_perfomance])
# avg_group1_2 = np.nanmean([inv_perfomance["Group1_2"] for inv_perfomance in warning_groups_perfomance])
# print(f"\n[G1] WARNING >= 3 & >= 4: [AVG] F1-SCORE --> {round(avg_group3_4, 2)} %")
# print(f"[G2] WARNING >= 1 & >= 2: [AVG] F1-SCORE --> {round(avg_group1_2, 2)} %\n")
# print("-" * 120)
